# %% [markdown]
# # Exploring merged Spotify Charts and Track Data

# %% [markdown]
# In this notebook, I finally merge my custom, cleaned "Spotify Top 50 Charts (2017-2021, for 50 countries)" dataset (`spotify_charts_cleaned.csv`) with all the track metadata I collected (`track_data_combined.csv`). Let's inspect the quality of the data and see if we can identify some interesting patterns in it!

# %%
from helpers import get_data_path, create_data_out_path, ROOT_DIR, DATA_DIR
import pandas as pd
from ast import literal_eval

# %%
tracks = pd.read_csv(
    get_data_path("track_data_combined.csv"),
    index_col="id",
    dtype={"album_type": "category"},
    converters={"genres": literal_eval},
    parse_dates=["album_release_date"]
)

# %%
tracks
# Out:
#                         explicit                                  name  \
# id
# 000RW47rhEkSqjgTrZx7YX     False                      Lance Individual
# 000xQL6tZNLJzIrtIgxqSl     False  Still Got Time (feat. PARTYNEXTDOOR)
# 000xYdQfIZ4pDmBGzQalKU     False                 Eu, Você, O Mar e Ela
# 001b8t3bYPfnabpjpfG1Y4      True                             Geen Stof
# 003VDDA7J3Xb2ZFlNx7nIZ      True                               YELL OH
# ...                          ...                                   ...
# 7zxphfIdUMOfZOAVpKFlld      True           Trapper Of The Year (Intro)
# 7zyYmIdjqqiX6kLryb7QBx     False                                以後別做朋友
# 7zyZ9yPXIQebb79PrMghpV     False                               Zap Zum
# 7zyofXGhXgaqT8fhvLufdf     False                  Kuka Antais Pukille?
# 7zzhknA0A39TH81meuX7WA      True                     C'est pas des LOL
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000xQL6tZNLJzIrtIgxqSl  https://p.scdn.co/mp3-preview/83fad967740b8a85...
# 000xYdQfIZ4pDmBGzQalKU  https://p.scdn.co/mp3-preview/ae0e943883e06623...
# 001b8t3bYPfnabpjpfG1Y4  https://p.scdn.co/mp3-preview/535320aa4cbc5811...
# 003VDDA7J3Xb2ZFlNx7nIZ  https://p.scdn.co/mp3-preview/14e659590d1a70cf...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  https://p.scdn.co/mp3-preview/b48d68019fc66831...
# 7zyYmIdjqqiX6kLryb7QBx  https://p.scdn.co/mp3-preview/4d243321f0ec66ba...
# 7zyZ9yPXIQebb79PrMghpV  https://p.scdn.co/mp3-preview/2f82c76f077fb377...
# 7zyofXGhXgaqT8fhvLufdf  https://p.scdn.co/mp3-preview/236ec096925cdb1f...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                        album_type                album_id album_release_date  \
# id
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000xQL6tZNLJzIrtIgxqSl     single  2kGUeTGnkLOYlinKRJe47G         2017-03-23
# 000xYdQfIZ4pDmBGzQalKU      album  4QianJs5Ls4mxwcT7gDBww         2016-11-04
# 001b8t3bYPfnabpjpfG1Y4      album  06v2EPzWTwcP0egTJVrPdU         2021-01-21
# 003VDDA7J3Xb2ZFlNx7nIZ     single  2orYogfKeURqyS1hRP1vZ4         2020-02-07
# ...                           ...                     ...                ...
# 7zxphfIdUMOfZOAVpKFlld     single  65DP4VYecvLUlUVfCsXPLF         2021-11-19
# 7zyYmIdjqqiX6kLryb7QBx      album  1JEzXcEYuEFKKmo4mfMgC7         2014-12-19
# 7zyZ9yPXIQebb79PrMghpV      album  194szTkDIGJsa9iZJNStwN         2021-06-24
# 7zyofXGhXgaqT8fhvLufdf     single  2QIHDFGxEjYdVg8Y1QYBRv         2018-11-21
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
#
#                        album_release_date_precision          isrc  isrc_year  \
# id
# 000RW47rhEkSqjgTrZx7YX                          day  BRRGE2010642     2020.0
# 000xQL6tZNLJzIrtIgxqSl                          day  USRC11700675     2017.0
# 000xYdQfIZ4pDmBGzQalKU                          day  BRRGE1603547     2016.0
# 001b8t3bYPfnabpjpfG1Y4                          day  NLG662000948     2020.0
# 003VDDA7J3Xb2ZFlNx7nIZ                          day  QZJ842000061     2020.0
# ...                                             ...           ...        ...
# 7zxphfIdUMOfZOAVpKFlld                          day  SE6XY2184006     2021.0
# 7zyYmIdjqqiX6kLryb7QBx                          day  TWA471410001     2014.0
# 7zyZ9yPXIQebb79PrMghpV                          day  BCM112100037     2021.0
# 7zyofXGhXgaqT8fhvLufdf                          day  FIUM71800543     2018.0
# 7zzhknA0A39TH81meuX7WA                          day  FR96X1941264     2019.0
#
#                               isrc_agency  ...    tempo  duration_ms  \
# id                                         ...
# 000RW47rhEkSqjgTrZx7YX  Pro-música Brazil  ...  117.399     164459.0
# 000xQL6tZNLJzIrtIgxqSl               RIAA  ...  120.963     188491.0
# 000xYdQfIZ4pDmBGzQalKU  Pro-música Brazil  ...  166.018     187119.0
# 001b8t3bYPfnabpjpfG1Y4               SENA  ...   95.951     167866.0
# 003VDDA7J3Xb2ZFlNx7nIZ               RIAA  ...   74.496     236779.0
# ...                                   ...  ...      ...          ...
# 7zxphfIdUMOfZOAVpKFlld        IFPI Sweden  ...  121.913     110164.0
# 7zyYmIdjqqiX6kLryb7QBx                RIT  ...  130.576     260573.0
# 7zyZ9yPXIQebb79PrMghpV  Pro-música Brazil  ...  169.123     167503.0
# 7zyofXGhXgaqT8fhvLufdf       IFPI Finland  ...   89.982     241564.0
# 7zzhknA0A39TH81meuX7WA               SCPP  ...  132.004     279467.0
#
#                         time_signature             artist_id_1  \
# id
# 000RW47rhEkSqjgTrZx7YX             4.0  1elUiq4X7pxej6FRlrEzjM
# 000xQL6tZNLJzIrtIgxqSl             4.0  5ZsFI1h6hIdQRw2ti0hz81
# 000xYdQfIZ4pDmBGzQalKU             4.0  3qvcCP2J0fWi0m0uQDUf6r
# 001b8t3bYPfnabpjpfG1Y4             4.0  1wFoE1RwBMWoWkXcFrCgsx
# 003VDDA7J3Xb2ZFlNx7nIZ             4.0  6Xgp2XMz1fhVYe7i6yNAax
# ...                                ...                     ...
# 7zxphfIdUMOfZOAVpKFlld             4.0  2Dor6diK1zw9BEluKBOdoA
# 7zyYmIdjqqiX6kLryb7QBx             4.0  5fEQLwq1BWWQNR8GzhOIvi
# 7zyZ9yPXIQebb79PrMghpV             4.0  6tzRZ39aZlNqlUzQlkuhDV
# 7zyofXGhXgaqT8fhvLufdf             4.0  3zh3U2eQ64EhBFbJuxgf1M
# 7zzhknA0A39TH81meuX7WA             4.0  3IW7ScrzXmPvZhB27hmfgy
#
#                                    artist_id_2             artist_id_3  \
# id
# 000RW47rhEkSqjgTrZx7YX                     NaN                     NaN
# 000xQL6tZNLJzIrtIgxqSl  2HPaUgqeutzr3jx5a9WyDV                     NaN
# 000xYdQfIZ4pDmBGzQalKU                     NaN                     NaN
# 001b8t3bYPfnabpjpfG1Y4                     NaN                     NaN
# 003VDDA7J3Xb2ZFlNx7nIZ  50co4Is1HCEo8bhOyUWKpn                     NaN
# ...                                        ...                     ...
# 7zxphfIdUMOfZOAVpKFlld                     NaN                     NaN
# 7zyYmIdjqqiX6kLryb7QBx                     NaN                     NaN
# 7zyZ9yPXIQebb79PrMghpV                     NaN                     NaN
# 7zyofXGhXgaqT8fhvLufdf  05qPtpcSltJZLI9sj0qm3B  4l0zTor5S32Yly4uw96Bto
# 7zzhknA0A39TH81meuX7WA                     NaN                     NaN
#
#                           artist_name_1  artist_name_2  artist_name_3  \
# id
# 000RW47rhEkSqjgTrZx7YX   Jorge & Mateus            NaN            NaN
# 000xQL6tZNLJzIrtIgxqSl             ZAYN  PARTYNEXTDOOR            NaN
# 000xYdQfIZ4pDmBGzQalKU     Luan Santana            NaN            NaN
# 001b8t3bYPfnabpjpfG1Y4         Josylvio            NaN            NaN
# 003VDDA7J3Xb2ZFlNx7nIZ     Trippie Redd     Young Thug            NaN
# ...                                 ...            ...            ...
# 7zxphfIdUMOfZOAVpKFlld               23            NaN            NaN
# 7zyYmIdjqqiX6kLryb7QBx        Eric Chou            NaN            NaN
# 7zyZ9yPXIQebb79PrMghpV    Pabllo Vittar            NaN            NaN
# 7zyofXGhXgaqT8fhvLufdf  Teflon Brothers         Spekti   Petri Nygård
# 7zzhknA0A39TH81meuX7WA              Jul            NaN            NaN
#
#                                                                    genres
# id
# 000RW47rhEkSqjgTrZx7YX      [arrocha, sertanejo, sertanejo universitario]
# 000xQL6tZNLJzIrtIgxqSl  [dance pop, pop, post-teen pop, uk pop, r&b, r...
# 000xYdQfIZ4pDmBGzQalKU  [arrocha, sertanejo, sertanejo pop, sertanejo ...
# 001b8t3bYPfnabpjpfG1Y4                                    [dutch hip hop]
# 003VDDA7J3Xb2ZFlNx7nIZ  [melodic rap, rap, trap, atl hip hop, atl trap...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  [swedish drill, swedish hip hop, swedish trap ...
# 7zyYmIdjqqiX6kLryb7QBx                                         [mandopop]
# 7zyZ9yPXIQebb79PrMghpV  [dance pop, funk carioca, funk pop, pop, pop l...
# 7zyofXGhXgaqT8fhvLufdf  [eurovision, finnish dance pop, finnish hip ho...
# 7zzhknA0A39TH81meuX7WA                         [francoton, rap marseille]
#
# [33881 rows x 31 columns]

# %%
charts = pd.read_csv(get_data_path("spotify_charts_cleaned.csv"), index_col="id", parse_dates=["date"], dtype={"region": "category"})
charts
# Out:
#                            region       date  rank   streams
# id
# 6mICuAdrwEjh6Y6lroV2Kg  Argentina 2017-01-01     1  253019.0
# 7DM4BPaS7uofFul3ywMe46  Argentina 2017-01-01     2  223988.0
# 3AEZUABDXNtecAOSC1qTfo  Argentina 2017-01-01     3  210943.0
# 6rQSrBHf7HlZjtcMZ4S4bO  Argentina 2017-01-01     4  173865.0
# 58IL315gMSTD37DOZPJ2hf  Argentina 2017-01-01     5  153956.0
# ...                           ...        ...   ...       ...
# 4aXicRG47bBEcKXlDaSRwW    Uruguay 2021-08-13    25   11431.0
# 43qcs9NpJhDxtG91zxFkj7    Uruguay 2021-08-13    27   10946.0
# 4M4DTyLupKvbJKlE4I4EYq    Uruguay 2021-08-13    33    9994.0
# 5jzEwSyyymBlf1fa1o39T2    Uruguay 2021-08-13    35    9251.0
# 5PjdY0CKGZdEuoNab3yDmX    Uruguay 2021-08-13    36    9179.0
#
# [4563816 rows x 4 columns]

# %%
track_charts = charts.join(tracks)
track_charts
# Out:
#                         region       date  rank   streams  explicit  \
# id
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-23    14  548706.0     False
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-24    14  714162.0     False
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-25    15  587405.0     False
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-26    17  386706.0     False
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-27    19  387562.0     False
# ...                        ...        ...   ...       ...       ...
# 7zzhknA0A39TH81meuX7WA  France 2019-12-08    34   95557.0      True
# 7zzhknA0A39TH81meuX7WA  France 2019-12-09    33  100571.0      True
# 7zzhknA0A39TH81meuX7WA  France 2019-12-10    36   95798.0      True
# 7zzhknA0A39TH81meuX7WA  France 2019-12-11    44   97717.0      True
# 7zzhknA0A39TH81meuX7WA  France 2019-12-12    45   93997.0      True
#
#                                      name  \
# id
# 000RW47rhEkSqjgTrZx7YX   Lance Individual
# 000RW47rhEkSqjgTrZx7YX   Lance Individual
# 000RW47rhEkSqjgTrZx7YX   Lance Individual
# 000RW47rhEkSqjgTrZx7YX   Lance Individual
# 000RW47rhEkSqjgTrZx7YX   Lance Individual
# ...                                   ...
# 7zzhknA0A39TH81meuX7WA  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  C'est pas des LOL
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# ...                                                                   ...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                        album_type                album_id album_release_date  \
# id
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# ...                           ...                     ...                ...
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
#
#                         ...    tempo duration_ms  time_signature  \
# id                      ...
# 000RW47rhEkSqjgTrZx7YX  ...  117.399    164459.0             4.0
# 000RW47rhEkSqjgTrZx7YX  ...  117.399    164459.0             4.0
# 000RW47rhEkSqjgTrZx7YX  ...  117.399    164459.0             4.0
# 000RW47rhEkSqjgTrZx7YX  ...  117.399    164459.0             4.0
# 000RW47rhEkSqjgTrZx7YX  ...  117.399    164459.0             4.0
# ...                     ...      ...         ...             ...
# 7zzhknA0A39TH81meuX7WA  ...  132.004    279467.0             4.0
# 7zzhknA0A39TH81meuX7WA  ...  132.004    279467.0             4.0
# 7zzhknA0A39TH81meuX7WA  ...  132.004    279467.0             4.0
# 7zzhknA0A39TH81meuX7WA  ...  132.004    279467.0             4.0
# 7zzhknA0A39TH81meuX7WA  ...  132.004    279467.0             4.0
#
#                                    artist_id_1 artist_id_2  artist_id_3  \
# id
# 000RW47rhEkSqjgTrZx7YX  1elUiq4X7pxej6FRlrEzjM         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX  1elUiq4X7pxej6FRlrEzjM         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX  1elUiq4X7pxej6FRlrEzjM         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX  1elUiq4X7pxej6FRlrEzjM         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX  1elUiq4X7pxej6FRlrEzjM         NaN          NaN
# ...                                        ...         ...          ...
# 7zzhknA0A39TH81meuX7WA  3IW7ScrzXmPvZhB27hmfgy         NaN          NaN
# 7zzhknA0A39TH81meuX7WA  3IW7ScrzXmPvZhB27hmfgy         NaN          NaN
# 7zzhknA0A39TH81meuX7WA  3IW7ScrzXmPvZhB27hmfgy         NaN          NaN
# 7zzhknA0A39TH81meuX7WA  3IW7ScrzXmPvZhB27hmfgy         NaN          NaN
# 7zzhknA0A39TH81meuX7WA  3IW7ScrzXmPvZhB27hmfgy         NaN          NaN
#
#                          artist_name_1  artist_name_2  artist_name_3  \
# id
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus            NaN            NaN
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus            NaN            NaN
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus            NaN            NaN
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus            NaN            NaN
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus            NaN            NaN
# ...                                ...            ...            ...
# 7zzhknA0A39TH81meuX7WA             Jul            NaN            NaN
# 7zzhknA0A39TH81meuX7WA             Jul            NaN            NaN
# 7zzhknA0A39TH81meuX7WA             Jul            NaN            NaN
# 7zzhknA0A39TH81meuX7WA             Jul            NaN            NaN
# 7zzhknA0A39TH81meuX7WA             Jul            NaN            NaN
#
#                                                                genres
# id
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# ...                                                               ...
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
#
# [4563816 rows x 35 columns]

# %%
columns_to_move = ["name", "artist_name_1", "artist_name_2", "artist_name_3"]
for col_name in reversed(columns_to_move):
  col = track_charts.pop(col_name)
  track_charts.insert(3, col_name, col)

# %%
track_charts
# Out:
#                         region       date  rank               name  \
# id
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-23    14   Lance Individual
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-24    14   Lance Individual
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-25    15   Lance Individual
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-26    17   Lance Individual
# 000RW47rhEkSqjgTrZx7YX  Brazil 2021-04-27    19   Lance Individual
# ...                        ...        ...   ...                ...
# 7zzhknA0A39TH81meuX7WA  France 2019-12-08    34  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  France 2019-12-09    33  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  France 2019-12-10    36  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  France 2019-12-11    44  C'est pas des LOL
# 7zzhknA0A39TH81meuX7WA  France 2019-12-12    45  C'est pas des LOL
#
#                          artist_name_1 artist_name_2 artist_name_3   streams  \
# id
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus           NaN           NaN  548706.0
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus           NaN           NaN  714162.0
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus           NaN           NaN  587405.0
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus           NaN           NaN  386706.0
# 000RW47rhEkSqjgTrZx7YX  Jorge & Mateus           NaN           NaN  387562.0
# ...                                ...           ...           ...       ...
# 7zzhknA0A39TH81meuX7WA             Jul           NaN           NaN   95557.0
# 7zzhknA0A39TH81meuX7WA             Jul           NaN           NaN  100571.0
# 7zzhknA0A39TH81meuX7WA             Jul           NaN           NaN   95798.0
# 7zzhknA0A39TH81meuX7WA             Jul           NaN           NaN   97717.0
# 7zzhknA0A39TH81meuX7WA             Jul           NaN           NaN   93997.0
#
#                         explicit  \
# id
# 000RW47rhEkSqjgTrZx7YX     False
# 000RW47rhEkSqjgTrZx7YX     False
# 000RW47rhEkSqjgTrZx7YX     False
# 000RW47rhEkSqjgTrZx7YX     False
# 000RW47rhEkSqjgTrZx7YX     False
# ...                          ...
# 7zzhknA0A39TH81meuX7WA      True
# 7zzhknA0A39TH81meuX7WA      True
# 7zzhknA0A39TH81meuX7WA      True
# 7zzhknA0A39TH81meuX7WA      True
# 7zzhknA0A39TH81meuX7WA      True
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# ...                                                                   ...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                         ... instrumentalness liveness valence    tempo  \
# id                      ...
# 000RW47rhEkSqjgTrZx7YX  ...              0.0    0.075   0.962  117.399
# 000RW47rhEkSqjgTrZx7YX  ...              0.0    0.075   0.962  117.399
# 000RW47rhEkSqjgTrZx7YX  ...              0.0    0.075   0.962  117.399
# 000RW47rhEkSqjgTrZx7YX  ...              0.0    0.075   0.962  117.399
# 000RW47rhEkSqjgTrZx7YX  ...              0.0    0.075   0.962  117.399
# ...                     ...              ...      ...     ...      ...
# 7zzhknA0A39TH81meuX7WA  ...              0.0    0.094   0.886  132.004
# 7zzhknA0A39TH81meuX7WA  ...              0.0    0.094   0.886  132.004
# 7zzhknA0A39TH81meuX7WA  ...              0.0    0.094   0.886  132.004
# 7zzhknA0A39TH81meuX7WA  ...              0.0    0.094   0.886  132.004
# 7zzhknA0A39TH81meuX7WA  ...              0.0    0.094   0.886  132.004
#
#                        duration_ms  time_signature             artist_id_1  \
# id
# 000RW47rhEkSqjgTrZx7YX    164459.0             4.0  1elUiq4X7pxej6FRlrEzjM
# 000RW47rhEkSqjgTrZx7YX    164459.0             4.0  1elUiq4X7pxej6FRlrEzjM
# 000RW47rhEkSqjgTrZx7YX    164459.0             4.0  1elUiq4X7pxej6FRlrEzjM
# 000RW47rhEkSqjgTrZx7YX    164459.0             4.0  1elUiq4X7pxej6FRlrEzjM
# 000RW47rhEkSqjgTrZx7YX    164459.0             4.0  1elUiq4X7pxej6FRlrEzjM
# ...                            ...             ...                     ...
# 7zzhknA0A39TH81meuX7WA    279467.0             4.0  3IW7ScrzXmPvZhB27hmfgy
# 7zzhknA0A39TH81meuX7WA    279467.0             4.0  3IW7ScrzXmPvZhB27hmfgy
# 7zzhknA0A39TH81meuX7WA    279467.0             4.0  3IW7ScrzXmPvZhB27hmfgy
# 7zzhknA0A39TH81meuX7WA    279467.0             4.0  3IW7ScrzXmPvZhB27hmfgy
# 7zzhknA0A39TH81meuX7WA    279467.0             4.0  3IW7ScrzXmPvZhB27hmfgy
#
#                        artist_id_2  artist_id_3  \
# id
# 000RW47rhEkSqjgTrZx7YX         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX         NaN          NaN
# 000RW47rhEkSqjgTrZx7YX         NaN          NaN
# ...                            ...          ...
# 7zzhknA0A39TH81meuX7WA         NaN          NaN
# 7zzhknA0A39TH81meuX7WA         NaN          NaN
# 7zzhknA0A39TH81meuX7WA         NaN          NaN
# 7zzhknA0A39TH81meuX7WA         NaN          NaN
# 7zzhknA0A39TH81meuX7WA         NaN          NaN
#
#                                                                genres
# id
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# 000RW47rhEkSqjgTrZx7YX  [arrocha, sertanejo, sertanejo universitario]
# ...                                                               ...
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
# 7zzhknA0A39TH81meuX7WA                     [francoton, rap marseille]
#
# [4563816 rows x 35 columns]

# %%
track_charts = track_charts.sort_values(["date", "region", "rank"])

# %% [markdown]
# ## Exporting data?

# %% [markdown]
# We could in theory export the data. However, the dataset becomes HUGE (2 GB). This is probably too much for practical applications, especially if the data should be made available via an interactive website.

# %%
#track_charts.to_csv(create_data_out_path("track_charts.csv"))

# %% [markdown]
# ## Checking completeness of data

# %% [markdown]
# Ideally, we should have 50 entries per day for every region. This means that if we look at the value counts per region, we should ideally come close to:

# %%
ideal_value_count = 50 * 365 * 5 # top 50 for every day, across 5 years
ideal_value_count
# Out:
# 91250

# %%
track_charts.region.value_counts()
# Out:
# Italy                 91297
# Finland               91296
# United Kingdom        91295
# Denmark               91295
# United States         91294
# Norway                91294
# Philippines           91294
# France                91294
# Hungary               91293
# Hong Kong             91293
# Taiwan                91293
# Indonesia             91292
# Malaysia              91292
# Netherlands           91292
# New Zealand           91292
# Ecuador               91292
# Poland                91292
# Ireland               91292
# Singapore             91292
# Sweden                91292
# Chile                 91292
# Canada                91292
# Turkey                91292
# Belgium               91292
# Australia             91292
# Portugal              91291
# Argentina             91291
# Guatemala             91291
# Bolivia               91291
# Czech Republic        91291
# Mexico                91290
# Colombia              91290
# Japan                 91290
# Dominican Republic    91290
# Costa Rica            91289
# Honduras              91289
# Paraguay              91288
# Peru                  91288
# Global                91286
# Panama                91286
# Uruguay               91285
# El Salvador           91281
# Iceland               91280
# Brazil                91276
# Greece                91276
# Spain                 91271
# Switzerland           91222
# Austria               91181
# Germany               91097
# Slovakia              90980
# Name: region, dtype: int64

# %%
track_charts.region.value_counts().min() / ideal_value_count
# Out:
# 0.997041095890411

# %% [markdown]
# Even for the region with the weakest data coverage, we have 99.7% of the data. Nice!

# %% [markdown]
# What do the track counts look like per region and date?

# %%
track_counts_per_region_and_date = track_charts.reset_index().groupby(["region", "date"]).id.count().rename("track_count")
track_counts_per_region_and_date.groupby("region").describe()
# Out:
#                      count       mean       std   min   25%   50%   75%   max
# region
# Argentina           1826.0  49.995071  0.070051  49.0  50.0  50.0  50.0  50.0
# Australia           1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Austria             1826.0  49.934830  0.896032  33.0  50.0  50.0  50.0  50.0
# Belgium             1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Bolivia             1826.0  49.995071  0.077480  48.0  50.0  50.0  50.0  50.0
# Brazil              1826.0  49.986857  0.123165  48.0  50.0  50.0  50.0  50.0
# Canada              1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Chile               1826.0  49.995619  0.066063  49.0  50.0  50.0  50.0  50.0
# Colombia            1826.0  49.994524  0.087414  48.0  50.0  50.0  50.0  50.0
# Costa Rica          1826.0  49.993976  0.101856  47.0  50.0  50.0  50.0  50.0
# Czech Republic      1826.0  49.995071  0.134380  46.0  50.0  50.0  50.0  50.0
# Denmark             1826.0  49.997262  0.070171  48.0  50.0  50.0  50.0  50.0
# Dominican Republic  1826.0  49.994524  0.080903  48.0  50.0  50.0  50.0  50.0
# Ecuador             1826.0  49.995619  0.066063  49.0  50.0  50.0  50.0  50.0
# El Salvador         1826.0  49.989595  0.153145  46.0  50.0  50.0  50.0  50.0
# Finland             1826.0  49.997809  0.066172  48.0  50.0  50.0  50.0  50.0
# France              1826.0  49.996714  0.099258  47.0  50.0  50.0  50.0  50.0
# Germany             1826.0  49.888828  1.169576  33.0  50.0  50.0  50.0  50.0
# Global              1826.0  49.992333  0.144094  46.0  50.0  50.0  50.0  50.0
# Greece              1826.0  49.986857  0.304923  39.0  50.0  50.0  50.0  50.0
# Guatemala           1826.0  49.995071  0.077480  48.0  50.0  50.0  50.0  50.0
# Honduras            1826.0  49.993976  0.101856  47.0  50.0  50.0  50.0  50.0
# Hong Kong           1826.0  49.996166  0.116978  46.0  50.0  50.0  50.0  50.0
# Hungary             1826.0  49.996166  0.116978  46.0  50.0  50.0  50.0  50.0
# Iceland             1826.0  49.989047  0.320770  37.0  50.0  50.0  50.0  50.0
# Indonesia           1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Ireland             1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Italy               1826.0  49.998357  0.052317  48.0  50.0  50.0  50.0  50.0
# Japan               1826.0  49.994524  0.136382  46.0  50.0  50.0  50.0  50.0
# Malaysia            1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Mexico              1826.0  49.994524  0.087414  48.0  50.0  50.0  50.0  50.0
# Netherlands         1826.0  49.995619  0.080970  48.0  50.0  50.0  50.0  50.0
# New Zealand         1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Norway              1826.0  49.996714  0.099258  47.0  50.0  50.0  50.0  50.0
# Panama              1826.0  49.992333  0.099016  48.0  50.0  50.0  50.0  50.0
# Paraguay            1826.0  49.993428  0.080822  49.0  50.0  50.0  50.0  50.0
# Peru                1826.0  49.993428  0.080822  49.0  50.0  50.0  50.0  50.0
# Philippines         1826.0  49.996714  0.099258  47.0  50.0  50.0  50.0  50.0
# Poland              1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Portugal            1826.0  49.995071  0.121533  46.0  50.0  50.0  50.0  50.0
# Singapore           1826.0  49.995619  0.132344  46.0  50.0  50.0  50.0  50.0
# Slovakia            1826.0  49.824754  1.304979  19.0  50.0  50.0  50.0  50.0
# Spain               1826.0  49.984118  0.133528  48.0  50.0  50.0  50.0  50.0
# Sweden              1826.0  49.995619  0.104593  47.0  50.0  50.0  50.0  50.0
# Switzerland         1826.0  49.957284  0.616960  34.0  50.0  50.0  50.0  50.0
# Taiwan              1826.0  49.996166  0.116978  46.0  50.0  50.0  50.0  50.0
# Turkey              1826.0  49.995619  0.104593  47.0  50.0  50.0  50.0  50.0
# United Kingdom      1826.0  49.997262  0.084355  47.0  50.0  50.0  50.0  50.0
# United States       1826.0  49.996714  0.099258  47.0  50.0  50.0  50.0  50.0
# Uruguay             1826.0  49.991785  0.101703  48.0  50.0  50.0  50.0  50.0

# %% [markdown]
# Let's look at the minimum value in more detail:

# %%
min_idx = track_counts_per_region_and_date.idxmin()
min_idx
# Out:
# ('Slovakia', Timestamp('2017-01-01 00:00:00'))

# %%
track_counts_per_region_and_date[min_idx]
# Out:
# 19

# %% [markdown]
# When looking at the [Spotify Charts page for Slovakia for January 1, 2017](https://charts.spotify.com/charts/view/regional-sk-daily/2017-01-01) (need to log in as Spotify user to view this page), we find out that there are indeed only 19 songs available. So, Spotify must have messed something up here. I am pretty sure that the other values were all derived from the official Spotify charts page, so there's really nothing we can do to get that missing data.

# %% [markdown]
# You might be confused about the counts: shouldn't they be

# %%
365 * 5
# Out:
# 1825

# %% [markdown]
# No! Remember that every fourth year is a leap year. The last one was 2020. So, everything's fine!

# %%
track_counts_per_region_and_date.reset_index().date.max()
# Out:
# Timestamp('2021-12-31 00:00:00')

# %% [markdown]
# Let's try to plot the data as well:

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

track_counts_by_region_pivot = track_counts_per_region_and_date.reset_index().pivot(
    columns=["region"], index="date", values="track_count"
)

plt.figure(figsize=(16, 16))
min_date = mdates.date2num(track_counts_by_region_pivot.index.min())
max_date = mdates.date2num(track_counts_by_region_pivot.index.max())

plt.xticks(ticks=list(range(len(track_counts_by_region_pivot.columns))), labels=track_counts_by_region_pivot.columns, rotation=90)

y_axis = plt.gca().yaxis
y_axis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
y_axis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
y_axis.set_major_locator(mdates.MonthLocator())

plt.imshow(
    track_counts_by_region_pivot,
    aspect="auto",
    extent=[0, 50, max_date, min_date],
    cmap="Greys",
    interpolation="none",
)
plt.show()

# %% [markdown]
# We can also check for completeness by looking at the date column and comparing it with a daily date index from 2017 to 2022:

# %%
five_years = pd.date_range("2017-01-01", "2021-12-31")
missing_dates = five_years.difference(track_charts.set_index("date").index)
missing_dates
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Checking completeness of data by region

# %% [markdown]
# Let's do that for every region:

# %%
def get_missing_dates(date_col):
  return len(five_years.difference(date_col))

missing_dates_across_all_regions = track_charts.groupby(["region"]).date.apply(get_missing_dates).sum()
missing_dates_across_all_regions
# Out:
# 0

# %% [markdown]
# We have some data for every day. What a relief!

# %% [markdown]
# ## Exploring the Data

# %%
global_charts = track_charts[track_charts.region == "Global"].drop(columns="region")
global_charts
# Out:
#                              date  rank  \
# id
# 5aAx2yezTd8zXrkmtKl66Z 2017-01-01     1
# 7BKLCZ1jbUBVqRi2FVlTVw 2017-01-01     2
# 4pdPtRcBmOSQDlJ3Fk945m 2017-01-01     3
# 5knuzwU65gJK7IF5yJsuaW 2017-01-01     4
# 1xznGGDReH1oQq0xzbwXa3 2017-01-01     5
# ...                           ...   ...
# 1c4htMHiolERc0YJvZNdlc 2021-12-31    46
# 4gvrJnKCKIPiacNsWVQwEU 2021-12-31    47
# 5wANPM4fQCJwkGd4rN57mH 2021-12-31    48
# 4RVwu0g32PAqgUiJoXsdF8 2021-12-31    49
# 2vmfvSoZBFAt9hhRoEByLi 2021-12-31    50
#
#                                                                 name  \
# id
# 5aAx2yezTd8zXrkmtKl66Z                                       Starboy
# 7BKLCZ1jbUBVqRi2FVlTVw                                        Closer
# 4pdPtRcBmOSQDlJ3Fk945m                               Let Me Love You
# 5knuzwU65gJK7IF5yJsuaW       Rockabye (feat. Sean Paul & Anne-Marie)
# 1xznGGDReH1oQq0xzbwXa3                                     One Dance
# ...                                                              ...
# 1c4htMHiolERc0YJvZNdlc                           Vai Lá Em Casa Hoje
# 4gvrJnKCKIPiacNsWVQwEU  love nwantiti (feat. Dj Yo! & AX'EL) - Remix
# 5wANPM4fQCJwkGd4rN57mH                               drivers license
# 4RVwu0g32PAqgUiJoXsdF8                             Happier Than Ever
# 2vmfvSoZBFAt9hhRoEByLi                                         Volví
#
#                                     artist_name_1     artist_name_2  \
# id
# 5aAx2yezTd8zXrkmtKl66Z                 The Weeknd         Daft Punk
# 7BKLCZ1jbUBVqRi2FVlTVw           The Chainsmokers            Halsey
# 4pdPtRcBmOSQDlJ3Fk945m                   DJ Snake     Justin Bieber
# 5knuzwU65gJK7IF5yJsuaW               Clean Bandit         Sean Paul
# 1xznGGDReH1oQq0xzbwXa3                      Drake            Wizkid
# ...                                           ...               ...
# 1c4htMHiolERc0YJvZNdlc  George Henrique & Rodrigo  Marília Mendonça
# 4gvrJnKCKIPiacNsWVQwEU                       CKay            Dj Yo!
# 5wANPM4fQCJwkGd4rN57mH             Olivia Rodrigo               NaN
# 4RVwu0g32PAqgUiJoXsdF8              Billie Eilish               NaN
# 2vmfvSoZBFAt9hhRoEByLi                   Aventura         Bad Bunny
#
#                        artist_name_3    streams  explicit  \
# id
# 5aAx2yezTd8zXrkmtKl66Z           NaN  3135625.0      True
# 7BKLCZ1jbUBVqRi2FVlTVw           NaN  3015525.0     False
# 4pdPtRcBmOSQDlJ3Fk945m           NaN  2545384.0     False
# 5knuzwU65gJK7IF5yJsuaW    Anne-Marie  2356604.0     False
# 1xznGGDReH1oQq0xzbwXa3          Kyla  2259887.0     False
# ...                              ...        ...       ...
# 1c4htMHiolERc0YJvZNdlc           NaN  1680296.0     False
# 4gvrJnKCKIPiacNsWVQwEU         AX'EL  1675604.0     False
# 5wANPM4fQCJwkGd4rN57mH           NaN  1674396.0      True
# 4RVwu0g32PAqgUiJoXsdF8           NaN  1653920.0      True
# 2vmfvSoZBFAt9hhRoEByLi           NaN  1635068.0      True
#
#                                                               preview_url  \
# id
# 5aAx2yezTd8zXrkmtKl66Z                                                NaN
# 7BKLCZ1jbUBVqRi2FVlTVw  https://p.scdn.co/mp3-preview/aacaac1614505dbb...
# 4pdPtRcBmOSQDlJ3Fk945m                                                NaN
# 5knuzwU65gJK7IF5yJsuaW  https://p.scdn.co/mp3-preview/afb53fb7e8ae5f5f...
# 1xznGGDReH1oQq0xzbwXa3                                                NaN
# ...                                                                   ...
# 1c4htMHiolERc0YJvZNdlc                                                NaN
# 4gvrJnKCKIPiacNsWVQwEU  https://p.scdn.co/mp3-preview/165d7571df628c2c...
# 5wANPM4fQCJwkGd4rN57mH  https://p.scdn.co/mp3-preview/3a145991602f4a73...
# 4RVwu0g32PAqgUiJoXsdF8  https://p.scdn.co/mp3-preview/20a10ed1ec5ad226...
# 2vmfvSoZBFAt9hhRoEByLi  https://p.scdn.co/mp3-preview/e1b8dd8e6f703ba1...
#
#                        album_type  ... instrumentalness liveness valence  \
# id                                 ...
# 5aAx2yezTd8zXrkmtKl66Z      album  ...         0.000003   0.1340   0.535
# 7BKLCZ1jbUBVqRi2FVlTVw     single  ...         0.000000   0.1110   0.661
# 4pdPtRcBmOSQDlJ3Fk945m      album  ...         0.000010   0.1220   0.142
# 5knuzwU65gJK7IF5yJsuaW     single  ...         0.000000   0.1800   0.742
# 1xznGGDReH1oQq0xzbwXa3      album  ...         0.004230   0.3510   0.371
# ...                           ...  ...              ...      ...     ...
# 1c4htMHiolERc0YJvZNdlc     single  ...         0.000000   0.9680   0.619
# 4gvrJnKCKIPiacNsWVQwEU     single  ...         0.093800   0.0549   0.443
# 5wANPM4fQCJwkGd4rN57mH      album  ...         0.000014   0.1060   0.137
# 4RVwu0g32PAqgUiJoXsdF8      album  ...         0.003490   0.1280   0.297
# 2vmfvSoZBFAt9hhRoEByLi     single  ...         0.000284   0.0674   0.791
#
#                           tempo  duration_ms time_signature  \
# id
# 5aAx2yezTd8zXrkmtKl66Z  186.054     230453.0            4.0
# 7BKLCZ1jbUBVqRi2FVlTVw   95.010     244960.0            4.0
# 4pdPtRcBmOSQDlJ3Fk945m  199.864     205947.0            4.0
# 5knuzwU65gJK7IF5yJsuaW  101.965     251088.0            4.0
# 1xznGGDReH1oQq0xzbwXa3  103.989     173987.0            4.0
# ...                         ...          ...            ...
# 1c4htMHiolERc0YJvZNdlc  157.628     191524.0            4.0
# 4gvrJnKCKIPiacNsWVQwEU  119.900     188369.0            3.0
# 5wANPM4fQCJwkGd4rN57mH  143.875     242013.0            4.0
# 4RVwu0g32PAqgUiJoXsdF8   81.055     298899.0            3.0
# 2vmfvSoZBFAt9hhRoEByLi  175.896     230125.0            4.0
#
#                                    artist_id_1             artist_id_2  \
# id
# 5aAx2yezTd8zXrkmtKl66Z  1Xyo4u8uXC1ZmMpatF05PJ  4tZwfgrHOc3mvqYlEYSvVi
# 7BKLCZ1jbUBVqRi2FVlTVw  69GGBxA162lTqCwzJG5jLp  26VFTg2z8YR0cCuwLzESi2
# 4pdPtRcBmOSQDlJ3Fk945m  540vIaP2JwjQb9dm3aArA4  1uNFoZAHBGtllmzznpCI3s
# 5knuzwU65gJK7IF5yJsuaW  6MDME20pz9RveH9rEXvrOM  3Isy6kedDrgPYoTS1dazA9
# 1xznGGDReH1oQq0xzbwXa3  3TVXtAsR1Inumwj472S9r4  3tVQdUvClmAT7URs9V3rsp
# ...                                        ...                     ...
# 1c4htMHiolERc0YJvZNdlc  3FlCKtwOEYQQYyGVEbxG2Z  1yR65psqiazQpeM79CcGh8
# 4gvrJnKCKIPiacNsWVQwEU  048LktY5zMnakWq7PTtFrz  7iTLGcddv1bOPirdYJjKVy
# 5wANPM4fQCJwkGd4rN57mH  1McMsnEElThX1knmY4oliG                     NaN
# 4RVwu0g32PAqgUiJoXsdF8  6qqNVTkY8uBg9cP3Jd7DAH                     NaN
# 2vmfvSoZBFAt9hhRoEByLi  1qto4hHid1P71emI6Fd8xi  4q3ewBCX7sLwd24euuV69X
#
#                                    artist_id_3  \
# id
# 5aAx2yezTd8zXrkmtKl66Z                     NaN
# 7BKLCZ1jbUBVqRi2FVlTVw                     NaN
# 4pdPtRcBmOSQDlJ3Fk945m                     NaN
# 5knuzwU65gJK7IF5yJsuaW  1zNqDE7qDGCsyzJwohVaoX
# 1xznGGDReH1oQq0xzbwXa3  77DAFfvm3O9zT5dIoG0eIO
# ...                                        ...
# 1c4htMHiolERc0YJvZNdlc                     NaN
# 4gvrJnKCKIPiacNsWVQwEU  5fUXK5m3BNwoRgTyKq8tnz
# 5wANPM4fQCJwkGd4rN57mH                     NaN
# 4RVwu0g32PAqgUiJoXsdF8                     NaN
# 2vmfvSoZBFAt9hhRoEByLi                     NaN
#
#                                                                    genres
# id
# 5aAx2yezTd8zXrkmtKl66Z  [canadian contemporary r&b, canadian pop, pop,...
# 7BKLCZ1jbUBVqRi2FVlTVw  [dance pop, edm, electropop, pop, pop dance, t...
# 4pdPtRcBmOSQDlJ3Fk945m  [dance pop, edm, electronic trap, pop, pop dan...
# 5knuzwU65gJK7IF5yJsuaW  [dance pop, edm, pop, pop dance, post-teen pop...
# 1xznGGDReH1oQq0xzbwXa3  [canadian hip hop, canadian pop, hip hop, rap,...
# ...                                                                   ...
# 1c4htMHiolERc0YJvZNdlc  [arrocha, sertanejo, sertanejo pop, sertanejo ...
# 4gvrJnKCKIPiacNsWVQwEU                                         [afro r&b]
# 5wANPM4fQCJwkGd4rN57mH                                              [pop]
# 4RVwu0g32PAqgUiJoXsdF8                         [art pop, electropop, pop]
# 2vmfvSoZBFAt9hhRoEByLi  [bachata, bachata dominicana, latin hip hop, l...
#
# [91286 rows x 34 columns]

# %%
countries_charts = track_charts[track_charts.region != "Global"].copy()
countries_charts.region = countries_charts.region.cat.remove_unused_categories()
countries_charts
# Out:
#                            region       date  rank  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  Argentina 2017-01-01     1
# 7DM4BPaS7uofFul3ywMe46  Argentina 2017-01-01     2
# 3AEZUABDXNtecAOSC1qTfo  Argentina 2017-01-01     3
# 6rQSrBHf7HlZjtcMZ4S4bO  Argentina 2017-01-01     4
# 58IL315gMSTD37DOZPJ2hf  Argentina 2017-01-01     5
# ...                           ...        ...   ...
# 7iXJg4IUyrWont5YSQrbKP    Uruguay 2021-12-31    46
# 0XYZhJIcwKNjd0tjbSXwaQ    Uruguay 2021-12-31    47
# 39yyHtQ4tkjZzd8TfIBKQw    Uruguay 2021-12-31    48
# 5eyO0n1HiiSWdGaaSoK731    Uruguay 2021-12-31    49
# 4bF2y8rR7GUjrd5LNEvej3    Uruguay 2021-12-31    50
#
#                                                        name artist_name_1  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg              Chantaje (feat. Maluma)       Shakira
# 7DM4BPaS7uofFul3ywMe46          Vente Pa' Ca (feat. Maluma)  Ricky Martin
# 3AEZUABDXNtecAOSC1qTfo           Reggaetón Lento (Bailemos)          CNCO
# 6rQSrBHf7HlZjtcMZ4S4bO                               Safari      J Balvin
# 58IL315gMSTD37DOZPJ2hf                          Shaky Shaky  Daddy Yankee
# ...                                                     ...           ...
# 7iXJg4IUyrWont5YSQrbKP                           Los Tragos          Reik
# 0XYZhJIcwKNjd0tjbSXwaQ                                 Sabe  Nicki Nicole
# 39yyHtQ4tkjZzd8TfIBKQw  Morad: Bzrp Music Sessions, Vol. 47      Bizarrap
# 5eyO0n1HiiSWdGaaSoK731                           2:50 Remix           MYA
# 4bF2y8rR7GUjrd5LNEvej3                               París      Ingratax
#
#                             artist_name_2 artist_name_3   streams  explicit  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg             Maluma           NaN  253019.0     False
# 7DM4BPaS7uofFul3ywMe46             Maluma           NaN  223988.0     False
# 3AEZUABDXNtecAOSC1qTfo                NaN           NaN  210943.0     False
# 6rQSrBHf7HlZjtcMZ4S4bO  Pharrell Williams           BIA  173865.0     False
# 58IL315gMSTD37DOZPJ2hf                NaN           NaN  153956.0     False
# ...                                   ...           ...       ...       ...
# 7iXJg4IUyrWont5YSQrbKP      Maria Becerra           NaN   10707.0     False
# 0XYZhJIcwKNjd0tjbSXwaQ     Rauw Alejandro           NaN   10635.0     False
# 39yyHtQ4tkjZzd8TfIBKQw              Morad           NaN   10491.0     False
# 5eyO0n1HiiSWdGaaSoK731               TINI          Duki   10388.0     False
# 4bF2y8rR7GUjrd5LNEvej3                NaN           NaN   10137.0     False
#
#                                                               preview_url  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  https://p.scdn.co/mp3-preview/b7a66b261ebbe2aa...
# 7DM4BPaS7uofFul3ywMe46  https://p.scdn.co/mp3-preview/21e38a8983daf1c3...
# 3AEZUABDXNtecAOSC1qTfo  https://p.scdn.co/mp3-preview/ced5c17cadb43603...
# 6rQSrBHf7HlZjtcMZ4S4bO                                                NaN
# 58IL315gMSTD37DOZPJ2hf                                                NaN
# ...                                                                   ...
# 7iXJg4IUyrWont5YSQrbKP  https://p.scdn.co/mp3-preview/0ac0ba472608a3f8...
# 0XYZhJIcwKNjd0tjbSXwaQ  https://p.scdn.co/mp3-preview/87d78407ee48bdda...
# 39yyHtQ4tkjZzd8TfIBKQw  https://p.scdn.co/mp3-preview/61d9340a0dc75302...
# 5eyO0n1HiiSWdGaaSoK731  https://p.scdn.co/mp3-preview/53aa65dfb6356b71...
# 4bF2y8rR7GUjrd5LNEvej3  https://p.scdn.co/mp3-preview/33562d290b78f802...
#
#                         ... instrumentalness liveness valence    tempo  \
# id                      ...
# 6mICuAdrwEjh6Y6lroV2Kg  ...         0.000030   0.1590   0.907  102.034
# 7DM4BPaS7uofFul3ywMe46  ...         0.000017   0.1010   0.533   99.935
# 3AEZUABDXNtecAOSC1qTfo  ...         0.000000   0.1760   0.710   93.974
# 6rQSrBHf7HlZjtcMZ4S4bO  ...         0.000003   0.1260   0.555  180.044
# 58IL315gMSTD37DOZPJ2hf  ...         0.000000   0.0631   0.873   88.007
# ...                     ...              ...      ...     ...      ...
# 7iXJg4IUyrWont5YSQrbKP  ...         0.000001   0.1610   0.681   93.900
# 0XYZhJIcwKNjd0tjbSXwaQ  ...         0.000000   0.1720   0.767   93.063
# 39yyHtQ4tkjZzd8TfIBKQw  ...         0.003390   0.1030   0.548  122.042
# 5eyO0n1HiiSWdGaaSoK731  ...         0.000000   0.2300   0.836  139.969
# 4bF2y8rR7GUjrd5LNEvej3  ...         0.000746   0.0654   0.399  167.933
#
#                        duration_ms  time_signature             artist_id_1  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg    195840.0             4.0  0EmeFodog0BfCgMzAIvKQp
# 7DM4BPaS7uofFul3ywMe46    259196.0             4.0  7slfeZO9LsJbWgpkIoXBUJ
# 3AEZUABDXNtecAOSC1qTfo    222560.0             4.0  0eecdvMrqBftK0M1VKhaF4
# 6rQSrBHf7HlZjtcMZ4S4bO    205600.0             4.0  1vyhD5VmyZ7KMfW5gqLgo5
# 58IL315gMSTD37DOZPJ2hf    234320.0             4.0  4VMYDCV2IEDYJArk749S6m
# ...                            ...             ...                     ...
# 7iXJg4IUyrWont5YSQrbKP    171001.0             4.0  0vR2qb8m9WHeZ5ByCbimq2
# 0XYZhJIcwKNjd0tjbSXwaQ    177656.0             4.0  2UZIAOlrnyZmyzt1nuXr9y
# 39yyHtQ4tkjZzd8TfIBKQw    177583.0             4.0  716NhGYqD1jl2wI1Qkgq36
# 5eyO0n1HiiSWdGaaSoK731    231708.0             4.0  5Rj6rNR8zIlUUDCs1OyPmW
# 4bF2y8rR7GUjrd5LNEvej3    151429.0             4.0  62YF0FglEltB3CnVIjoko8
#
#                                    artist_id_2             artist_id_3  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  1r4hJ1h58CWwUQe3MxPuau                     NaN
# 7DM4BPaS7uofFul3ywMe46  1r4hJ1h58CWwUQe3MxPuau                     NaN
# 3AEZUABDXNtecAOSC1qTfo                     NaN                     NaN
# 6rQSrBHf7HlZjtcMZ4S4bO  2RdwBSPQiwcmiDo9kixcl8  6veh5zbFpm31XsPdjBgPER
# 58IL315gMSTD37DOZPJ2hf                     NaN                     NaN
# ...                                        ...                     ...
# 7iXJg4IUyrWont5YSQrbKP  1DxLCyH42yaHKGK3cl5bvG                     NaN
# 0XYZhJIcwKNjd0tjbSXwaQ  1mcTU81TzQhprhouKaTkpq                     NaN
# 39yyHtQ4tkjZzd8TfIBKQw  4az97MtWmBQ5Db3GfDh9j9                     NaN
# 5eyO0n1HiiSWdGaaSoK731  7vXDAI8JwjW531ouMGbfcp  1bAftSH8umNcGZ0uyV7LMg
# 4bF2y8rR7GUjrd5LNEvej3                     NaN                     NaN
#
#                                                                    genres
# id
# 6mICuAdrwEjh6Y6lroV2Kg  [colombian pop, dance pop, latin pop, reggaeto...
# 7DM4BPaS7uofFul3ywMe46  [dance pop, latin pop, mexican pop, puerto ric...
# 3AEZUABDXNtecAOSC1qTfo                   [boy band, latin pop, reggaeton]
# 6rQSrBHf7HlZjtcMZ4S4bO  [reggaeton, reggaeton colombiano, trap latino,...
# 58IL315gMSTD37DOZPJ2hf            [latin hip hop, reggaeton, trap latino]
# ...                                                                   ...
# 7iXJg4IUyrWont5YSQrbKP  [latin arena pop, latin pop, mexican pop, pop ...
# 0XYZhJIcwKNjd0tjbSXwaQ  [argentine hip hop, r&b argentino, trap argent...
# 39yyHtQ4tkjZzd8TfIBKQw  [argentine hip hop, pop venezolano, trap argen...
# 5eyO0n1HiiSWdGaaSoK731  [latin pop, pop argentino, argentine hip hop, ...
# 4bF2y8rR7GUjrd5LNEvej3                   [concurso de talentos argentino]
#
# [4472530 rows x 35 columns]

# %% [markdown]
# ### Identifying the songs that reached number 1 in most countries

# %%
number_ones = (
    countries_charts[countries_charts["rank"] == 1]
    .reset_index()
    .drop_duplicates(subset=["id", "region"])
    .groupby(["id", "name", "artist_name_1"])
    .region.count()
    .sort_values(ascending=False)
)
number_ones[:10]
# Out:
# id                      name                                artist_name_1
# 4aWmUDTfIPGksMNLV2rQP2  Despacito (Featuring Daddy Yankee)  Luis Fonsi       49
# 5CtI0qwDJkDQGwXD1H1cLb  Despacito - Remix                   Luis Fonsi       46
# 7qiZfU4dY1lWllzX7mPBI3  Shape of You                        Ed Sheeran       35
# 0bYg9bo50gSsH3LtXe2SQn  All I Want for Christmas Is You     Mariah Carey     32
# 2G7V7zsVDxg1yRsu7Ew9RJ  In My Feelings                      Drake            31
# 0gplL1WMoJ6iYaPgMCL0gX  Easy On Me                          Adele            30
# 0TK2YIli7K1leLovkQiNik  Señorita                            Shawn Mendes     27
# 1rgnBhdG2JDFTbYkYRZAku  Dance Monkey                        Tones And I      25
# 6v3KW9xbzN5yKLt9YKDYA2  Señorita                            Shawn Mendes     25
# 5PjdY0CKGZdEuoNab3yDmX  STAY (with Justin Bieber)           The Kid LAROI    25
# Name: region, dtype: int64

# %% [markdown]
# #### Development of average chart song length from 2017 to 2021

# %% [markdown]
# Several media reports claim that Pop Songs are becoming shorter and shorter due to the influence of Spotify's algorithm (see for example [this](https://www.prsformusic.com/m-magazine/features/song-length-the-spotify-effect#:~:text=Pop%20songs%20are%20one%20minute,Are%20algorithms%20to%20blame%3F&text=20%20May%202019-,Pop%20songs%20are%20one%20minute%20and%2013%20seconds%20shorter%20on,they%20were%2020%20years%20ago.) article). Can we observe that trend of decreasing average song length also when looking at the length of Spotify Chart songs from 2017 to 2021?

# %%
song_lengths = (
    global_charts.reset_index()
    .drop_duplicates(subset=["id", "date"])
    .groupby(["date"])
    .duration_ms.median()
) / 1000 # convert milliseconds to seconds
song_lengths.name = "song duration (s)"
song_lengths
# Out:
# date
# 2017-01-01    211.2020
# 2017-01-02    210.6150
# 2017-01-03    210.6150
# 2017-01-04    210.2600
# 2017-01-05    210.2600
#                 ...
# 2021-12-27    202.8995
# 2021-12-28    202.8995
# 2021-12-29    202.8995
# 2021-12-30    201.3875
# 2021-12-31    195.4750
# Name: song duration (s), Length: 1826, dtype: float64

# %%
import seaborn as sns

# %%
sns.lineplot(song_lengths)
plt.title("Median song lengths for Spotify Daily Top 50 (global)")
# Out:
# Text(0.5, 1.0, 'Median song lengths for Spotify Daily Top 50 (global)')

# %% [markdown]
# ### Countries with most songs streamed

# %%
streams = countries_charts.groupby(["region", "date"]).streams.sum().sort_values(ascending=False).reset_index().set_index("date")
streams
# Out:
#                    region      streams
# date
# 2021-09-03  United States  107186728.0
# 2018-06-29  United States  104387689.0
# 2020-12-25  United States   92143610.0
# 2021-12-25  United States   85469959.0
# 2018-06-30  United States   82462231.0
# ...                   ...          ...
# 2017-01-01         Greece      59509.0
# 2017-01-01        Iceland      58313.0
# 2017-01-05       Slovakia      54583.0
# 2017-01-02       Slovakia      53821.0
# 2017-01-01       Slovakia      25068.0
#
# [89474 rows x 2 columns]

# %%
sns.lineplot(streams)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
sns.lineplot(streams[streams.region == "United States"])
# Out:
# <AxesSubplot: xlabel='date'>

# %%
years = list(range(2018, 2022))
fig, axs = plt.subplots(len(years), 1, figsize=(12, 18))
us_streams = streams[streams.region == "United States"]
for i, ax in enumerate(axs.ravel()):
  year = years[i]
  year_range = pd.date_range(f"{year}-01-01", f"{year}-12-31")
  sns.lineplot(us_streams.loc[year_range], ax=ax)
  ax.set_title(f"{year}")

plt.show()

# %%
streams.index
# Out:
# DatetimeIndex(['2021-09-03', '2018-06-29', '2020-12-25', '2021-12-25',
#                '2018-06-30', '2018-04-27', '2020-12-11', '2018-09-28',
#                '2020-07-24', '2018-04-20',
#                ...
#                '2017-01-10', '2017-01-06', '2017-01-04', '2017-01-08',
#                '2017-01-09', '2017-01-01', '2017-01-01', '2017-01-05',
#                '2017-01-02', '2017-01-01'],
#               dtype='datetime64[ns]', name='date', length=89474, freq=None)

# %%
streams[streams.index.duplicated(False)].sort_index()
# Out:
#                     region     streams
# date
# 2017-01-01        Slovakia     25068.0
# 2017-01-01          France   2650110.0
# 2017-01-01        Malaysia    659272.0
# 2017-01-01         Uruguay    315699.0
# 2017-01-01       Australia   2983688.0
# ...                    ...         ...
# 2021-12-31        Slovakia    374634.0
# 2021-12-31        Portugal   1191161.0
# 2021-12-31         Austria   1145893.0
# 2021-12-31  United Kingdom   9998946.0
# 2021-12-31           Spain  12660097.0
#
# [89474 rows x 2 columns]

# %%
us_streams = streams[streams.region == "United States"]

import numpy as np

def plot_year_by_year_comparisons(streams):
    years = list(range(2018, 2022))
    fig, axs = plt.subplots(len(years), 1, figsize=(12, 18))
    for i, ax in enumerate(axs.ravel()):
        
        year = years[i]
        prev_year = year - 1
        date_range = pd.date_range(f"{prev_year}-01-01", f"{year}-12-31")
        cur_streams = streams.reindex(date_range)#loc[date_range]
        #cur_streams.loc[pd.date_range(f"{year}-02-01", f"{year}-02-28"), "streams"] = np.nan
        cur_streams.streams.fillna(np.inf, inplace=True)
        sns.lineplot(
            x=cur_streams.index.dayofyear,
            y=cur_streams["streams"],
            hue=cur_streams.index.year,
            ax=ax,
        )
    plt.show()

plot_year_by_year_comparisons(us_streams)

# %%
plot_year_by_year_comparisons(streams)
# Out:
# /tmp/ipykernel_61656/2891280251.py:13: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   cur_streams = streams.reindex(date_range)#loc[date_range]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [28], line 1
# ----> 1 plot_year_by_year_comparisons(streams)
#
# Cell In [27], line 13, in plot_year_by_year_comparisons(streams)
#      11 prev_year = year - 1
#      12 date_range = pd.date_range(f"{prev_year}-01-01", f"{year}-12-31")
# ---> 13 cur_streams = streams.reindex(date_range)#loc[date_range]
#      14 #cur_streams.loc[pd.date_range(f"{year}-02-01", f"{year}-02-28"), "streams"] = np.nan
#      15 cur_streams.streams.fillna(np.inf, inplace=True)
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/util/_decorators.py:347, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     345 @wraps(func)
#     346 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 347     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/frame.py:5194, in DataFrame.reindex(self, *args, **kwargs)
#    5192 kwargs.pop("axis", None)
#    5193 kwargs.pop("labels", None)
# -> 5194 return super().reindex(**kwargs)
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/generic.py:5289, in NDFrame.reindex(self, *args, **kwargs)
#    5286     return self._reindex_multi(axes, copy, fill_value)
#    5288 # perform the reindex on the axes
# -> 5289 return self._reindex_axes(
#    5290     axes, level, limit, tolerance, method, fill_value, copy
#    5291 ).__finalize__(self, method="reindex")
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/frame.py:4993, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4991 index = axes["index"]
#    4992 if index is not None:
# -> 4993     frame = frame._reindex_index(
#    4994         index, method, copy, level, fill_value, limit, tolerance
#    4995     )
#    4997 return frame
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/frame.py:5012, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4999 def _reindex_index(
#    5000     self,
#    5001     new_index,
#    (...)
#    5007     tolerance=None,
#    5008 ):
#    5009     new_index, indexer = self.index.reindex(
#    5010         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    5011     )
# -> 5012     return self._reindex_with_indexers(
#    5013         {0: [new_index, indexer]},
#    5014         copy=copy,
#    5015         fill_value=fill_value,
#    5016         allow_dups=False,
#    5017     )
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/generic.py:5355, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5352     indexer = ensure_platform_int(indexer)
#    5354 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5355 new_data = new_data.reindex_indexer(
#    5356     index,
#    5357     indexer,
#    5358     axis=baxis,
#    5359     fill_value=fill_value,
#    5360     allow_dups=allow_dups,
#    5361     copy=copy,
#    5362 )
#    5363 # If we've made a copy once, no need to make another one
#    5364 copy = False
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/internals/managers.py:729, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     727 # some axes don't allow reindexing with dups
#     728 if not allow_dups:
# --> 729     self.axes[axis]._validate_can_reindex(indexer)
#     731 if axis >= self.ndim:
#     732     raise IndexError("Requested axis not found in manager")
#
# File ~/anaconda3/envs/sejmouvisds/lib/python3.10/site-packages/pandas/core/indexes/base.py:4359, in Index._validate_can_reindex(self, indexer)
#    4357 # trying to reindex on an axis with duplicates
#    4358 if not self._index_as_unique and len(indexer):
# -> 4359     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels
