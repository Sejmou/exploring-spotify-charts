# %%
import pandas as pd
from helpers import get_data_path

# %%
tracks = pd.read_csv(get_data_path("tracks.csv"))
tracks
# Out:
#                                                    album  \
# 0      {'album_type': 'album', 'artists': [{'external...
# 1      {'album_type': 'single', 'artists': [{'externa...
# 2      {'album_type': 'album', 'artists': [{'external...
# 3      {'album_type': 'album', 'artists': [{'external...
# 4      {'album_type': 'single', 'artists': [{'externa...
# ...                                                  ...
# 33876  {'album_type': 'album', 'artists': [{'external...
# 33877  {'album_type': 'single', 'artists': [{'externa...
# 33878  {'album_type': 'single', 'artists': [{'externa...
# 33879  {'album_type': 'single', 'artists': [{'externa...
# 33880  {'album_type': 'album', 'artists': [{'external...
#
#                                                  artists  \
# 0      [{'external_urls': {'spotify': 'https://open.s...
# 1      [{'external_urls': {'spotify': 'https://open.s...
# 2      [{'external_urls': {'spotify': 'https://open.s...
# 3      [{'external_urls': {'spotify': 'https://open.s...
# 4      [{'external_urls': {'spotify': 'https://open.s...
# ...                                                  ...
# 33876  [{'external_urls': {'spotify': 'https://open.s...
# 33877  [{'external_urls': {'spotify': 'https://open.s...
# 33878  [{'external_urls': {'spotify': 'https://open.s...
# 33879  [{'external_urls': {'spotify': 'https://open.s...
# 33880  [{'external_urls': {'spotify': 'https://open.s...
#
#                                        available_markets  disc_number  \
# 0      ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 1      ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 2      ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 3                                                     []            1
# 4                                                     []            1
# ...                                                  ...          ...
# 33876  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 33877  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 33878                                                 []            1
# 33879  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 33880  ['AD', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU...            1
#
#        duration_ms  explicit              external_ids  \
# 0           195840     False  {'isrc': 'USSD11600299'}
# 1           259195     False  {'isrc': 'USSD11600252'}
# 2           222560     False  {'isrc': 'USSD11600135'}
# 3           205600     False  {'isrc': 'USUM71604778'}
# 4           234320     False  {'isrc': 'US2BU1600020'}
# ...            ...       ...                       ...
# 33876       179120     False  {'isrc': 'UYM120700001'}
# 33877       211896     False  {'isrc': 'UYM122103910'}
# 33878       180240      True  {'isrc': 'BXIV82097196'}
# 33879       165466      True  {'isrc': 'GBUM71702567'}
# 33880       180386      True  {'isrc': 'USQX91701275'}
#
#                                            external_urls  \
# 0      {'spotify': 'https://open.spotify.com/track/6m...
# 1      {'spotify': 'https://open.spotify.com/track/7D...
# 2      {'spotify': 'https://open.spotify.com/track/3A...
# 3      {'spotify': 'https://open.spotify.com/track/6r...
# 4      {'spotify': 'https://open.spotify.com/track/58...
# ...                                                  ...
# 33876  {'spotify': 'https://open.spotify.com/track/6C...
# 33877  {'spotify': 'https://open.spotify.com/track/7a...
# 33878  {'spotify': 'https://open.spotify.com/track/1P...
# 33879  {'spotify': 'https://open.spotify.com/track/6y...
# 33880  {'spotify': 'https://open.spotify.com/track/7K...
#
#                                                     href  \
# 0      https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 1      https://api.spotify.com/v1/tracks/7DM4BPaS7uof...
# 2      https://api.spotify.com/v1/tracks/3AEZUABDXNte...
# 3      https://api.spotify.com/v1/tracks/6rQSrBHf7HlZ...
# 4      https://api.spotify.com/v1/tracks/58IL315gMSTD...
# ...                                                  ...
# 33876  https://api.spotify.com/v1/tracks/6ClL99PvuCeB...
# 33877  https://api.spotify.com/v1/tracks/7asgcWpGtv92...
# 33878  https://api.spotify.com/v1/tracks/1PIiIVeacU0F...
# 33879  https://api.spotify.com/v1/tracks/6yf3MxEOScNB...
# 33880  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
#
#                            id  is_local  \
# 0      6mICuAdrwEjh6Y6lroV2Kg     False
# 1      7DM4BPaS7uofFul3ywMe46     False
# 2      3AEZUABDXNtecAOSC1qTfo     False
# 3      6rQSrBHf7HlZjtcMZ4S4bO     False
# 4      58IL315gMSTD37DOZPJ2hf     False
# ...                       ...       ...
# 33876  6ClL99PvuCeBLTFTdnR1Hw     False
# 33877  7asgcWpGtv92TiMZUYNWVt     False
# 33878  1PIiIVeacU0Fj7Rm9lFlsx     False
# 33879  6yf3MxEOScNBTYCHOAIiNQ     False
# 33880  7KA4W4McWYRpgf0fWsJZWB     False
#
#                                                  name  popularity  \
# 0                             Chantaje (feat. Maluma)          76
# 1                         Vente Pa' Ca (feat. Maluma)          72
# 2                          Reggaetón Lento (Bailemos)          72
# 3                                              Safari           0
# 4                                         Shaky Shaky           0
# ...                                               ...         ...
# 33876                              Que Tiene la Noche          42
# 33877                                      Me Encanta          58
# 33878                                          Paypal           0
# 33879  Instruction (feat. Demi Lovato & Stefflon Don)          52
# 33880                See You Again (feat. Kali Uchis)          84
#
#                                              preview_url  track_number   type  \
# 0      https://p.scdn.co/mp3-preview/b7a66b261ebbe2aa...             3  track
# 1      https://p.scdn.co/mp3-preview/21e38a8983daf1c3...             1  track
# 2      https://p.scdn.co/mp3-preview/ced5c17cadb43603...             3  track
# 3                                                    NaN             3  track
# 4                                                    NaN             1  track
# ...                                                  ...           ...    ...
# 33876  https://p.scdn.co/mp3-preview/93168930edca3314...             1  track
# 33877  https://p.scdn.co/mp3-preview/719b6f57859cf341...             1  track
# 33878                                                NaN             1  track
# 33879  https://p.scdn.co/mp3-preview/d528dbeae270d471...             1  track
# 33880  https://p.scdn.co/mp3-preview/e6c4c9656721fe0a...             4  track
#
#                                         uri
# 0      spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1      spotify:track:7DM4BPaS7uofFul3ywMe46
# 2      spotify:track:3AEZUABDXNtecAOSC1qTfo
# 3      spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 4      spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                                     ...
# 33876  spotify:track:6ClL99PvuCeBLTFTdnR1Hw
# 33877  spotify:track:7asgcWpGtv92TiMZUYNWVt
# 33878  spotify:track:1PIiIVeacU0Fj7Rm9lFlsx
# 33879  spotify:track:6yf3MxEOScNBTYCHOAIiNQ
# 33880  spotify:track:7KA4W4McWYRpgf0fWsJZWB
#
# [33881 rows x 17 columns]

# %%
artists = pd.read_csv(get_data_path("artist_data.csv"))
artists
# Out:
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/artist/0...
# 1     {'spotify': 'https://open.spotify.com/artist/1...
# 2     {'spotify': 'https://open.spotify.com/artist/7...
# 3     {'spotify': 'https://open.spotify.com/artist/0...
# 4     {'spotify': 'https://open.spotify.com/artist/1...
# ...                                                 ...
# 9895  {'spotify': 'https://open.spotify.com/artist/6...
# 9896  {'spotify': 'https://open.spotify.com/artist/2...
# 9897  {'spotify': 'https://open.spotify.com/artist/7...
# 9898  {'spotify': 'https://open.spotify.com/artist/7...
# 9899  {'spotify': 'https://open.spotify.com/artist/6...
#
#                               followers  \
# 0     {'href': None, 'total': 25410505}
# 1     {'href': None, 'total': 32515561}
# 2      {'href': None, 'total': 6909733}
# 3      {'href': None, 'total': 9276524}
# 4     {'href': None, 'total': 35676285}
# ...                                 ...
# 9895     {'href': None, 'total': 51232}
# 9896     {'href': None, 'total': 17542}
# 9897     {'href': None, 'total': 43358}
# 9898     {'href': None, 'total': 33245}
# 9899       {'href': None, 'total': 139}
#
#                                                  genres  \
# 0           ['colombian pop', 'dance pop', 'latin pop']
# 1     ['reggaeton', 'reggaeton colombiano', 'trap la...
# 2     ['dance pop', 'latin pop', 'mexican pop', 'pue...
# 3                ['boy band', 'latin pop', 'reggaeton']
# 4     ['reggaeton', 'reggaeton colombiano', 'trap la...
# ...                                                 ...
# 9895                                     ['cumbia pop']
# 9896  ['cumbia pop', 'cumbia uruguaya', 'plena urugu...
# 9897  ['cumbia pop', 'cumbia uruguaya', 'plena urugu...
# 9898                                                 []
# 9899                                   ['rap paraense']
#
#                                                    href  \
# 0     https://api.spotify.com/v1/artists/0EmeFodog0B...
# 1     https://api.spotify.com/v1/artists/1r4hJ1h58CW...
# 2     https://api.spotify.com/v1/artists/7slfeZO9LsJ...
# 3     https://api.spotify.com/v1/artists/0eecdvMrqBf...
# 4     https://api.spotify.com/v1/artists/1vyhD5VmyZ7...
# ...                                                 ...
# 9895  https://api.spotify.com/v1/artists/6SGCqG5HEr5...
# 9896  https://api.spotify.com/v1/artists/2QoRWNLJ6A9...
# 9897  https://api.spotify.com/v1/artists/7Bl9s8h4F1j...
# 9898  https://api.spotify.com/v1/artists/7A7wnJp6eGB...
# 9899  https://api.spotify.com/v1/artists/6OviQMT0o5K...
#
#                           id  \
# 0     0EmeFodog0BfCgMzAIvKQp
# 1     1r4hJ1h58CWwUQe3MxPuau
# 2     7slfeZO9LsJbWgpkIoXBUJ
# 3     0eecdvMrqBftK0M1VKhaF4
# 4     1vyhD5VmyZ7KMfW5gqLgo5
# ...                      ...
# 9895  6SGCqG5HEr5gFZR9ct8wID
# 9896  2QoRWNLJ6A9M8f9F0ovGcM
# 9897  7Bl9s8h4F1jcX1aJYHBpfm
# 9898  7A7wnJp6eGBNV5Foax2kYg
# 9899  6OviQMT0o5K1fzKYvUNbRS
#
#                                                  images            name  \
# 0     [{'height': 640, 'url': 'https://i.scdn.co/ima...         Shakira
# 1     [{'height': 640, 'url': 'https://i.scdn.co/ima...          Maluma
# 2     [{'height': 640, 'url': 'https://i.scdn.co/ima...    Ricky Martin
# 3     [{'height': 640, 'url': 'https://i.scdn.co/ima...            CNCO
# 4     [{'height': 640, 'url': 'https://i.scdn.co/ima...        J Balvin
# ...                                                 ...             ...
# 9895  [{'height': 640, 'url': 'https://i.scdn.co/ima...   Matías Valdez
# 9896  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Sonido Caracol
# 9897  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Chacho Ramos
# 9898  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Teto Mc
# 9899  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Lucas Corleone
#
#       popularity    type                                    uri
# 0             85  artist  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 1             83  artist  spotify:artist:1r4hJ1h58CWwUQe3MxPuau
# 2             72  artist  spotify:artist:7slfeZO9LsJbWgpkIoXBUJ
# 3             69  artist  spotify:artist:0eecdvMrqBftK0M1VKhaF4
# 4             87  artist  spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5
# ...          ...     ...                                    ...
# 9895          57  artist  spotify:artist:6SGCqG5HEr5gFZR9ct8wID
# 9896          35  artist  spotify:artist:2QoRWNLJ6A9M8f9F0ovGcM
# 9897          48  artist  spotify:artist:7Bl9s8h4F1jcX1aJYHBpfm
# 9898          37  artist  spotify:artist:7A7wnJp6eGBNV5Foax2kYg
# 9899           1  artist  spotify:artist:6OviQMT0o5K1fzKYvUNbRS
#
# [9900 rows x 10 columns]

# %%
import musicbrainzngs as m
m.set_useragent("application", "0.01", "http://example.com")

# %%
def get_info(artist_row):
  data = {}
  data 
  try:
    first_match = m.search_artists(artist_row.name)["artist-list"][0]
    data["country"] = first_match["country"]
    data[""]
    print(first_match)
    return data
  except:
    print("No data found for")
    pass

# %%
len(artists.name.drop_duplicates())
# Out:
# 9788
