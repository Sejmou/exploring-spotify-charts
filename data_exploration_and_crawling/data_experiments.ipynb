# %%
import pandas as pd
from helpers import get_data_path

# %%
tracks = pd.read_csv(get_data_path("tracks.csv"))
tracks
# Out:
#                                                    album  \
# 0      {'album_type': 'album', 'artists': [{'external...
# 1      {'album_type': 'single', 'artists': [{'externa...
# 2      {'album_type': 'album', 'artists': [{'external...
# 3      {'album_type': 'album', 'artists': [{'external...
# 4      {'album_type': 'single', 'artists': [{'externa...
# ...                                                  ...
# 33876  {'album_type': 'album', 'artists': [{'external...
# 33877  {'album_type': 'single', 'artists': [{'externa...
# 33878  {'album_type': 'single', 'artists': [{'externa...
# 33879  {'album_type': 'single', 'artists': [{'externa...
# 33880  {'album_type': 'album', 'artists': [{'external...
#
#                                                  artists  \
# 0      [{'external_urls': {'spotify': 'https://open.s...
# 1      [{'external_urls': {'spotify': 'https://open.s...
# 2      [{'external_urls': {'spotify': 'https://open.s...
# ...

# %%
track_features = pd.read_csv(get_data_path("audio_features.csv"))
track_features
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.852   0.773   8.0    -2.921   0.0       0.0776       0.18700
# 1             0.663   0.920  11.0    -4.070   0.0       0.2260       0.00431
# 2             0.761   0.838   4.0    -3.073   0.0       0.0502       0.40000
# 3             0.508   0.687   0.0    -4.361   1.0       0.3260       0.55100
# 4             0.899   0.626   6.0    -4.228   0.0       0.2920       0.07600
# ...             ...     ...   ...       ...   ...          ...           ...
# 33876         0.766   0.795   9.0    -5.530   0.0       0.0644       0.26600
# 33877         0.672   0.708   7.0    -5.454   1.0       0.0364       0.55100
# 33878         0.902   0.560   4.0    -4.471   0.0       0.3220       0.30200
# 33879         0.767   0.929   9.0    -3.080   0.0       0.1850       0.10200
# 33880         0.558   0.559   6.0    -9.222   1.0       0.0959       0.37100
#
# ...

# %%
clean_charts = pd.read_csv(get_data_path("spotify_charts_cleaned.csv"))
clean_charts
# Out:
#             region        date  rank                                   uri  \
# 0        Argentina  2017-01-01     1  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1        Argentina  2017-01-01     2  spotify:track:7DM4BPaS7uofFul3ywMe46
# 2        Argentina  2017-01-01     3  spotify:track:3AEZUABDXNtecAOSC1qTfo
# 3        Argentina  2017-01-01     4  spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 4        Argentina  2017-01-01     5  spotify:track:58IL315gMSTD37DOZPJ2hf
# ...            ...         ...   ...                                   ...
# 4556320    Uruguay  2021-08-13    25  spotify:track:4aXicRG47bBEcKXlDaSRwW
# 4556321    Uruguay  2021-08-13    27  spotify:track:43qcs9NpJhDxtG91zxFkj7
# 4556322    Uruguay  2021-08-13    33  spotify:track:4M4DTyLupKvbJKlE4I4EYq
# 4556323    Uruguay  2021-08-13    35  spotify:track:5jzEwSyyymBlf1fa1o39T2
# 4556324    Uruguay  2021-08-13    36  spotify:track:5PjdY0CKGZdEuoNab3yDmX
#
#           streams
# 0        253019.0
# 1        223988.0
# ...

# %%
artist_data = pd.read_csv(get_data_path("artist_data.csv"))
artist_data
# Out:
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/artist/0...
# 1     {'spotify': 'https://open.spotify.com/artist/1...
# 2     {'spotify': 'https://open.spotify.com/artist/7...
# 3     {'spotify': 'https://open.spotify.com/artist/0...
# 4     {'spotify': 'https://open.spotify.com/artist/1...
# ...                                                 ...
# 9895  {'spotify': 'https://open.spotify.com/artist/6...
# 9896  {'spotify': 'https://open.spotify.com/artist/2...
# 9897  {'spotify': 'https://open.spotify.com/artist/7...
# 9898  {'spotify': 'https://open.spotify.com/artist/7...
# 9899  {'spotify': 'https://open.spotify.com/artist/6...
#
#                               followers  \
# 0     {'href': None, 'total': 25410505}
# 1     {'href': None, 'total': 32515561}
# 2      {'href': None, 'total': 6909733}
# 3      {'href': None, 'total': 9276524}
# 4     {'href': None, 'total': 35676285}
# ...                                 ...
# ...
