# %% [markdown]
# # Obtaining metadata for countries of Spotify charts dataset

# %% [markdown]
# To make the information about the countries (regions that are not `"Global"`) in the chart data even more insightful, we should get the country ISO codes as well. Furthermore, region information could be useful.

# %%
import pandas as pd
from helpers import get_data_path, create_data_out_path

# %% [markdown]
# ## Loading charts data

# %%
charts = pd.read_csv(get_data_path("top50.csv"))
charts
# Out:
#             region        date  rank   streams                      id
# 0        Argentina  2017-01-01     1  253019.0  6mICuAdrwEjh6Y6lroV2Kg
# 1        Argentina  2017-01-01     2  223988.0  7DM4BPaS7uofFul3ywMe46
# 2        Argentina  2017-01-01     3  210943.0  3AEZUABDXNtecAOSC1qTfo
# 3        Argentina  2017-01-01     4  173865.0  6rQSrBHf7HlZjtcMZ4S4bO
# 4        Argentina  2017-01-01     5  153956.0  58IL315gMSTD37DOZPJ2hf
# ...            ...         ...   ...       ...                     ...
# 4563811    Uruguay  2021-08-13    25   11431.0  4aXicRG47bBEcKXlDaSRwW
# 4563812    Uruguay  2021-08-13    27   10946.0  43qcs9NpJhDxtG91zxFkj7
# 4563813    Uruguay  2021-08-13    33    9994.0  4M4DTyLupKvbJKlE4I4EYq
# 4563814    Uruguay  2021-08-13    35    9251.0  5jzEwSyyymBlf1fa1o39T2
# 4563815    Uruguay  2021-08-13    36    9179.0  5PjdY0CKGZdEuoNab3yDmX
#
# [4563816 rows x 5 columns]

# %% [markdown]
# ## Loading ISO code data

# %%
country_iso_data = pd.read_csv(
    get_data_path(
        "iso_codes.csv",
        download_url="https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv",
    ),
).set_index("alpha-3")
country_iso_data
# Out:
#                       name alpha-2  country-code     iso_3166-2   region  \
# alpha-3
# AFG            Afghanistan      AF             4  ISO 3166-2:AF     Asia
# ALA          Åland Islands      AX           248  ISO 3166-2:AX   Europe
# ALB                Albania      AL             8  ISO 3166-2:AL   Europe
# DZA                Algeria      DZ            12  ISO 3166-2:DZ   Africa
# ASM         American Samoa      AS            16  ISO 3166-2:AS  Oceania
# ...                    ...     ...           ...            ...      ...
# WLF      Wallis and Futuna      WF           876  ISO 3166-2:WF  Oceania
# ESH         Western Sahara      EH           732  ISO 3166-2:EH   Africa
# YEM                  Yemen      YE           887  ISO 3166-2:YE     Asia
# ZMB                 Zambia      ZM           894  ISO 3166-2:ZM   Africa
# ZWE               Zimbabwe      ZW           716  ISO 3166-2:ZW   Africa
#
#                  sub-region intermediate-region  region-code  sub-region-code  \
# alpha-3
# AFG           Southern Asia                 NaN        142.0             34.0
# ALA         Northern Europe                 NaN        150.0            154.0
# ALB         Southern Europe                 NaN        150.0             39.0
# DZA         Northern Africa                 NaN          2.0             15.0
# ASM               Polynesia                 NaN          9.0             61.0
# ...                     ...                 ...          ...              ...
# WLF               Polynesia                 NaN          9.0             61.0
# ESH         Northern Africa                 NaN          2.0             15.0
# YEM            Western Asia                 NaN        142.0            145.0
# ZMB      Sub-Saharan Africa      Eastern Africa          2.0            202.0
# ZWE      Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#          intermediate-region-code
# alpha-3
# AFG                           NaN
# ALA                           NaN
# ALB                           NaN
# DZA                           NaN
# ASM                           NaN
# ...                           ...
# WLF                           NaN
# ESH                           NaN
# YEM                           NaN
# ZMB                          14.0
# ZWE                          14.0
#
# [249 rows x 10 columns]

# %% [markdown]
# ## Joining Spotify regions with ISO code dataframe

# %%
countries = list(set(charts.reset_index().region))
countries.remove("Global")
len(countries)
# Out:
# 49

# %%
matches = (
    country_iso_data[country_iso_data["name"].isin(countries)][["name"]]
    .copy()
    .rename(columns={"name": "spotify_region"})
)
mismatches = list(set(countries) - set(matches.spotify_region.to_list()))

# %%
matches
# Out:
#              spotify_region
# alpha-3
# ARG               Argentina
# AUS               Australia
# AUT                 Austria
# BEL                 Belgium
# BRA                  Brazil
# CAN                  Canada
# CHL                   Chile
# COL                Colombia
# CRI              Costa Rica
# DNK                 Denmark
# DOM      Dominican Republic
# ECU                 Ecuador
# SLV             El Salvador
# FIN                 Finland
# FRA                  France
# DEU                 Germany
# GRC                  Greece
# GTM               Guatemala
# HND                Honduras
# HKG               Hong Kong
# HUN                 Hungary
# ISL                 Iceland
# IDN               Indonesia
# IRL                 Ireland
# ITA                   Italy
# JPN                   Japan
# MYS                Malaysia
# MEX                  Mexico
# NLD             Netherlands
# NZL             New Zealand
# NOR                  Norway
# PAN                  Panama
# PRY                Paraguay
# PER                    Peru
# PHL             Philippines
# POL                  Poland
# PRT                Portugal
# SGP               Singapore
# SVK                Slovakia
# ESP                   Spain
# SWE                  Sweden
# CHE             Switzerland
# TUR                  Turkey
# URY                 Uruguay

# %%
mismatches
# Out:
# ['Czech Republic', 'United Kingdom', 'United States', 'Bolivia', 'Taiwan']

# %%
def search_for_country_name_substr(substr):
  return country_iso_data[country_iso_data.name.str.lower().str.contains(substr.lower())]

# %%
search_for_country_name_substr("Bol")
# Out:
#                                        name alpha-2  country-code  \
# alpha-3
# BOL        Bolivia (Plurinational State of)      BO            68
# VEN      Venezuela (Bolivarian Republic of)      VE           862
#
#             iso_3166-2    region                       sub-region  \
# alpha-3
# BOL      ISO 3166-2:BO  Americas  Latin America and the Caribbean
# VEN      ISO 3166-2:VE  Americas  Latin America and the Caribbean
#
#         intermediate-region  region-code  sub-region-code  \
# alpha-3
# BOL           South America         19.0            419.0
# VEN           South America         19.0            419.0
#
#          intermediate-region-code
# alpha-3
# BOL                           5.0
# VEN                           5.0

# %%
manual_mappings = []

# %%
manual_mappings.append(("Bolivia", "BOL"))

# %%
search_for_country_name_substr("Cze")
# Out:
#             name alpha-2  country-code     iso_3166-2  region      sub-region  \
# alpha-3
# CZE      Czechia      CZ           203  ISO 3166-2:CZ  Europe  Eastern Europe
#
#         intermediate-region  region-code  sub-region-code  \
# alpha-3
# CZE                     NaN        150.0            151.0
#
#          intermediate-region-code
# alpha-3
# CZE                           NaN

# %%
manual_mappings.append(("Czech Republic", "CZE"))

# %%
search_for_country_name_substr("Taiwan")
# Out:
#                               name alpha-2  country-code     iso_3166-2  \
# alpha-3
# TWN      Taiwan, Province of China      TW           158  ISO 3166-2:TW
#
#         region    sub-region intermediate-region  region-code  \
# alpha-3
# TWN       Asia  Eastern Asia                 NaN        142.0
#
#          sub-region-code  intermediate-region-code
# alpha-3
# TWN                 30.0                       NaN

# %%
manual_mappings.append(("Taiwan", "TWN"))

# %%
search_for_country_name_substr("United Kingdom")
# Out:
#                                                       name alpha-2  \
# alpha-3
# GBR      United Kingdom of Great Britain and Northern I...      GB
#
#          country-code     iso_3166-2  region       sub-region  \
# alpha-3
# GBR               826  ISO 3166-2:GB  Europe  Northern Europe
#
#         intermediate-region  region-code  sub-region-code  \
# alpha-3
# GBR                     NaN        150.0            154.0
#
#          intermediate-region-code
# alpha-3
# GBR                           NaN

# %%
manual_mappings.append(("United Kingdom", "GBR"))

# %%
search_for_country_name_substr("United States")
# Out:
#                                          name alpha-2  country-code  \
# alpha-3
# USA                  United States of America      US           840
# UMI      United States Minor Outlying Islands      UM           581
#
#             iso_3166-2    region        sub-region intermediate-region  \
# alpha-3
# USA      ISO 3166-2:US  Americas  Northern America                 NaN
# UMI      ISO 3166-2:UM   Oceania        Micronesia                 NaN
#
#          region-code  sub-region-code  intermediate-region-code
# alpha-3
# USA             19.0             21.0                       NaN
# UMI              9.0             57.0                       NaN

# %%
manual_mappings.append(("United States", "USA"))

# %%
manual_mapping_df = pd.DataFrame(manual_mappings, columns=["spotify_region", "alpha-3"]).set_index("alpha-3")

# %%
spotify_country_iso_alpha3 = pd.concat([matches, manual_mapping_df])

# %%
spotify_country_iso_alpha3
# Out:
#              spotify_region
# alpha-3
# ARG               Argentina
# AUS               Australia
# AUT                 Austria
# BEL                 Belgium
# BRA                  Brazil
# CAN                  Canada
# CHL                   Chile
# COL                Colombia
# CRI              Costa Rica
# DNK                 Denmark
# DOM      Dominican Republic
# ECU                 Ecuador
# SLV             El Salvador
# FIN                 Finland
# FRA                  France
# DEU                 Germany
# GRC                  Greece
# GTM               Guatemala
# HND                Honduras
# HKG               Hong Kong
# HUN                 Hungary
# ISL                 Iceland
# IDN               Indonesia
# IRL                 Ireland
# ITA                   Italy
# JPN                   Japan
# MYS                Malaysia
# MEX                  Mexico
# NLD             Netherlands
# NZL             New Zealand
# NOR                  Norway
# PAN                  Panama
# PRY                Paraguay
# PER                    Peru
# PHL             Philippines
# POL                  Poland
# PRT                Portugal
# SGP               Singapore
# SVK                Slovakia
# ESP                   Spain
# SWE                  Sweden
# CHE             Switzerland
# TUR                  Turkey
# URY                 Uruguay
# BOL                 Bolivia
# CZE          Czech Republic
# TWN                  Taiwan
# GBR          United Kingdom
# USA           United States

# %%
spotify_country_iso_alpha3.shape
# Out:
# (49, 1)

# %%
spotify_country_iso_alpha3.columns
# Out:
# Index(['spotify_region'], dtype='object')

# %%
country_iso_data.columns
# Out:
# Index(['name', 'alpha-2', 'country-code', 'iso_3166-2', 'region', 'sub-region',
#        'intermediate-region', 'region-code', 'sub-region-code',
#        'intermediate-region-code'],
#       dtype='object')

# %%
country_iso_data
# Out:
#                       name alpha-2  country-code     iso_3166-2   region  \
# alpha-3
# AFG            Afghanistan      AF             4  ISO 3166-2:AF     Asia
# ALA          Åland Islands      AX           248  ISO 3166-2:AX   Europe
# ALB                Albania      AL             8  ISO 3166-2:AL   Europe
# DZA                Algeria      DZ            12  ISO 3166-2:DZ   Africa
# ASM         American Samoa      AS            16  ISO 3166-2:AS  Oceania
# ...                    ...     ...           ...            ...      ...
# WLF      Wallis and Futuna      WF           876  ISO 3166-2:WF  Oceania
# ESH         Western Sahara      EH           732  ISO 3166-2:EH   Africa
# YEM                  Yemen      YE           887  ISO 3166-2:YE     Asia
# ZMB                 Zambia      ZM           894  ISO 3166-2:ZM   Africa
# ZWE               Zimbabwe      ZW           716  ISO 3166-2:ZW   Africa
#
#                  sub-region intermediate-region  region-code  sub-region-code  \
# alpha-3
# AFG           Southern Asia                 NaN        142.0             34.0
# ALA         Northern Europe                 NaN        150.0            154.0
# ALB         Southern Europe                 NaN        150.0             39.0
# DZA         Northern Africa                 NaN          2.0             15.0
# ASM               Polynesia                 NaN          9.0             61.0
# ...                     ...                 ...          ...              ...
# WLF               Polynesia                 NaN          9.0             61.0
# ESH         Northern Africa                 NaN          2.0             15.0
# YEM            Western Asia                 NaN        142.0            145.0
# ZMB      Sub-Saharan Africa      Eastern Africa          2.0            202.0
# ZWE      Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#          intermediate-region-code
# alpha-3
# AFG                           NaN
# ALA                           NaN
# ALB                           NaN
# DZA                           NaN
# ASM                           NaN
# ...                           ...
# WLF                           NaN
# ESH                           NaN
# YEM                           NaN
# ZMB                          14.0
# ZWE                          14.0
#
# [249 rows x 10 columns]

# %%
spotify_country_iso_data = spotify_country_iso_alpha3.join(country_iso_data)
spotify_country_iso_data
# Out:
#              spotify_region  \
# alpha-3
# ARG               Argentina
# AUS               Australia
# AUT                 Austria
# BEL                 Belgium
# BRA                  Brazil
# CAN                  Canada
# CHL                   Chile
# COL                Colombia
# CRI              Costa Rica
# DNK                 Denmark
# DOM      Dominican Republic
# ECU                 Ecuador
# SLV             El Salvador
# FIN                 Finland
# FRA                  France
# DEU                 Germany
# GRC                  Greece
# GTM               Guatemala
# HND                Honduras
# HKG               Hong Kong
# HUN                 Hungary
# ISL                 Iceland
# IDN               Indonesia
# IRL                 Ireland
# ITA                   Italy
# JPN                   Japan
# MYS                Malaysia
# MEX                  Mexico
# NLD             Netherlands
# NZL             New Zealand
# NOR                  Norway
# PAN                  Panama
# PRY                Paraguay
# PER                    Peru
# PHL             Philippines
# POL                  Poland
# PRT                Portugal
# SGP               Singapore
# SVK                Slovakia
# ESP                   Spain
# SWE                  Sweden
# CHE             Switzerland
# TUR                  Turkey
# URY                 Uruguay
# BOL                 Bolivia
# CZE          Czech Republic
# TWN                  Taiwan
# GBR          United Kingdom
# USA           United States
#
#                                                       name alpha-2  \
# alpha-3
# ARG                                              Argentina      AR
# AUS                                              Australia      AU
# AUT                                                Austria      AT
# BEL                                                Belgium      BE
# BRA                                                 Brazil      BR
# CAN                                                 Canada      CA
# CHL                                                  Chile      CL
# COL                                               Colombia      CO
# CRI                                             Costa Rica      CR
# DNK                                                Denmark      DK
# DOM                                     Dominican Republic      DO
# ECU                                                Ecuador      EC
# SLV                                            El Salvador      SV
# FIN                                                Finland      FI
# FRA                                                 France      FR
# DEU                                                Germany      DE
# GRC                                                 Greece      GR
# GTM                                              Guatemala      GT
# HND                                               Honduras      HN
# HKG                                              Hong Kong      HK
# HUN                                                Hungary      HU
# ISL                                                Iceland      IS
# IDN                                              Indonesia      ID
# IRL                                                Ireland      IE
# ITA                                                  Italy      IT
# JPN                                                  Japan      JP
# MYS                                               Malaysia      MY
# MEX                                                 Mexico      MX
# NLD                                            Netherlands      NL
# NZL                                            New Zealand      NZ
# NOR                                                 Norway      NO
# PAN                                                 Panama      PA
# PRY                                               Paraguay      PY
# PER                                                   Peru      PE
# PHL                                            Philippines      PH
# POL                                                 Poland      PL
# PRT                                               Portugal      PT
# SGP                                              Singapore      SG
# SVK                                               Slovakia      SK
# ESP                                                  Spain      ES
# SWE                                                 Sweden      SE
# CHE                                            Switzerland      CH
# TUR                                                 Turkey      TR
# URY                                                Uruguay      UY
# BOL                       Bolivia (Plurinational State of)      BO
# CZE                                                Czechia      CZ
# TWN                              Taiwan, Province of China      TW
# GBR      United Kingdom of Great Britain and Northern I...      GB
# USA                               United States of America      US
#
#          country-code     iso_3166-2    region  \
# alpha-3
# ARG                32  ISO 3166-2:AR  Americas
# AUS                36  ISO 3166-2:AU   Oceania
# AUT                40  ISO 3166-2:AT    Europe
# BEL                56  ISO 3166-2:BE    Europe
# BRA                76  ISO 3166-2:BR  Americas
# CAN               124  ISO 3166-2:CA  Americas
# CHL               152  ISO 3166-2:CL  Americas
# COL               170  ISO 3166-2:CO  Americas
# CRI               188  ISO 3166-2:CR  Americas
# DNK               208  ISO 3166-2:DK    Europe
# DOM               214  ISO 3166-2:DO  Americas
# ECU               218  ISO 3166-2:EC  Americas
# SLV               222  ISO 3166-2:SV  Americas
# FIN               246  ISO 3166-2:FI    Europe
# FRA               250  ISO 3166-2:FR    Europe
# DEU               276  ISO 3166-2:DE    Europe
# GRC               300  ISO 3166-2:GR    Europe
# GTM               320  ISO 3166-2:GT  Americas
# HND               340  ISO 3166-2:HN  Americas
# HKG               344  ISO 3166-2:HK      Asia
# HUN               348  ISO 3166-2:HU    Europe
# ISL               352  ISO 3166-2:IS    Europe
# IDN               360  ISO 3166-2:ID      Asia
# IRL               372  ISO 3166-2:IE    Europe
# ITA               380  ISO 3166-2:IT    Europe
# JPN               392  ISO 3166-2:JP      Asia
# MYS               458  ISO 3166-2:MY      Asia
# MEX               484  ISO 3166-2:MX  Americas
# NLD               528  ISO 3166-2:NL    Europe
# NZL               554  ISO 3166-2:NZ   Oceania
# NOR               578  ISO 3166-2:NO    Europe
# PAN               591  ISO 3166-2:PA  Americas
# PRY               600  ISO 3166-2:PY  Americas
# PER               604  ISO 3166-2:PE  Americas
# PHL               608  ISO 3166-2:PH      Asia
# POL               616  ISO 3166-2:PL    Europe
# PRT               620  ISO 3166-2:PT    Europe
# SGP               702  ISO 3166-2:SG      Asia
# SVK               703  ISO 3166-2:SK    Europe
# ESP               724  ISO 3166-2:ES    Europe
# SWE               752  ISO 3166-2:SE    Europe
# CHE               756  ISO 3166-2:CH    Europe
# TUR               792  ISO 3166-2:TR      Asia
# URY               858  ISO 3166-2:UY  Americas
# BOL                68  ISO 3166-2:BO  Americas
# CZE               203  ISO 3166-2:CZ    Europe
# TWN               158  ISO 3166-2:TW      Asia
# GBR               826  ISO 3166-2:GB    Europe
# USA               840  ISO 3166-2:US  Americas
#
#                               sub-region intermediate-region  region-code  \
# alpha-3
# ARG      Latin America and the Caribbean       South America         19.0
# AUS            Australia and New Zealand                 NaN          9.0
# AUT                       Western Europe                 NaN        150.0
# BEL                       Western Europe                 NaN        150.0
# BRA      Latin America and the Caribbean       South America         19.0
# CAN                     Northern America                 NaN         19.0
# CHL      Latin America and the Caribbean       South America         19.0
# COL      Latin America and the Caribbean       South America         19.0
# CRI      Latin America and the Caribbean     Central America         19.0
# DNK                      Northern Europe                 NaN        150.0
# DOM      Latin America and the Caribbean           Caribbean         19.0
# ECU      Latin America and the Caribbean       South America         19.0
# SLV      Latin America and the Caribbean     Central America         19.0
# FIN                      Northern Europe                 NaN        150.0
# FRA                       Western Europe                 NaN        150.0
# DEU                       Western Europe                 NaN        150.0
# GRC                      Southern Europe                 NaN        150.0
# GTM      Latin America and the Caribbean     Central America         19.0
# HND      Latin America and the Caribbean     Central America         19.0
# HKG                         Eastern Asia                 NaN        142.0
# HUN                       Eastern Europe                 NaN        150.0
# ISL                      Northern Europe                 NaN        150.0
# IDN                   South-eastern Asia                 NaN        142.0
# IRL                      Northern Europe                 NaN        150.0
# ITA                      Southern Europe                 NaN        150.0
# JPN                         Eastern Asia                 NaN        142.0
# MYS                   South-eastern Asia                 NaN        142.0
# MEX      Latin America and the Caribbean     Central America         19.0
# NLD                       Western Europe                 NaN        150.0
# NZL            Australia and New Zealand                 NaN          9.0
# NOR                      Northern Europe                 NaN        150.0
# PAN      Latin America and the Caribbean     Central America         19.0
# PRY      Latin America and the Caribbean       South America         19.0
# PER      Latin America and the Caribbean       South America         19.0
# PHL                   South-eastern Asia                 NaN        142.0
# POL                       Eastern Europe                 NaN        150.0
# PRT                      Southern Europe                 NaN        150.0
# SGP                   South-eastern Asia                 NaN        142.0
# SVK                       Eastern Europe                 NaN        150.0
# ESP                      Southern Europe                 NaN        150.0
# SWE                      Northern Europe                 NaN        150.0
# CHE                       Western Europe                 NaN        150.0
# TUR                         Western Asia                 NaN        142.0
# URY      Latin America and the Caribbean       South America         19.0
# BOL      Latin America and the Caribbean       South America         19.0
# CZE                       Eastern Europe                 NaN        150.0
# TWN                         Eastern Asia                 NaN        142.0
# GBR                      Northern Europe                 NaN        150.0
# USA                     Northern America                 NaN         19.0
#
#          sub-region-code  intermediate-region-code
# alpha-3
# ARG                419.0                       5.0
# AUS                 53.0                       NaN
# AUT                155.0                       NaN
# BEL                155.0                       NaN
# BRA                419.0                       5.0
# CAN                 21.0                       NaN
# CHL                419.0                       5.0
# COL                419.0                       5.0
# CRI                419.0                      13.0
# DNK                154.0                       NaN
# DOM                419.0                      29.0
# ECU                419.0                       5.0
# SLV                419.0                      13.0
# FIN                154.0                       NaN
# FRA                155.0                       NaN
# DEU                155.0                       NaN
# GRC                 39.0                       NaN
# GTM                419.0                      13.0
# HND                419.0                      13.0
# HKG                 30.0                       NaN
# HUN                151.0                       NaN
# ISL                154.0                       NaN
# IDN                 35.0                       NaN
# IRL                154.0                       NaN
# ITA                 39.0                       NaN
# JPN                 30.0                       NaN
# MYS                 35.0                       NaN
# MEX                419.0                      13.0
# NLD                155.0                       NaN
# NZL                 53.0                       NaN
# NOR                154.0                       NaN
# PAN                419.0                      13.0
# PRY                419.0                       5.0
# PER                419.0                       5.0
# PHL                 35.0                       NaN
# POL                151.0                       NaN
# PRT                 39.0                       NaN
# SGP                 35.0                       NaN
# SVK                151.0                       NaN
# ESP                 39.0                       NaN
# SWE                154.0                       NaN
# CHE                155.0                       NaN
# TUR                145.0                       NaN
# URY                419.0                       5.0
# BOL                419.0                       5.0
# CZE                151.0                       NaN
# TWN                 30.0                       NaN
# GBR                154.0                       NaN
# USA                 21.0                       NaN

# %% [markdown]
# Wow, that was painful.

# %%
spotify_country_iso_data.columns
# Out:
# Index(['spotify_region', 'name', 'alpha-2', 'country-code', 'iso_3166-2',
#        'region', 'sub-region', 'intermediate-region', 'region-code',
#        'sub-region-code', 'intermediate-region-code'],
#       dtype='object')

# %%
spotify_country_iso_data = spotify_country_iso_data.reset_index()[
    ["spotify_region", "alpha-3", "alpha-2", "region", "sub-region"]
].rename(
    columns={
        "alpha-3": "iso_alpha3",
        "alpha-2": "iso_alpha2",
        "region": "geo_region",
        "sub-region": "geo_subregion",
    }
)
spotify_country_iso_data
# Out:
#         spotify_region iso_alpha3 iso_alpha2 geo_region  \
# 0            Argentina        ARG         AR   Americas
# 1            Australia        AUS         AU    Oceania
# 2              Austria        AUT         AT     Europe
# 3              Belgium        BEL         BE     Europe
# 4               Brazil        BRA         BR   Americas
# 5               Canada        CAN         CA   Americas
# 6                Chile        CHL         CL   Americas
# 7             Colombia        COL         CO   Americas
# 8           Costa Rica        CRI         CR   Americas
# 9              Denmark        DNK         DK     Europe
# 10  Dominican Republic        DOM         DO   Americas
# 11             Ecuador        ECU         EC   Americas
# 12         El Salvador        SLV         SV   Americas
# 13             Finland        FIN         FI     Europe
# 14              France        FRA         FR     Europe
# 15             Germany        DEU         DE     Europe
# 16              Greece        GRC         GR     Europe
# 17           Guatemala        GTM         GT   Americas
# 18            Honduras        HND         HN   Americas
# 19           Hong Kong        HKG         HK       Asia
# 20             Hungary        HUN         HU     Europe
# 21             Iceland        ISL         IS     Europe
# 22           Indonesia        IDN         ID       Asia
# 23             Ireland        IRL         IE     Europe
# 24               Italy        ITA         IT     Europe
# 25               Japan        JPN         JP       Asia
# 26            Malaysia        MYS         MY       Asia
# 27              Mexico        MEX         MX   Americas
# 28         Netherlands        NLD         NL     Europe
# 29         New Zealand        NZL         NZ    Oceania
# 30              Norway        NOR         NO     Europe
# 31              Panama        PAN         PA   Americas
# 32            Paraguay        PRY         PY   Americas
# 33                Peru        PER         PE   Americas
# 34         Philippines        PHL         PH       Asia
# 35              Poland        POL         PL     Europe
# 36            Portugal        PRT         PT     Europe
# 37           Singapore        SGP         SG       Asia
# 38            Slovakia        SVK         SK     Europe
# 39               Spain        ESP         ES     Europe
# 40              Sweden        SWE         SE     Europe
# 41         Switzerland        CHE         CH     Europe
# 42              Turkey        TUR         TR       Asia
# 43             Uruguay        URY         UY   Americas
# 44             Bolivia        BOL         BO   Americas
# 45      Czech Republic        CZE         CZ     Europe
# 46              Taiwan        TWN         TW       Asia
# 47      United Kingdom        GBR         GB     Europe
# 48       United States        USA         US   Americas
#
#                       geo_subregion
# 0   Latin America and the Caribbean
# 1         Australia and New Zealand
# 2                    Western Europe
# 3                    Western Europe
# 4   Latin America and the Caribbean
# 5                  Northern America
# 6   Latin America and the Caribbean
# 7   Latin America and the Caribbean
# 8   Latin America and the Caribbean
# 9                   Northern Europe
# 10  Latin America and the Caribbean
# 11  Latin America and the Caribbean
# 12  Latin America and the Caribbean
# 13                  Northern Europe
# 14                   Western Europe
# 15                   Western Europe
# 16                  Southern Europe
# 17  Latin America and the Caribbean
# 18  Latin America and the Caribbean
# 19                     Eastern Asia
# 20                   Eastern Europe
# 21                  Northern Europe
# 22               South-eastern Asia
# 23                  Northern Europe
# 24                  Southern Europe
# 25                     Eastern Asia
# 26               South-eastern Asia
# 27  Latin America and the Caribbean
# 28                   Western Europe
# 29        Australia and New Zealand
# 30                  Northern Europe
# 31  Latin America and the Caribbean
# 32  Latin America and the Caribbean
# 33  Latin America and the Caribbean
# 34               South-eastern Asia
# 35                   Eastern Europe
# 36                  Southern Europe
# 37               South-eastern Asia
# 38                   Eastern Europe
# 39                  Southern Europe
# 40                  Northern Europe
# 41                   Western Europe
# 42                     Western Asia
# 43  Latin America and the Caribbean
# 44  Latin America and the Caribbean
# 45                   Eastern Europe
# 46                     Eastern Asia
# 47                  Northern Europe
# 48                 Northern America

# %% [markdown]
# ## Export data

# %%
spotify_country_iso_data.to_csv(create_data_out_path("spotify_region_metadata.csv"), index=False)
# Out:
# Data output path: /home/sejmou/Repos/Uni/VisDS/vis-ds/data/spotify_region_metadata.csv
