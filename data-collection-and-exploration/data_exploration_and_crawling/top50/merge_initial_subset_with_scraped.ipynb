# %% [markdown]
# # Merging the (incomplete) Top 50 subset of initial Chart dataset with additional scraped data

# %% [markdown]
# In this document, I combine the "almost complete" Top 50 subset of the initial Spotify Charts [Kaggle dataset](https://www.kaggle.com/datasets/dhruvildave/spotify-charts) (including data for the 50 countries with best "data coverage", stored in `top50_almost_complete.csv`) with the additional data I scraped for the incomplete entries of that dataset using the scripts in `data_crawling`. The endresult is a more complete and cleaned `top50.csv` dataset of daily Top 50 charts for 50 countries.
#
# Note that even this "final" dataset has some missing values as Spotify just doesn't provide complete charts for every day and every country (see also the missing data plot below for more insights).

# %%
import pandas as pd
from helpers import get_data_path, create_data_out_path, split_dataframe
import os
import re
from difflib import get_close_matches
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scraped_data_folder_path = get_data_path("scraped_chart_data")
scraped_files = os.listdir(scraped_data_folder_path)
len(scraped_files)
# Out:
# 2115

# %% [markdown]
# ## Mapping region codes to region names from existing dataset

# %%
country_iso_codes = pd.read_csv(
    get_data_path(
        "iso_codes.csv",
        download_url="https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv",
    ),
)[["name", "alpha-2"]]
country_iso_codes["alpha-2"] = country_iso_codes["alpha-2"].str.lower()
country_iso_codes
# Out:
#                   name alpha-2
# 0          Afghanistan      af
# 1        Åland Islands      ax
# 2              Albania      al
# 3              Algeria      dz
# 4       American Samoa      as
# ..                 ...     ...
# 244  Wallis and Futuna      wf
# 245     Western Sahara      eh
# 246              Yemen      ye
# 247             Zambia      zm
# 248           Zimbabwe      zw
#
# [249 rows x 2 columns]

# %%
def extract_region_code(file_name: str):
    return re.search(r"\-([a-z]*)\-", file_name).groups()[0]


region_codes_in_data = pd.Series(
    list(set([extract_region_code(fname) for fname in scraped_files])), name="alpha-2"
)
region_codes_in_data
# Out:
# 0     global
# 1         tr
# 2         pe
# 3         hk
# 4         cz
# 5         ec
# 6         sv
# 7         bo
# 8         tw
# 9         gt
# 10        id
# 11        ar
# 12        ch
# 13        es
# 14        nz
# 15        gb
# 16        ie
# 17        pl
# 18        at
# 19        cl
# 20        ph
# 21        sk
# 22        no
# 23        do
# 24        sg
# 25        my
# 26        mx
# 27        be
# 28        cr
# 29        de
# 30        pa
# 31        is
# 32        fi
# 33        nl
# 34        us
# 35        co
# 36        hn
# 37        fr
# 38        se
# 39        dk
# 40        pt
# 41        uy
# 42        gr
# 43        br
# 44        ca
# 45        it
# 46        jp
# 47        au
# 48        py
# 49        hu
# Name: alpha-2, dtype: object

# %%
codes_and_names = pd.merge(region_codes_in_data, country_iso_codes, how="left").rename(
    columns={"alpha-2": "code", "name": "country_name"}
)
codes_and_names.loc[codes_and_names.code == "global", "country_name"] = "Global"
codes_and_names
# Out:
#       code                                       country_name
# 0   global                                             Global
# 1       tr                                             Turkey
# 2       pe                                               Peru
# 3       hk                                          Hong Kong
# 4       cz                                            Czechia
# 5       ec                                            Ecuador
# 6       sv                                        El Salvador
# 7       bo                   Bolivia (Plurinational State of)
# 8       tw                          Taiwan, Province of China
# 9       gt                                          Guatemala
# 10      id                                          Indonesia
# 11      ar                                          Argentina
# 12      ch                                        Switzerland
# 13      es                                              Spain
# 14      nz                                        New Zealand
# 15      gb  United Kingdom of Great Britain and Northern I...
# 16      ie                                            Ireland
# 17      pl                                             Poland
# 18      at                                            Austria
# 19      cl                                              Chile
# 20      ph                                        Philippines
# 21      sk                                           Slovakia
# 22      no                                             Norway
# 23      do                                 Dominican Republic
# 24      sg                                          Singapore
# 25      my                                           Malaysia
# 26      mx                                             Mexico
# 27      be                                            Belgium
# 28      cr                                         Costa Rica
# 29      de                                            Germany
# 30      pa                                             Panama
# 31      is                                            Iceland
# 32      fi                                            Finland
# 33      nl                                        Netherlands
# 34      us                           United States of America
# 35      co                                           Colombia
# 36      hn                                           Honduras
# 37      fr                                             France
# 38      se                                             Sweden
# 39      dk                                            Denmark
# 40      pt                                           Portugal
# 41      uy                                            Uruguay
# 42      gr                                             Greece
# 43      br                                             Brazil
# 44      ca                                             Canada
# 45      it                                              Italy
# 46      jp                                              Japan
# 47      au                                          Australia
# 48      py                                           Paraguay
# 49      hu                                            Hungary

# %%
existing_data = pd.read_csv(
    get_data_path(
        "top50_almost_complete.csv",
    ),
)

# %%
all_region_names = list(existing_data.region.drop_duplicates())
all_region_names
# Out:
# ['Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Colombia',
#  'Bolivia',
#  'Brazil',
#  'Canada',
#  'Denmark',
#  'Chile',
#  'Costa Rica',
#  'Czech Republic',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Finland',
#  'France',
#  'Germany',
#  'Global',
#  'Greece',
#  'Guatemala',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'Indonesia',
#  'Ireland',
#  'Italy',
#  'Japan',
#  'Malaysia',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Singapore',
#  'Slovakia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Turkey',
#  'United Kingdom',
#  'United States',
#  'Uruguay']

# %%
# join using fuzzy matching
def get_close_match_if_exists(country_name):
    matches = get_close_matches(country_name, all_region_names)
    if len(matches) > 0:
        return matches[0]
    else:
        return None


codes_and_names["region_name"] = codes_and_names["country_name"].apply(
    get_close_match_if_exists
)
codes_and_names
# Out:
#       code                                       country_name  \
# 0   global                                             Global
# 1       tr                                             Turkey
# 2       pe                                               Peru
# 3       hk                                          Hong Kong
# 4       cz                                            Czechia
# 5       ec                                            Ecuador
# 6       sv                                        El Salvador
# 7       bo                   Bolivia (Plurinational State of)
# 8       tw                          Taiwan, Province of China
# 9       gt                                          Guatemala
# 10      id                                          Indonesia
# 11      ar                                          Argentina
# 12      ch                                        Switzerland
# 13      es                                              Spain
# 14      nz                                        New Zealand
# 15      gb  United Kingdom of Great Britain and Northern I...
# 16      ie                                            Ireland
# 17      pl                                             Poland
# 18      at                                            Austria
# 19      cl                                              Chile
# 20      ph                                        Philippines
# 21      sk                                           Slovakia
# 22      no                                             Norway
# 23      do                                 Dominican Republic
# 24      sg                                          Singapore
# 25      my                                           Malaysia
# 26      mx                                             Mexico
# 27      be                                            Belgium
# 28      cr                                         Costa Rica
# 29      de                                            Germany
# 30      pa                                             Panama
# 31      is                                            Iceland
# 32      fi                                            Finland
# 33      nl                                        Netherlands
# 34      us                           United States of America
# 35      co                                           Colombia
# 36      hn                                           Honduras
# 37      fr                                             France
# 38      se                                             Sweden
# 39      dk                                            Denmark
# 40      pt                                           Portugal
# 41      uy                                            Uruguay
# 42      gr                                             Greece
# 43      br                                             Brazil
# 44      ca                                             Canada
# 45      it                                              Italy
# 46      jp                                              Japan
# 47      au                                          Australia
# 48      py                                           Paraguay
# 49      hu                                            Hungary
#
#            region_name
# 0               Global
# 1               Turkey
# 2                 Peru
# 3            Hong Kong
# 4                 None
# 5              Ecuador
# 6          El Salvador
# 7                 None
# 8                 None
# 9            Guatemala
# 10           Indonesia
# 11           Argentina
# 12         Switzerland
# 13               Spain
# 14         New Zealand
# 15                None
# 16             Ireland
# 17              Poland
# 18             Austria
# 19               Chile
# 20         Philippines
# 21            Slovakia
# 22              Norway
# 23  Dominican Republic
# 24           Singapore
# 25            Malaysia
# 26              Mexico
# 27             Belgium
# 28          Costa Rica
# 29             Germany
# 30              Panama
# 31             Iceland
# 32             Finland
# 33         Netherlands
# 34       United States
# 35            Colombia
# 36            Honduras
# 37              France
# 38              Sweden
# 39             Denmark
# 40            Portugal
# 41             Uruguay
# 42              Greece
# 43              Brazil
# 44              Canada
# 45               Italy
# 46               Japan
# 47           Australia
# 48            Paraguay
# 49             Hungary

# %%
codes_and_names.loc[codes_and_names.region_name.isna()]
# Out:
#    code                                       country_name region_name
# 4    cz                                            Czechia        None
# 7    bo                   Bolivia (Plurinational State of)        None
# 8    tw                          Taiwan, Province of China        None
# 15   gb  United Kingdom of Great Britain and Northern I...        None

# %%
missing_mappings = [
    ("tw", "Taiwan"),
    ("cz", "Czech Republic"),
    ("bo", "Bolivia"),
    ("gb", "United Kingdom"),
]
for (code, region_name) in missing_mappings:
    codes_and_names.loc[codes_and_names.code == code, "region_name"] = region_name

region_code_to_name = (
    codes_and_names.merge(
        pd.Series(all_region_names, name="region_name"), on="region_name"
    )[["code", "region_name"]]
    .rename(columns={"region_name": "name"})
    .set_index("code")
)
len(region_code_to_name) == len(all_region_names)
# Out:
# True

# %%
region_code_to_name = region_code_to_name["name"]
region_code_to_name
# Out:
# code
# global                Global
# tr                    Turkey
# pe                      Peru
# hk                 Hong Kong
# cz            Czech Republic
# ec                   Ecuador
# sv               El Salvador
# bo                   Bolivia
# tw                    Taiwan
# gt                 Guatemala
# id                 Indonesia
# ar                 Argentina
# ch               Switzerland
# es                     Spain
# nz               New Zealand
# gb            United Kingdom
# ie                   Ireland
# pl                    Poland
# at                   Austria
# cl                     Chile
# ph               Philippines
# sk                  Slovakia
# no                    Norway
# do        Dominican Republic
# sg                 Singapore
# my                  Malaysia
# mx                    Mexico
# be                   Belgium
# cr                Costa Rica
# de                   Germany
# pa                    Panama
# is                   Iceland
# fi                   Finland
# nl               Netherlands
# us             United States
# co                  Colombia
# hn                  Honduras
# fr                    France
# se                    Sweden
# dk                   Denmark
# pt                  Portugal
# uy                   Uruguay
# gr                    Greece
# br                    Brazil
# ca                    Canada
# it                     Italy
# jp                     Japan
# au                 Australia
# py                  Paraguay
# hu                   Hungary
# Name: name, dtype: object

# %% [markdown]
# ## Create final cleaned dataset

# %% [markdown]
# Let's look at our existing data first:

# %%
existing_data
# Out:
#                                         title  rank        date  \
# 0                     Chantaje (feat. Maluma)     1  2017-01-01
# 1                 Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                  Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                      Safari     4  2017-01-01
# 4                                 Shaky Shaky     5  2017-01-01
# ...                                       ...   ...         ...
# 4477827           Explícale (feat. Bad Bunny)    46  2018-01-31
# 4477828  Nena Maldicion (feat. Lenny Tavarez)    47  2018-01-31
# 4477829                            Ahora Dice    48  2018-01-31
# 4477830         La fórmula (feat. Chris Jedi)    49  2018-01-31
# 4477831                              Mi Gente    50  2018-01-31
#
#                                         artist  \
# 0                                      Shakira
# 1                                 Ricky Martin
# 2                                         CNCO
# 3        J Balvin, Pharrell Williams, BIA, Sky
# 4                                 Daddy Yankee
# ...                                        ...
# 4477827                                 Yandel
# 4477828            Paulo Londra, Lenny Tavárez
# 4477829  Chris Jedi, J Balvin, Ozuna, Arcangel
# 4477830      De La Ghetto, Daddy Yankee, Ozuna
# 4477831                J Balvin, Willy William
#
#                                                        url     region  \
# 0        https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina
# 1        https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina
# 2        https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina
# 3        https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina
# 4        https://open.spotify.com/track/58IL315gMSTD37D...  Argentina
# ...                                                    ...        ...
# 4477827  https://open.spotify.com/track/1LszjjoVwDDZcWU...    Uruguay
# 4477828  https://open.spotify.com/track/3TnhQSRwT3AVMdX...    Uruguay
# 4477829  https://open.spotify.com/track/22eADXu8DfOAUED...    Uruguay
# 4477830  https://open.spotify.com/track/4XCQtUoRSh22Ep1...    Uruguay
# 4477831  https://open.spotify.com/track/2rb5MvYT7ZIxbKW...    Uruguay
#
#                  trend   streams
# 0        SAME_POSITION  253019.0
# 1              MOVE_UP  223988.0
# 2            MOVE_DOWN  210943.0
# 3        SAME_POSITION  173865.0
# 4              MOVE_UP  153956.0
# ...                ...       ...
# 4477827      MOVE_DOWN    4560.0
# 4477828        MOVE_UP    4406.0
# 4477829  SAME_POSITION    4316.0
# 4477830  SAME_POSITION    4272.0
# 4477831  SAME_POSITION    4142.0
#
# [4477832 rows x 8 columns]

# %% [markdown]
# Let's drop the trend column. It's computable from the data anyway!

# %%
existing_data.drop(columns="trend", inplace=True)

# %%
existing_data.artist
# Out:
# 0                                        Shakira
# 1                                   Ricky Martin
# 2                                           CNCO
# 3          J Balvin, Pharrell Williams, BIA, Sky
# 4                                   Daddy Yankee
#                            ...
# 4477827                                   Yandel
# 4477828              Paulo Londra, Lenny Tavárez
# 4477829    Chris Jedi, J Balvin, Ozuna, Arcangel
# 4477830        De La Ghetto, Daddy Yankee, Ozuna
# 4477831                  J Balvin, Willy William
# Name: artist, Length: 4477832, dtype: object

# %% [markdown]
# The scraped data contains only track URIs.
# For example: `spotify:track:2rb5MvYT7ZIxbKW5hfcHx8`
#
# It would be convenient if the existing data also just used them instead of full Spotify song links.

# %% [markdown]
# What's the format of the URLs in the existing data?

# %%
existing_data.url[0]
# Out:
# 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'

# %%
def convert_to_uri(track_url: str):
    return track_url.replace("https://open.spotify.com/track/", "spotify:track:")


convert_to_uri(existing_data.url[0])
# Out:
# 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg'

# %% [markdown]
# Just make sure the URIs have equal length:

# %%
len(convert_to_uri(existing_data.url[0])) == len("spotify:track:2rb5MvYT7ZIxbKW5hfcHx8")
# Out:
# True

# %%
existing_data["uri"] = existing_data.url.apply(convert_to_uri)
existing_data.drop(columns="url", inplace=True)

# %%
existing_data
# Out:
#                                         title  rank        date  \
# 0                     Chantaje (feat. Maluma)     1  2017-01-01
# 1                 Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                  Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                      Safari     4  2017-01-01
# 4                                 Shaky Shaky     5  2017-01-01
# ...                                       ...   ...         ...
# 4477827           Explícale (feat. Bad Bunny)    46  2018-01-31
# 4477828  Nena Maldicion (feat. Lenny Tavarez)    47  2018-01-31
# 4477829                            Ahora Dice    48  2018-01-31
# 4477830         La fórmula (feat. Chris Jedi)    49  2018-01-31
# 4477831                              Mi Gente    50  2018-01-31
#
#                                         artist     region   streams  \
# 0                                      Shakira  Argentina  253019.0
# 1                                 Ricky Martin  Argentina  223988.0
# 2                                         CNCO  Argentina  210943.0
# 3        J Balvin, Pharrell Williams, BIA, Sky  Argentina  173865.0
# 4                                 Daddy Yankee  Argentina  153956.0
# ...                                        ...        ...       ...
# 4477827                                 Yandel    Uruguay    4560.0
# 4477828            Paulo Londra, Lenny Tavárez    Uruguay    4406.0
# 4477829  Chris Jedi, J Balvin, Ozuna, Arcangel    Uruguay    4316.0
# 4477830      De La Ghetto, Daddy Yankee, Ozuna    Uruguay    4272.0
# 4477831                J Balvin, Willy William    Uruguay    4142.0
#
#                                           uri
# 0        spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1        spotify:track:7DM4BPaS7uofFul3ywMe46
# 2        spotify:track:3AEZUABDXNtecAOSC1qTfo
# 3        spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 4        spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                                       ...
# 4477827  spotify:track:1LszjjoVwDDZcWUQbzeDLG
# 4477828  spotify:track:3TnhQSRwT3AVMdXw5JPq0x
# 4477829  spotify:track:22eADXu8DfOAUEDw4vU8qy
# 4477830  spotify:track:4XCQtUoRSh22Ep18ULmDnT
# 4477831  spotify:track:2rb5MvYT7ZIxbKW5hfcHx8
#
# [4477832 rows x 7 columns]

# %% [markdown]
# ### process new scraped files

# %%
dfs = []

# %%
def extract_date(file_name: str):
    date = re.search(r"[0-9][0-9][0-9][0-9]-[0-9][0-9]-[0-9][0-9]", file_name).group()
    return date


# example
extract_date(scraped_files[0])
# Out:
# '2021-12-13'

# %%
incomplete_data = []


def create_df_in_format_of_existing_data(file_name):
    data = pd.read_csv(
        get_data_path(os.path.join(scraped_data_folder_path, file_name))
    ).rename(columns={"track_name": "title", "artist_names": "artist"})
    r_code = extract_region_code(file_name)
    r_name = region_code_to_name[r_code]
    data["region"] = r_name
    date = extract_date(file_name)
    data["date"] = date
    data = data[existing_data.columns]

    # keep only top 50
    data = data.loc[data["rank"] <= 50]
    track_count = len(data)
    if track_count < 50:
        incomplete_data.append((r_name, date, file_name, track_count))
    return data


new_data = pd.concat(
    [create_df_in_format_of_existing_data(file_name) for file_name in scraped_files]
)
new_data
# Out:
#              title  rank        date               artist region  streams  \
# 0           ベテルギウス     1  2021-12-13                Yuuri  Japan   215005
# 1          ドライフラワー     2  2021-12-13                Yuuri  Japan   206931
# 2             残響散歌     3  2021-12-13                Aimer  Japan   206079
# 3               一途     4  2021-12-13             King Gnu  Japan   201641
# 4         なんでもないよ、     5  2021-12-13     Macaroni Empitsu  Japan   187740
# ..             ...   ...         ...                  ...    ...      ...
# 45           PORFA    46  2020-10-08  Feid, Justin Quiles  Chile    73584
# 46            Lean    47  2020-10-08          Mike Caride  Chile    73246
# 47      La Difícil    48  2020-10-08            Bad Bunny  Chile    71215
# 48  Yo Perreo Sola    49  2020-10-08            Bad Bunny  Chile    68428
# 49      Ignorantes    50  2020-10-08      Bad Bunny, Sech  Chile    65964
#
#                                      uri
# 0   spotify:track:2sf18cEv463VgqmdjDsFpw
# 1   spotify:track:7dH0dpi751EoguDDg3xx6J
# 2   spotify:track:7v8wKvNQQIxkugCFFjrkaO
# 3   spotify:track:7ncPjJBktLEOpstY5JOUMK
# 4   spotify:track:2PFzK3kMDDYKhGnugvNYf1
# ..                                   ...
# 45  spotify:track:4TOmcZvw0gHa7GiXRbcYAW
# 46  spotify:track:5DoLhdU27owX1NMrKLUbUl
# 47  spotify:track:6NfrH0ANGmgBXyxgV2PeXt
# 48  spotify:track:0SqqAgdovOE24BzxIClpjw
# 49  spotify:track:38RIEav39FGi86jppxO0du
#
# [104575 rows x 7 columns]

# %%
incomplete_data = pd.DataFrame(
    incomplete_data, columns=["region", "date", "file_name", "track_count"]
).set_index(["region", "date"])
incomplete_data
# Out:
#                                                    file_name  track_count
# region      date
# Switzerland 2017-12-07      regional-ch-daily-2017-12-07.csv           46
# Austria     2017-12-14      regional-at-daily-2017-12-14.csv           49
# Slovakia    2017-01-04      regional-sk-daily-2017-01-04.csv           43
# Panama      2021-08-13      regional-pa-daily-2021-08-13.csv           49
# Bolivia     2017-11-11      regional-bo-daily-2017-11-11.csv           49
# ...                                                      ...          ...
# Austria     2017-12-08      regional-at-daily-2017-12-08.csv           47
# Global      2017-11-12  regional-global-daily-2017-11-12.csv           49
# Denmark     2017-07-21      regional-dk-daily-2017-07-21.csv           48
# Switzerland 2017-12-02      regional-ch-daily-2017-12-02.csv           39
# Germany     2017-12-07      regional-de-daily-2017-12-07.csv           33
#
# [401 rows x 2 columns]

# %%
track_counts_new_data = incomplete_data.track_count

# %%
new_vs_existing = incomplete_data.join(
    track_counts_new_data, how="left", lsuffix="_new", rsuffix="_existing"
)
new_vs_existing
# Out:
#                                                    file_name  track_count_new  \
# region      date
# Switzerland 2017-12-07      regional-ch-daily-2017-12-07.csv               46
# Austria     2017-12-14      regional-at-daily-2017-12-14.csv               49
# Slovakia    2017-01-04      regional-sk-daily-2017-01-04.csv               43
# Panama      2021-08-13      regional-pa-daily-2021-08-13.csv               49
# Bolivia     2017-11-11      regional-bo-daily-2017-11-11.csv               49
# ...                                                      ...              ...
# Austria     2017-12-08      regional-at-daily-2017-12-08.csv               47
# Global      2017-11-12  regional-global-daily-2017-11-12.csv               49
# Denmark     2017-07-21      regional-dk-daily-2017-07-21.csv               48
# Switzerland 2017-12-02      regional-ch-daily-2017-12-02.csv               39
# Germany     2017-12-07      regional-de-daily-2017-12-07.csv               33
#
#                         track_count_existing
# region      date
# Switzerland 2017-12-07                    46
# Austria     2017-12-14                    49
# Slovakia    2017-01-04                    43
# Panama      2021-08-13                    49
# Bolivia     2017-11-11                    49
# ...                                      ...
# Austria     2017-12-08                    47
# Global      2017-11-12                    49
# Denmark     2017-07-21                    48
# Switzerland 2017-12-02                    39
# Germany     2017-12-07                    33
#
# [401 rows x 3 columns]

# %%
new_vs_existing.loc[
    new_vs_existing.track_count_new > new_vs_existing.track_count_existing
]
# Out:
# Empty DataFrame
# Columns: [file_name, track_count_new, track_count_existing]
# Index: []

# %% [markdown]
# That's sad! For 401 rows it looks like Spotify just doesn't provide better data than the data we already have.
#
# I guess we'll have to live with that.

# %%
1 - len(incomplete_data) / len(new_data)
# Out:
# 0.9961654315084867

# %% [markdown]
# Still, as we see above, we managed to get complete data for 99.5% of the other cases where we didn't have data before!

# %%
existing_data.date = pd.to_datetime(existing_data.date)
existing_data["source"] = "existing"
new_data.date = pd.to_datetime(new_data.date)
new_data["source"] = "new"

# %%
combined_data = pd.concat(
    [
        existing_data.set_index(["region", "date"]),
        new_data.set_index(["region", "date"]),
    ]
).sort_index()
combined_data
# Out:
#                                                     title  rank  \
# region    date
# Argentina 2017-01-01              Chantaje (feat. Maluma)     1
#           2017-01-01          Vente Pa' Ca (feat. Maluma)     2
#           2017-01-01           Reggaetón Lento (Bailemos)     3
#           2017-01-01                               Safari     4
#           2017-01-01                          Shaky Shaky     5
# ...                                                   ...   ...
# Uruguay   2021-12-31                           Los Tragos    46
#           2021-12-31                                 Sabe    47
#           2021-12-31  Morad: Bzrp Music Sessions, Vol. 47    48
#           2021-12-31                           2:50 Remix    49
#           2021-12-31                               París    50
#
#                                                      artist   streams  \
# region    date
# Argentina 2017-01-01                                Shakira  253019.0
#           2017-01-01                           Ricky Martin  223988.0
#           2017-01-01                                   CNCO  210943.0
#           2017-01-01  J Balvin, Pharrell Williams, BIA, Sky  173865.0
#           2017-01-01                           Daddy Yankee  153956.0
# ...                                                     ...       ...
# Uruguay   2021-12-31                    Reik, Maria Becerra   10707.0
#           2021-12-31           Nicki Nicole, Rauw Alejandro   10635.0
#           2021-12-31                        Bizarrap, Morad   10491.0
#           2021-12-31                        MYA, TINI, Duki   10388.0
#           2021-12-31                               Ingratax   10137.0
#
#                                                        uri    source
# region    date
# Argentina 2017-01-01  spotify:track:6mICuAdrwEjh6Y6lroV2Kg  existing
#           2017-01-01  spotify:track:7DM4BPaS7uofFul3ywMe46  existing
#           2017-01-01  spotify:track:3AEZUABDXNtecAOSC1qTfo  existing
#           2017-01-01  spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  existing
#           2017-01-01  spotify:track:58IL315gMSTD37DOZPJ2hf  existing
# ...                                                    ...       ...
# Uruguay   2021-12-31  spotify:track:7iXJg4IUyrWont5YSQrbKP       new
#           2021-12-31  spotify:track:0XYZhJIcwKNjd0tjbSXwaQ       new
#           2021-12-31  spotify:track:39yyHtQ4tkjZzd8TfIBKQw       new
#           2021-12-31  spotify:track:5eyO0n1HiiSWdGaaSoK731       new
#           2021-12-31  spotify:track:4bF2y8rR7GUjrd5LNEvej3       new
#
# [4582407 rows x 6 columns]

# %%
len(combined_data)
# Out:
# 4582407

# %%
combined_data_filtered = combined_data.reset_index()
combined_data_filtered = combined_data_filtered.drop_duplicates(
    subset=combined_data_filtered.columns.difference(["source"])
)
combined_data_filtered = combined_data_filtered.set_index(["region", "date", "rank"])
combined_data_filtered
# Out:
#                                                          title  \
# region    date       rank
# Argentina 2017-01-01 1                 Chantaje (feat. Maluma)
#                      2             Vente Pa' Ca (feat. Maluma)
#                      3              Reggaetón Lento (Bailemos)
#                      4                                  Safari
#                      5                             Shaky Shaky
# ...                                                        ...
# Uruguay   2021-12-31 46                             Los Tragos
#                      47                                   Sabe
#                      48    Morad: Bzrp Music Sessions, Vol. 47
#                      49                             2:50 Remix
#                      50                                 París
#
#                                                           artist   streams  \
# region    date       rank
# Argentina 2017-01-01 1                                   Shakira  253019.0
#                      2                              Ricky Martin  223988.0
#                      3                                      CNCO  210943.0
#                      4     J Balvin, Pharrell Williams, BIA, Sky  173865.0
#                      5                              Daddy Yankee  153956.0
# ...                                                          ...       ...
# Uruguay   2021-12-31 46                      Reik, Maria Becerra   10707.0
#                      47             Nicki Nicole, Rauw Alejandro   10635.0
#                      48                          Bizarrap, Morad   10491.0
#                      49                          MYA, TINI, Duki   10388.0
#                      50                                 Ingratax   10137.0
#
#                                                             uri    source
# region    date       rank
# Argentina 2017-01-01 1     spotify:track:6mICuAdrwEjh6Y6lroV2Kg  existing
#                      2     spotify:track:7DM4BPaS7uofFul3ywMe46  existing
#                      3     spotify:track:3AEZUABDXNtecAOSC1qTfo  existing
#                      4     spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  existing
#                      5     spotify:track:58IL315gMSTD37DOZPJ2hf  existing
# ...                                                         ...       ...
# Uruguay   2021-12-31 46    spotify:track:7iXJg4IUyrWont5YSQrbKP       new
#                      47    spotify:track:0XYZhJIcwKNjd0tjbSXwaQ       new
#                      48    spotify:track:39yyHtQ4tkjZzd8TfIBKQw       new
#                      49    spotify:track:5eyO0n1HiiSWdGaaSoK731       new
#                      50    spotify:track:4bF2y8rR7GUjrd5LNEvej3       new
#
# [4569311 rows x 5 columns]

# %%
def count_new_vs_existing(df):
    return pd.Series(
        [(df.source == "new").sum(), (df.source == "existing").sum()],
        index=["track_count_new", "track_count_existing"],
    )

# %%
new_vs_existing = combined_data_filtered.groupby(["region", "date"]).apply(
    count_new_vs_existing
)
new_vs_existing
# Out:
#                       track_count_new  track_count_existing
# region    date
# Argentina 2017-01-01                0                    50
#           2017-01-02                0                    50
#           2017-01-03                0                    50
#           2017-01-04                0                    50
#           2017-01-05                0                    50
# ...                               ...                   ...
# Uruguay   2021-12-27               50                     0
#           2021-12-28               50                     0
#           2021-12-29               50                     0
#           2021-12-30               50                     0
#           2021-12-31               49                     0
#
# [91300 rows x 2 columns]

# %%
new_vs_existing.loc[
    (new_vs_existing.track_count_new != 0)
    & (new_vs_existing.track_count_existing != 0)
    & (new_vs_existing.track_count_existing != new_vs_existing.track_count_new)
]
# Out:
#                       track_count_new  track_count_existing
# region    date
# Argentina 2017-07-20               17                    49
#           2017-07-21               18                    49
#           2017-11-09               19                    49
#           2017-11-10               19                    49
#           2017-11-11               20                    49
# ...                               ...                   ...
# Uruguay   2017-11-14               18                    49
#           2021-08-10                8                    49
#           2021-08-11                8                    49
#           2021-08-12                8                    49
#           2021-08-13                8                    49
#
# [395 rows x 2 columns]

# %% [markdown]
# This tells us, that we only managed to find additional chart data for those days and regions where we didn't have _any_ data before

# %% [markdown]
# Now, finally, let's check if we introduced duplicates in our dataset. This would be the case if we had multiple tracks with the same rank for a particular region and date. Ideally, the drop_duplicates() call should remove all the duplicates.

# %%
track_counts_filtered = (
    combined_data_filtered.groupby(["region", "date", "rank"]).count().uri
)
track_counts_filtered
# Out:
# region     date        rank
# Argentina  2017-01-01  1       1
#                        2       1
#                        3       1
#                        4       1
#                        5       1
#                               ..
# Uruguay    2021-12-31  46      1
#                        47      1
#                        48      1
#                        49      1
#                        50      1
# Name: uri, Length: 4563825, dtype: int64

# %%
duplicates = track_counts_filtered.loc[track_counts_filtered > 1]
duplicates.name = "duplicates"
duplicates
# Out:
# region     date        rank
# Argentina  2017-07-20  6       2
#                        8       2
#                        10      2
#                        11      2
#                        17      2
#                               ..
# Uruguay    2021-08-13  25      2
#                        27      2
#                        33      2
#                        35      2
#                        36      2
# Name: duplicates, Length: 5486, dtype: int64

# %%
combined_data_filtered.loc[duplicates.index]
# Out:
#                                                      title  \
# region    date       rank
# Argentina 2017-07-20 6                    Escápate Conmigo
#                      6      Escápate Conmigo (feat. Ozuna)
#                      8                             Tu Foto
#                      8                             Tú Foto
#                      10                    Olha a Explosão
# ...                                                    ...
# Uruguay   2021-08-13 33    YO SE QUE TU (feat. Rusherking)
#                      35                                512
#                      35                                512
#                      36          STAY (with Justin Bieber)
#                      36          STAY (with Justin Bieber)
#
#                                                            artist   streams  \
# region    date       rank
# Argentina 2017-07-20 6                               Wisin, Ozuna  162494.0
#                      6                               Wisin, Ozuna  162494.0
#                      8                                      Ozuna  130466.0
#                      8                                      Ozuna  130466.0
#                      10                                MC Kevinho  117570.0
# ...                                                           ...       ...
# Uruguay   2021-08-13 33    FMK, Tiago PZK, LIT killah, Rusherking    9994.0
#                      35                         Mora, Jhay Cortez    9251.0
#                      35                              Mora, Jhayco    9251.0
#                      36                             The Kid LAROI    9179.0
#                      36              The Kid LAROI, Justin Bieber    9179.0
#
#                                                             uri    source
# region    date       rank
# Argentina 2017-07-20 6     spotify:track:2cnKEkpVUSV4wnjQiTWfH6  existing
#                      6     spotify:track:2cnKEkpVUSV4wnjQiTWfH6       new
#                      8     spotify:track:0Szp49tpFasIjX04Mcsydp  existing
#                      8     spotify:track:0Szp49tpFasIjX04Mcsydp       new
#                      10    spotify:track:6m2LNopVJKsvBB9l7Z1rwn  existing
# ...                                                         ...       ...
# Uruguay   2021-08-13 33    spotify:track:4M4DTyLupKvbJKlE4I4EYq       new
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2  existing
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2       new
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX  existing
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX       new
#
# [10972 rows x 5 columns]

# %% [markdown]
# We see that all the duplicates in our dataset seem to be mismatches in the way the title and artist are written. Let's remove that information (we can get it back later), drop the duplicates and check again:

# %%
filtered_only_essential_cols = combined_data_filtered.drop(
    columns=["title", "artist", "source"]
).drop_duplicates()
filtered_only_essential_cols
# Out:
#                             streams                                   uri
# region    date       rank
# Argentina 2017-01-01 1     253019.0  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
#                      2     223988.0  spotify:track:7DM4BPaS7uofFul3ywMe46
#                      3     210943.0  spotify:track:3AEZUABDXNtecAOSC1qTfo
#                      4     173865.0  spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
#                      5     153956.0  spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                             ...                                   ...
# Uruguay   2021-12-31 46     10707.0  spotify:track:7iXJg4IUyrWont5YSQrbKP
#                      47     10635.0  spotify:track:0XYZhJIcwKNjd0tjbSXwaQ
#                      48     10491.0  spotify:track:39yyHtQ4tkjZzd8TfIBKQw
#                      49     10388.0  spotify:track:5eyO0n1HiiSWdGaaSoK731
#                      50     10137.0  spotify:track:4bF2y8rR7GUjrd5LNEvej3
#
# [4435934 rows x 2 columns]

# %%
track_counts_filtered_essential = (
    filtered_only_essential_cols.groupby(["region", "date", "rank"]).count().uri
)
duplicates2 = track_counts_filtered_essential.loc[track_counts_filtered_essential > 1]
duplicates2
# Out:
# region    date        rank
# Slovakia  2017-01-05  16      2
#                       23      2
#           2017-01-06  19      2
#                       23      2
#           2017-01-07  22      2
#                              ..
#           2017-05-10  35      2
#                       37      2
#                       43      2
#                       46      2
#                       47      2
# Name: uri, Length: 154, dtype: int64

# %%
filtered_only_essential_cols.loc[duplicates2.index]
# Out:
#                           streams                                   uri
# region   date       rank
# Slovakia 2017-01-05 16     1326.0  spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     16     1326.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23     1224.0  spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#                     23     1224.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-06 19     1278.0  spotify:track:1yNyoWWWikbLhwIGWjZuDW
# ...                           ...                                   ...
#          2017-05-10 43     1105.0  spotify:track:7nKBxz47S9SD79N086fuhn
#                     46     1036.0  spotify:track:14oOKFGuXu8DqvOe1W8vao
#                     46     1036.0  spotify:track:61WbtB6ujkpNAsAf5LjF4b
#                     47     1029.0  spotify:track:542Xd5qDeLBvgXZXhfW7LE
#                     47     1029.0  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
# [308 rows x 2 columns]

# %% [markdown]
# Ok, now that's weird: 308 rows are still duplicated!

# %% [markdown]
# The nice thing is that we can use the index of the duplicates to find out more from the original filtered dataset with all columns:

# %%
true_duplicates = combined_data_filtered.loc[duplicates2.index]
true_duplicates
# Out:
#                                                                       title  \
# region   date       rank
# Slovakia 2017-01-05 16                                            All Night
#                     16                                            All Night
#                     23                                        Now and Later
#                     23                                        Now and Later
#          2017-01-06 19                                            All Night
# ...                                                                     ...
#          2017-05-10 43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     46                                          Bon Appétit
#                     46                                          Bon Appétit
#                     47                        Obsession (feat. Jon Bellion)
#                     47                        Obsession (feat. Jon Bellion)
#
#                                                                    artist  \
# region   date       rank
# Slovakia 2017-01-05 16                                  The Vamps, Matoma
#                     16                                  The Vamps, Matoma
#                     23                                    Sage The Gemini
#                     23                                    Sage The Gemini
#          2017-01-06 19                                  The Vamps, Matoma
# ...                                                                   ...
#          2017-05-10 43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#                     46                                  Katy Perry, Migos
#                     46                                  Katy Perry, Migos
#                     47                                               Vice
#                     47                                  Vice, Jon Bellion
#
#                           streams                                   uri  \
# region   date       rank
# Slovakia 2017-01-05 16     1326.0  spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     16     1326.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23     1224.0  spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#                     23     1224.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-06 19     1278.0  spotify:track:1yNyoWWWikbLhwIGWjZuDW
# ...                           ...                                   ...
#          2017-05-10 43     1105.0  spotify:track:7nKBxz47S9SD79N086fuhn
#                     46     1036.0  spotify:track:14oOKFGuXu8DqvOe1W8vao
#                     46     1036.0  spotify:track:61WbtB6ujkpNAsAf5LjF4b
#                     47     1029.0  spotify:track:542Xd5qDeLBvgXZXhfW7LE
#                     47     1029.0  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
#                             source
# region   date       rank
# Slovakia 2017-01-05 16    existing
#                     16         new
#                     23    existing
#                     23         new
#          2017-01-06 19    existing
# ...                            ...
#          2017-05-10 43         new
#                     46    existing
#                     46         new
#                     47    existing
#                     47         new
#
# [308 rows x 5 columns]

# %%
duplicates_ex = true_duplicates.loc[true_duplicates.source == "existing"].drop(
    columns=["source"]
)
duplicates_new = true_duplicates.loc[true_duplicates.source == "new"].drop(
    columns=["source"]
)

# %%
duplicates_reshaped = duplicates_ex.join(
    duplicates_new, lsuffix="_existing", rsuffix="_new"
)
duplicates_reshaped
# Out:
#                                           title_existing    artist_existing  \
# region   date       rank
# Slovakia 2017-01-05 16                         All Night  The Vamps, Matoma
#                     23                     Now and Later    Sage The Gemini
#          2017-01-06 19                         All Night  The Vamps, Matoma
#                     23                     Now and Later    Sage The Gemini
#          2017-01-07 22                     Now and Later    Sage The Gemini
# ...                                                  ...                ...
#          2017-05-10 35    You Don't Know Me - Radio Edit    Jax Jones, RAYE
#                     37                      Passionfruit              Drake
#                     43                              DNA.     Kendrick Lamar
#                     46                       Bon Appétit  Katy Perry, Migos
#                     47     Obsession (feat. Jon Bellion)               Vice
#
#                           streams_existing  \
# region   date       rank
# Slovakia 2017-01-05 16              1326.0
#                     23              1224.0
#          2017-01-06 19              1278.0
#                     23              1215.0
#          2017-01-07 22              1291.0
# ...                                    ...
#          2017-05-10 35              1409.0
#                     37              1398.0
#                     43              1112.0
#                     46              1036.0
#                     47              1029.0
#
#                                                   uri_existing  \
# region   date       rank
# Slovakia 2017-01-05 16    spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     23    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#          2017-01-06 19    spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     23    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#          2017-01-07 22    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# ...                                                        ...
#          2017-05-10 35    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     37    spotify:track:5mCPDVBb16L4XQwDdbRUpz
#                     43    spotify:track:6HZILIRieu8S0iqY8kIKhj
#                     46    spotify:track:14oOKFGuXu8DqvOe1W8vao
#                     47    spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                                                                   title_new  \
# region   date       rank
# Slovakia 2017-01-05 16                                            All Night
#                     23                                        Now and Later
#          2017-01-06 19                                            All Night
#                     23                                        Now and Later
#          2017-01-07 22                                        Now and Later
# ...                                                                     ...
#          2017-05-10 35                       You Don't Know Me (feat. RAYE)
#                     37                                         Passionfruit
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     46                                          Bon Appétit
#                     47                        Obsession (feat. Jon Bellion)
#
#                                                                artist_new  \
# region   date       rank
# Slovakia 2017-01-05 16                                  The Vamps, Matoma
#                     23                                    Sage The Gemini
#          2017-01-06 19                                  The Vamps, Matoma
#                     23                                    Sage The Gemini
#          2017-01-07 22                                    Sage The Gemini
# ...                                                                   ...
#          2017-05-10 35                                    Jax Jones, RAYE
#                     37                                              Drake
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#                     46                                  Katy Perry, Migos
#                     47                                  Vice, Jon Bellion
#
#                           streams_new                               uri_new
# region   date       rank
# Slovakia 2017-01-05 16         1326.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23         1224.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-06 19         1278.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23         1215.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-07 22         1291.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
# ...                               ...                                   ...
#          2017-05-10 35         1409.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     37         1398.0  spotify:track:7hDc8b7IXETo14hHIHdnhd
#                     43         1105.0  spotify:track:7nKBxz47S9SD79N086fuhn
#                     46         1036.0  spotify:track:61WbtB6ujkpNAsAf5LjF4b
#                     47         1029.0  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
# [154 rows x 8 columns]

# %%
df = duplicates_reshaped  # too lazy to type more
df.loc[df.title_existing != df.title_new]
# Out:
#                                                              title_existing  \
# region   date       rank
# Slovakia 2017-05-06 4                                           I'm the One
#                     8                    Despacito (Featuring Daddy Yankee)
#                     18                                              Tuesday
#                     26                       You Don't Know Me - Radio Edit
#                     35    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     37                                           Solo Dance
#          2017-05-07 3                                           I'm the One
#                     9                    Despacito (Featuring Daddy Yankee)
#                     23                                              Tuesday
#                     29                       You Don't Know Me - Radio Edit
#                     43                                              The One
#          2017-05-08 4                                           I'm the One
#                     11                   Despacito (Featuring Daddy Yankee)
#                     24                                              Tuesday
#                     30                       You Don't Know Me - Radio Edit
#                     43                                           Slow Hands
#          2017-05-10 4                                           I'm the One
#                     13                   Despacito (Featuring Daddy Yankee)
#                     19                                              Tuesday
#                     35                       You Don't Know Me - Radio Edit
#                     43                                                 DNA.
#
#                                                             artist_existing  \
# region   date       rank
# Slovakia 2017-05-06 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     8                                            Luis Fonsi
#                     18                        Burak Yeter, Danelle Sandoval
#                     26                                      Jax Jones, RAYE
#                     35                                     Enrique Iglesias
#                     37                                        Martin Jensen
#          2017-05-07 3     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     9                                            Luis Fonsi
#                     23                        Burak Yeter, Danelle Sandoval
#                     29                                      Jax Jones, RAYE
#                     43                                     The Chainsmokers
#          2017-05-08 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     11                                           Luis Fonsi
#                     24                        Burak Yeter, Danelle Sandoval
#                     30                                      Jax Jones, RAYE
#                     43                                          Niall Horan
#          2017-05-10 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     13                                           Luis Fonsi
#                     19                        Burak Yeter, Danelle Sandoval
#                     35                                      Jax Jones, RAYE
#                     43                                       Kendrick Lamar
#
#                           streams_existing  \
# region   date       rank
# Slovakia 2017-05-06 4               3026.0
#                     8               2466.0
#                     18              1780.0
#                     26              1613.0
#                     35              1348.0
#                     37              1300.0
#          2017-05-07 3               2869.0
#                     9               2170.0
#                     23              1640.0
#                     29              1442.0
#                     43              1107.0
#          2017-05-08 4               2926.0
#                     11              2232.0
#                     24              1695.0
#                     30              1497.0
#                     43              1154.0
#          2017-05-10 4               3087.0
#                     13              2178.0
#                     19              1811.0
#                     35              1409.0
#                     43              1112.0
#
#                                                   uri_existing  \
# region   date       rank
# Slovakia 2017-05-06 4     spotify:track:72Q0FQQo32KJloivv5xge2
#                     8     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     18    spotify:track:5c4tB0saSkNHX5CyDosuF7
#                     26    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     35    spotify:track:7nKBxz47S9SD79N086fuhn
#                     37    spotify:track:6HUnnBwYZqcED1eQztxMBN
#          2017-05-07 3     spotify:track:72Q0FQQo32KJloivv5xge2
#                     9     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     23    spotify:track:5c4tB0saSkNHX5CyDosuF7
#                     29    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     43    spotify:track:0wfbD5rAksdXUzRvMfM3x5
#          2017-05-08 4     spotify:track:72Q0FQQo32KJloivv5xge2
#                     11    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     24    spotify:track:5c4tB0saSkNHX5CyDosuF7
#                     30    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     43    spotify:track:167NczpNbRF7oWakJaY3Hh
#          2017-05-10 4     spotify:track:72Q0FQQo32KJloivv5xge2
#                     13    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     19    spotify:track:5c4tB0saSkNHX5CyDosuF7
#                     35    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     43    spotify:track:6HZILIRieu8S0iqY8kIKhj
#
#                                                                   title_new  \
# region   date       rank
# Slovakia 2017-05-06 4     I'm the One (feat. Justin Bieber, Quavo, Chanc...
#                     8                                             Despacito
#                     18                     Tuesday (feat. Danelle Sandoval)
#                     26                       You Don't Know Me (feat. RAYE)
#                     35                                        Unforgettable
#                     37    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-07 3     I'm the One (feat. Justin Bieber, Quavo, Chanc...
#                     9                                             Despacito
#                     23                     Tuesday (feat. Danelle Sandoval)
#                     29                       You Don't Know Me (feat. RAYE)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-08 4     I'm the One (feat. Justin Bieber, Quavo, Chanc...
#                     11                                            Despacito
#                     24                     Tuesday (feat. Danelle Sandoval)
#                     30                       You Don't Know Me (feat. RAYE)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-10 4     I'm the One (feat. Justin Bieber, Quavo, Chanc...
#                     13                                            Despacito
#                     19                     Tuesday (feat. Danelle Sandoval)
#                     35                       You Don't Know Me (feat. RAYE)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#
#                                                                  artist_new  \
# region   date       rank
# Slovakia 2017-05-06 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     8                              Luis Fonsi, Daddy Yankee
#                     18                        Burak Yeter, Danelle Sandoval
#                     26                                      Jax Jones, RAYE
#                     35                             French Montana, Swae Lee
#                     37      Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-07 3     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     9                              Luis Fonsi, Daddy Yankee
#                     23                        Burak Yeter, Danelle Sandoval
#                     29                                      Jax Jones, RAYE
#                     43      Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-08 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     11                             Luis Fonsi, Daddy Yankee
#                     24                        Burak Yeter, Danelle Sandoval
#                     30                                      Jax Jones, RAYE
#                     43      Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-10 4     DJ Khaled, Justin Bieber, Quavo, Chance the Ra...
#                     13                             Luis Fonsi, Daddy Yankee
#                     19                        Burak Yeter, Danelle Sandoval
#                     35                                      Jax Jones, RAYE
#                     43      Enrique Iglesias, Descemer Bueno, Zion & Lennox
#
#                           streams_new                               uri_new
# region   date       rank
# Slovakia 2017-05-06 4          3026.0  spotify:track:3DXncPQOG4VBw3QHh3S817
#                     8          2443.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     18         1780.0  spotify:track:7abpmGpF7PGep2rDU68GBR
#                     26         1613.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     35         1317.0  spotify:track:3B54sVLJ402zGa6Xm4YGNe
#                     37         1296.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-07 3          2869.0  spotify:track:3DXncPQOG4VBw3QHh3S817
#                     9          2165.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     23         1640.0  spotify:track:7abpmGpF7PGep2rDU68GBR
#                     29         1442.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     43         1078.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-08 4          2926.0  spotify:track:3DXncPQOG4VBw3QHh3S817
#                     11         2219.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     24         1695.0  spotify:track:7abpmGpF7PGep2rDU68GBR
#                     30         1497.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     43         1142.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-10 4          3087.0  spotify:track:3DXncPQOG4VBw3QHh3S817
#                     13         2169.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     19         1811.0  spotify:track:7abpmGpF7PGep2rDU68GBR
#                     35         1409.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     43         1105.0  spotify:track:7nKBxz47S9SD79N086fuhn

# %%
df.loc[df.artist_existing != df.artist_new]
# Out:
#                                                              title_existing  \
# region   date       rank
# Slovakia 2017-05-06 8                    Despacito (Featuring Daddy Yankee)
#                     28               Pretty Girl - Cheat Codes X CADE Remix
#                     31                    Slide (feat. Frank Ocean & Migos)
#                     35    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     37                                           Solo Dance
#          2017-05-07 9                    Despacito (Featuring Daddy Yankee)
#                     19               Pretty Girl - Cheat Codes X CADE Remix
#                     35                    Slide (feat. Frank Ocean & Migos)
#                     43                                              The One
#          2017-05-08 11                   Despacito (Featuring Daddy Yankee)
#                     25               Pretty Girl - Cheat Codes X CADE Remix
#                     33                    Slide (feat. Frank Ocean & Migos)
#                     43                                           Slow Hands
#          2017-05-10 13                   Despacito (Featuring Daddy Yankee)
#                     29                    Slide (feat. Frank Ocean & Migos)
#                     43                                                 DNA.
#                     47                        Obsession (feat. Jon Bellion)
#
#                            artist_existing  streams_existing  \
# region   date       rank
# Slovakia 2017-05-06 8           Luis Fonsi            2466.0
#                     28    Maggie Lindemann            1598.0
#                     31       Calvin Harris            1429.0
#                     35    Enrique Iglesias            1348.0
#                     37       Martin Jensen            1300.0
#          2017-05-07 9           Luis Fonsi            2170.0
#                     19    Maggie Lindemann            1763.0
#                     35       Calvin Harris            1276.0
#                     43    The Chainsmokers            1107.0
#          2017-05-08 11          Luis Fonsi            2232.0
#                     25    Maggie Lindemann            1677.0
#                     33       Calvin Harris            1384.0
#                     43         Niall Horan            1154.0
#          2017-05-10 13          Luis Fonsi            2178.0
#                     29       Calvin Harris            1520.0
#                     43      Kendrick Lamar            1112.0
#                     47                Vice            1029.0
#
#                                                   uri_existing  \
# region   date       rank
# Slovakia 2017-05-06 8     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     28    spotify:track:39IsH7B5byx8NRlEKlZVg9
#                     31    spotify:track:6gpcs5eMhJwax4mIfKDYQk
#                     35    spotify:track:7nKBxz47S9SD79N086fuhn
#                     37    spotify:track:6HUnnBwYZqcED1eQztxMBN
#          2017-05-07 9     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     19    spotify:track:39IsH7B5byx8NRlEKlZVg9
#                     35    spotify:track:6gpcs5eMhJwax4mIfKDYQk
#                     43    spotify:track:0wfbD5rAksdXUzRvMfM3x5
#          2017-05-08 11    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     25    spotify:track:39IsH7B5byx8NRlEKlZVg9
#                     33    spotify:track:6gpcs5eMhJwax4mIfKDYQk
#                     43    spotify:track:167NczpNbRF7oWakJaY3Hh
#          2017-05-10 13    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     29    spotify:track:6gpcs5eMhJwax4mIfKDYQk
#                     43    spotify:track:6HZILIRieu8S0iqY8kIKhj
#                     47    spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                                                                   title_new  \
# region   date       rank
# Slovakia 2017-05-06 8                                             Despacito
#                     28               Pretty Girl - Cheat Codes X CADE Remix
#                     31                    Slide (feat. Frank Ocean & Migos)
#                     35                                        Unforgettable
#                     37    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-07 9                                             Despacito
#                     19               Pretty Girl - Cheat Codes X CADE Remix
#                     35                    Slide (feat. Frank Ocean & Migos)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-08 11                                            Despacito
#                     25               Pretty Girl - Cheat Codes X CADE Remix
#                     33                    Slide (feat. Frank Ocean & Migos)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-10 13                                            Despacito
#                     29                    Slide (feat. Frank Ocean & Migos)
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     47                        Obsession (feat. Jon Bellion)
#
#                                                                artist_new  \
# region   date       rank
# Slovakia 2017-05-06 8                            Luis Fonsi, Daddy Yankee
#                     28                Maggie Lindemann, Cheat Codes, CADE
#                     31        Calvin Harris, Frank Ocean, Migos, Funk Wav
#                     35                           French Montana, Swae Lee
#                     37    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-07 9                            Luis Fonsi, Daddy Yankee
#                     19                Maggie Lindemann, Cheat Codes, CADE
#                     35        Calvin Harris, Frank Ocean, Migos, Funk Wav
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-08 11                           Luis Fonsi, Daddy Yankee
#                     25                Maggie Lindemann, Cheat Codes, CADE
#                     33        Calvin Harris, Frank Ocean, Migos, Funk Wav
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-10 13                           Luis Fonsi, Daddy Yankee
#                     29        Calvin Harris, Frank Ocean, Migos, Funk Wav
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#                     47                                  Vice, Jon Bellion
#
#                           streams_new                               uri_new
# region   date       rank
# Slovakia 2017-05-06 8          2443.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     28         1598.0  spotify:track:1NDxZ7cFAo481dtYWdrUnR
#                     31         1429.0  spotify:track:7tr2za8SQg2CI8EDgrdtNl
#                     35         1317.0  spotify:track:3B54sVLJ402zGa6Xm4YGNe
#                     37         1296.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-07 9          2165.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     19         1763.0  spotify:track:1NDxZ7cFAo481dtYWdrUnR
#                     35         1276.0  spotify:track:7tr2za8SQg2CI8EDgrdtNl
#                     43         1078.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-08 11         2219.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     25         1677.0  spotify:track:1NDxZ7cFAo481dtYWdrUnR
#                     33         1384.0  spotify:track:7tr2za8SQg2CI8EDgrdtNl
#                     43         1142.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-10 13         2169.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     29         1520.0  spotify:track:7tr2za8SQg2CI8EDgrdtNl
#                     43         1105.0  spotify:track:7nKBxz47S9SD79N086fuhn
#                     47         1029.0  spotify:track:5pvVAwQbuFoR7LkcicrKnk

# %%
df.loc[df.streams_existing != df.streams_new]
# Out:
#                                                              title_existing  \
# region   date       rank
# Slovakia 2017-05-06 8                    Despacito (Featuring Daddy Yankee)
#                     35    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     37                                           Solo Dance
#          2017-05-07 9                    Despacito (Featuring Daddy Yankee)
#                     43                                              The One
#          2017-05-08 11                   Despacito (Featuring Daddy Yankee)
#                     43                                           Slow Hands
#          2017-05-10 13                   Despacito (Featuring Daddy Yankee)
#                     43                                                 DNA.
#
#                            artist_existing  streams_existing  \
# region   date       rank
# Slovakia 2017-05-06 8           Luis Fonsi            2466.0
#                     35    Enrique Iglesias            1348.0
#                     37       Martin Jensen            1300.0
#          2017-05-07 9           Luis Fonsi            2170.0
#                     43    The Chainsmokers            1107.0
#          2017-05-08 11          Luis Fonsi            2232.0
#                     43         Niall Horan            1154.0
#          2017-05-10 13          Luis Fonsi            2178.0
#                     43      Kendrick Lamar            1112.0
#
#                                                   uri_existing  \
# region   date       rank
# Slovakia 2017-05-06 8     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     35    spotify:track:7nKBxz47S9SD79N086fuhn
#                     37    spotify:track:6HUnnBwYZqcED1eQztxMBN
#          2017-05-07 9     spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43    spotify:track:0wfbD5rAksdXUzRvMfM3x5
#          2017-05-08 11    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43    spotify:track:167NczpNbRF7oWakJaY3Hh
#          2017-05-10 13    spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43    spotify:track:6HZILIRieu8S0iqY8kIKhj
#
#                                                                   title_new  \
# region   date       rank
# Slovakia 2017-05-06 8                                             Despacito
#                     35                                        Unforgettable
#                     37    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-07 9                                             Despacito
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-08 11                                            Despacito
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#          2017-05-10 13                                            Despacito
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#
#                                                                artist_new  \
# region   date       rank
# Slovakia 2017-05-06 8                            Luis Fonsi, Daddy Yankee
#                     35                           French Montana, Swae Lee
#                     37    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-07 9                            Luis Fonsi, Daddy Yankee
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-08 11                           Luis Fonsi, Daddy Yankee
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#          2017-05-10 13                           Luis Fonsi, Daddy Yankee
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#
#                           streams_new                               uri_new
# region   date       rank
# Slovakia 2017-05-06 8          2443.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     35         1317.0  spotify:track:3B54sVLJ402zGa6Xm4YGNe
#                     37         1296.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-07 9          2165.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43         1078.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-08 11         2219.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43         1142.0  spotify:track:7nKBxz47S9SD79N086fuhn
#          2017-05-10 13         2169.0  spotify:track:4aWmUDTfIPGksMNLV2rQP2
#                     43         1105.0  spotify:track:7nKBxz47S9SD79N086fuhn

# %%
df.loc[df.uri_existing != df.uri_new]
# Out:
#                                           title_existing    artist_existing  \
# region   date       rank
# Slovakia 2017-01-05 16                         All Night  The Vamps, Matoma
#                     23                     Now and Later    Sage The Gemini
#          2017-01-06 19                         All Night  The Vamps, Matoma
#                     23                     Now and Later    Sage The Gemini
#          2017-01-07 22                     Now and Later    Sage The Gemini
# ...                                                  ...                ...
#          2017-05-10 35    You Don't Know Me - Radio Edit    Jax Jones, RAYE
#                     37                      Passionfruit              Drake
#                     43                              DNA.     Kendrick Lamar
#                     46                       Bon Appétit  Katy Perry, Migos
#                     47     Obsession (feat. Jon Bellion)               Vice
#
#                           streams_existing  \
# region   date       rank
# Slovakia 2017-01-05 16              1326.0
#                     23              1224.0
#          2017-01-06 19              1278.0
#                     23              1215.0
#          2017-01-07 22              1291.0
# ...                                    ...
#          2017-05-10 35              1409.0
#                     37              1398.0
#                     43              1112.0
#                     46              1036.0
#                     47              1029.0
#
#                                                   uri_existing  \
# region   date       rank
# Slovakia 2017-01-05 16    spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     23    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#          2017-01-06 19    spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                     23    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#          2017-01-07 22    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# ...                                                        ...
#          2017-05-10 35    spotify:track:4WrS6vezaPwOafKJmHqMEU
#                     37    spotify:track:5mCPDVBb16L4XQwDdbRUpz
#                     43    spotify:track:6HZILIRieu8S0iqY8kIKhj
#                     46    spotify:track:14oOKFGuXu8DqvOe1W8vao
#                     47    spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                                                                   title_new  \
# region   date       rank
# Slovakia 2017-01-05 16                                            All Night
#                     23                                        Now and Later
#          2017-01-06 19                                            All Night
#                     23                                        Now and Later
#          2017-01-07 22                                        Now and Later
# ...                                                                     ...
#          2017-05-10 35                       You Don't Know Me (feat. RAYE)
#                     37                                         Passionfruit
#                     43    SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
#                     46                                          Bon Appétit
#                     47                        Obsession (feat. Jon Bellion)
#
#                                                                artist_new  \
# region   date       rank
# Slovakia 2017-01-05 16                                  The Vamps, Matoma
#                     23                                    Sage The Gemini
#          2017-01-06 19                                  The Vamps, Matoma
#                     23                                    Sage The Gemini
#          2017-01-07 22                                    Sage The Gemini
# ...                                                                   ...
#          2017-05-10 35                                    Jax Jones, RAYE
#                     37                                              Drake
#                     43    Enrique Iglesias, Descemer Bueno, Zion & Lennox
#                     46                                  Katy Perry, Migos
#                     47                                  Vice, Jon Bellion
#
#                           streams_new                               uri_new
# region   date       rank
# Slovakia 2017-01-05 16         1326.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23         1224.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-06 19         1278.0  spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                     23         1215.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
#          2017-01-07 22         1291.0  spotify:track:08WPvDEsHvTFuB9w8tC2OS
# ...                               ...                                   ...
#          2017-05-10 35         1409.0  spotify:track:00lNx0OcTJrS3MKHcB80HY
#                     37         1398.0  spotify:track:7hDc8b7IXETo14hHIHdnhd
#                     43         1105.0  spotify:track:7nKBxz47S9SD79N086fuhn
#                     46         1036.0  spotify:track:61WbtB6ujkpNAsAf5LjF4b
#                     47         1029.0  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
# [150 rows x 8 columns]

# %% [markdown]
# That's soo weird... Looks like all the rows seem to refer to the same songs, but different track URIs are used.

# %%
len(df.loc[df.streams_existing < df.streams_new])
# Out:
# 0

# %% [markdown]
# Let's write the info to a file that we can inspect manually. It is feasible, as there are just roughly 150 rows.

# %%
df.to_csv(create_data_out_path("duplicates.csv"))
# Out:
# Data output path: /home/sejmou/Repos/Uni/VisDS/vis-ds/data/duplicates.csv

# %% [markdown]
# ### Verifying track URIs are valid

# %% [markdown]
# Let's try use `spotipy` to check whether the duplicated tracks are really available on Spotify:

# %%
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

# %%
chunks = split_dataframe(df, chunk_size=50)

# %%
existing_tracks = pd.concat(
    [pd.DataFrame(sp.tracks(chunk.uri_existing)["tracks"]) for chunk in chunks]
)
existing_tracks
# Out:
#                                                 album  \
# 0   {'album_type': 'single', 'artists': [{'externa...
# 1   {'album_type': 'single', 'artists': [{'externa...
# 2   {'album_type': 'single', 'artists': [{'externa...
# 3   {'album_type': 'single', 'artists': [{'externa...
# 4   {'album_type': 'single', 'artists': [{'externa...
# ..                                                ...
# 49  {'album_type': 'single', 'artists': [{'externa...
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'single', 'artists': [{'externa...
# 3   {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# ..                                                ...
# 49  [{'external_urls': {'spotify': 'https://open.s...
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0                                                  []            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                                  []            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ..                                                ...          ...
# 49                                                 []            1
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                                  []            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        197793     False  {'isrc': 'GBUM71605342'}
# 1        193181     False  {'isrc': 'USAT21602883'}
# 2        197793     False  {'isrc': 'GBUM71605342'}
# 3        193181     False  {'isrc': 'USAT21602883'}
# 4        193181     False  {'isrc': 'USAT21602883'}
# ..          ...       ...                       ...
# 49       211935      True  {'isrc': 'GBUM71606456'}
# 0        298940      True  {'isrc': 'USCM51700072'}
# 1        185946      True  {'isrc': 'USUM71703079'}
# 2        227292     False  {'isrc': 'USUM71702488'}
# 3        221982     False  {'isrc': 'USAT21700461'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/1y...
# 1   {'spotify': 'https://open.spotify.com/track/43...
# 2   {'spotify': 'https://open.spotify.com/track/1y...
# 3   {'spotify': 'https://open.spotify.com/track/43...
# 4   {'spotify': 'https://open.spotify.com/track/43...
# ..                                                ...
# 49  {'spotify': 'https://open.spotify.com/track/4W...
# 0   {'spotify': 'https://open.spotify.com/track/5m...
# 1   {'spotify': 'https://open.spotify.com/track/6H...
# 2   {'spotify': 'https://open.spotify.com/track/14...
# 3   {'spotify': 'https://open.spotify.com/track/54...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/1yNyoWWWikbL...  1yNyoWWWikbLhwIGWjZuDW
# 1   https://api.spotify.com/v1/tracks/43jBqV3j3Xi1...  43jBqV3j3Xi1g6wO0bhIMd
# 2   https://api.spotify.com/v1/tracks/1yNyoWWWikbL...  1yNyoWWWikbLhwIGWjZuDW
# 3   https://api.spotify.com/v1/tracks/43jBqV3j3Xi1...  43jBqV3j3Xi1g6wO0bhIMd
# 4   https://api.spotify.com/v1/tracks/43jBqV3j3Xi1...  43jBqV3j3Xi1g6wO0bhIMd
# ..                                                ...                     ...
# 49  https://api.spotify.com/v1/tracks/4WrS6vezaPwO...  4WrS6vezaPwOafKJmHqMEU
# 0   https://api.spotify.com/v1/tracks/5mCPDVBb16L4...  5mCPDVBb16L4XQwDdbRUpz
# 1   https://api.spotify.com/v1/tracks/6HZILIRieu8S...  6HZILIRieu8S0iqY8kIKhj
# 2   https://api.spotify.com/v1/tracks/14oOKFGuXu8D...  14oOKFGuXu8DqvOe1W8vao
# 3   https://api.spotify.com/v1/tracks/542Xd5qDeLBv...  542Xd5qDeLBvgXZXhfW7LE
#
#     is_local                            name  popularity  \
# 0      False                       All Night           0
# 1      False                   Now and Later          54
# 2      False                       All Night           0
# 3      False                   Now and Later          54
# 4      False                   Now and Later          54
# ..       ...                             ...         ...
# 49     False  You Don't Know Me - Radio Edit           0
# 0      False                    Passionfruit          83
# 1      False                            DNA.          79
# 2      False                     Bon Appétit           0
# 3      False   Obsession (feat. Jon Bellion)          35
#
#                                           preview_url  track_number   type  \
# 0                                                None             1  track
# 1   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...             1  track
# 2                                                None             1  track
# 3   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...             1  track
# 4   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...             1  track
# ..                                                ...           ...    ...
# 49                                               None             1  track
# 0   https://p.scdn.co/mp3-preview/c014129d2fde9be4...             3  track
# 1   https://p.scdn.co/mp3-preview/7c9aac4ace7e49d4...             2  track
# 2                                                None             1  track
# 3   https://p.scdn.co/mp3-preview/e3d6b0bce4174829...             1  track
#
#                                      uri
# 0   spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 1   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 2   spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 3   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 4   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# ..                                   ...
# 49  spotify:track:4WrS6vezaPwOafKJmHqMEU
# 0   spotify:track:5mCPDVBb16L4XQwDdbRUpz
# 1   spotify:track:6HZILIRieu8S0iqY8kIKhj
# 2   spotify:track:14oOKFGuXu8DqvOe1W8vao
# 3   spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
# [154 rows x 17 columns]

# %%
new_tracks = pd.concat(
    [pd.DataFrame(sp.tracks(chunk.uri_new)["tracks"]) for chunk in chunks]
)
new_tracks
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'album', 'artists': [{'external...
# ..                                                ...
# 49  {'album_type': 'single', 'artists': [{'externa...
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'single', 'artists': [{'externa...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'single', 'artists': [{'externa...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# ..                                                ...
# 49  [{'external_urls': {'spotify': 'https://open.s...
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0                                                  []            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                                  []            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ..                                                ...          ...
# 49                                                 []            1
# 0                                                  []            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                                  []            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit              external_ids  \
# 0        197640     False  {'isrc': 'GBUM71605342'}
# 1        193181     False  {'isrc': 'USAT21702430'}
# 2        197640     False  {'isrc': 'GBUM71605342'}
# 3        193181     False  {'isrc': 'USAT21702430'}
# 4        193181     False  {'isrc': 'USAT21702430'}
# ..          ...       ...                       ...
# 49       213946      True  {'isrc': 'GBUM71606456'}
# 0        298940      True  {'isrc': 'USCM51700072'}
# 1        207680     False  {'isrc': 'USRC11700058'}
# 2        227821     False  {'isrc': 'USUM71702488'}
# 3        221982     False  {'isrc': 'USAT21701820'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/4b...
# 1   {'spotify': 'https://open.spotify.com/track/08...
# 2   {'spotify': 'https://open.spotify.com/track/4b...
# 3   {'spotify': 'https://open.spotify.com/track/08...
# 4   {'spotify': 'https://open.spotify.com/track/08...
# ..                                                ...
# 49  {'spotify': 'https://open.spotify.com/track/00...
# 0   {'spotify': 'https://open.spotify.com/track/7h...
# 1   {'spotify': 'https://open.spotify.com/track/7n...
# 2   {'spotify': 'https://open.spotify.com/track/61...
# 3   {'spotify': 'https://open.spotify.com/track/5p...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/4b4KcovePX8K...  4b4KcovePX8Ke2cLIQTLM0
# 1   https://api.spotify.com/v1/tracks/08WPvDEsHvTF...  08WPvDEsHvTFuB9w8tC2OS
# 2   https://api.spotify.com/v1/tracks/4b4KcovePX8K...  4b4KcovePX8Ke2cLIQTLM0
# 3   https://api.spotify.com/v1/tracks/08WPvDEsHvTF...  08WPvDEsHvTFuB9w8tC2OS
# 4   https://api.spotify.com/v1/tracks/08WPvDEsHvTF...  08WPvDEsHvTFuB9w8tC2OS
# ..                                                ...                     ...
# 49  https://api.spotify.com/v1/tracks/00lNx0OcTJrS...  00lNx0OcTJrS3MKHcB80HY
# 0   https://api.spotify.com/v1/tracks/7hDc8b7IXETo...  7hDc8b7IXETo14hHIHdnhd
# 1   https://api.spotify.com/v1/tracks/7nKBxz47S9SD...  7nKBxz47S9SD79N086fuhn
# 2   https://api.spotify.com/v1/tracks/61WbtB6ujkpN...  61WbtB6ujkpNAsAf5LjF4b
# 3   https://api.spotify.com/v1/tracks/5pvVAwQbuFoR...  5pvVAwQbuFoR7LkcicrKnk
#
#     is_local                                               name  popularity  \
# 0      False                                          All Night           0
# 1      False                                      Now and Later          53
# 2      False                                          All Night           0
# 3      False                                      Now and Later          53
# 4      False                                      Now and Later          53
# ..       ...                                                ...         ...
# 49     False                     You Don't Know Me - Radio Edit           2
# 0      False                                       Passionfruit           0
# 1      False  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...          69
# 2      False                                        Bon appétit           0
# 3      False                      Obsession (feat. Jon Bellion)          46
#
#                                           preview_url  track_number   type  \
# 0                                                None             2  track
# 1   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...            15  track
# 2                                                None             2  track
# 3   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...            15  track
# 4   https://p.scdn.co/mp3-preview/4e07add7f65df6d1...            15  track
# ..                                                ...           ...    ...
# 49                                               None             1  track
# 0                                                None             3  track
# 1   https://p.scdn.co/mp3-preview/1b7a210a0e85e975...             1  track
# 2                                                None            11  track
# 3   https://p.scdn.co/mp3-preview/e3d6b0bce4174829...             1  track
#
#                                      uri
# 0   spotify:track:4b4KcovePX8Ke2cLIQTLM0
# 1   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# 2   spotify:track:4b4KcovePX8Ke2cLIQTLM0
# 3   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# 4   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# ..                                   ...
# 49  spotify:track:00lNx0OcTJrS3MKHcB80HY
# 0   spotify:track:7hDc8b7IXETo14hHIHdnhd
# 1   spotify:track:7nKBxz47S9SD79N086fuhn
# 2   spotify:track:61WbtB6ujkpNAsAf5LjF4b
# 3   spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
# [154 rows x 17 columns]

# %% [markdown]
# We got valid song data for both the existing and new data.

# %% [markdown]
# The manual analysis in Google Sheets convinced me that in all instances, the same songs are actually referred to. So, those tracks can be considered duplicates!

# %%
duplicate_mapping= df[["uri_new", "uri_existing"]]
duplicate_mapping = duplicate_mapping.reset_index()[["uri_new", "uri_existing"]].drop_duplicates()
duplicate_mapping = duplicate_mapping.loc[duplicate_mapping.uri_new != duplicate_mapping.uri_existing].reset_index().drop(columns="index")
duplicate_mapping
# Out:
#                                  uri_new                          uri_existing
# 0   spotify:track:4b4KcovePX8Ke2cLIQTLM0  spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 1   spotify:track:08WPvDEsHvTFuB9w8tC2OS  spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 2   spotify:track:2HzfRSfCogBSsgW2CckVA2  spotify:track:3TRFq09DUgYj1mug6RRqJW
# 3   spotify:track:6D0b04NJIKfEMg040WioJQ  spotify:track:1sXUWdKx03aP9Gmzft58rt
# 4   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8  spotify:track:0Nhu3zSYbEz32IYiobV75e
# 5   spotify:track:3DXncPQOG4VBw3QHh3S817  spotify:track:72Q0FQQo32KJloivv5xge2
# 6   spotify:track:3ebXMykcMXOcLeJ9xZ17XH  spotify:track:0KR2W3St74th8z3LS94Ffh
# 7   spotify:track:0CcQNd8CINkwQfe1RDtGV6  spotify:track:6VRghJeP6I0w1KxkdWFfIh
# 8   spotify:track:7abpmGpF7PGep2rDU68GBR  spotify:track:5c4tB0saSkNHX5CyDosuF7
# 9   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8  spotify:track:1mDGDb2fUmUMdqV3tb8VKQ
# 10  spotify:track:00lNx0OcTJrS3MKHcB80HY  spotify:track:4WrS6vezaPwOafKJmHqMEU
# 11  spotify:track:1NDxZ7cFAo481dtYWdrUnR  spotify:track:39IsH7B5byx8NRlEKlZVg9
# 12  spotify:track:61WbtB6ujkpNAsAf5LjF4b  spotify:track:14oOKFGuXu8DqvOe1W8vao
# 13  spotify:track:5Ohxk2dO5COHF1krpoPigN  spotify:track:5ELRkzdzz0HvGpMDlfZHkV
# 14  spotify:track:7tr2za8SQg2CI8EDgrdtNl  spotify:track:6gpcs5eMhJwax4mIfKDYQk
# 15  spotify:track:3B54sVLJ402zGa6Xm4YGNe  spotify:track:7nKBxz47S9SD79N086fuhn
# 16  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:6HUnnBwYZqcED1eQztxMBN
# 17  spotify:track:0tKcYR2II1VCQWT79i5NrW  spotify:track:56lBX2WHqfGuoeZxZvUnVj
# 18  spotify:track:3B54sVLJ402zGa6Xm4YGNe  spotify:track:1F2HXIJrE2Xn81OzT2zZvW
# 19  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 20  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:167NczpNbRF7oWakJaY3Hh
# 21  spotify:track:4IWAyPf1KMq7JCyGeCjTeH  spotify:track:4izg6Hydc6XGErWW6nbdsV
# 22  spotify:track:7hDc8b7IXETo14hHIHdnhd  spotify:track:5mCPDVBb16L4XQwDdbRUpz
# 23  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:6HZILIRieu8S0iqY8kIKhj
# 24  spotify:track:5pvVAwQbuFoR7LkcicrKnk  spotify:track:542Xd5qDeLBvgXZXhfW7LE

# %%
duplicate_mapping.loc[duplicate_mapping.uri_new.isin(duplicate_mapping.uri_existing)]
# Out:
#                                  uri_new                          uri_existing
# 16  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:6HUnnBwYZqcED1eQztxMBN
# 19  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 20  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:167NczpNbRF7oWakJaY3Hh
# 23  spotify:track:7nKBxz47S9SD79N086fuhn  spotify:track:6HZILIRieu8S0iqY8kIKhj

# %%
def get_track_names_from_spotify(uris):
  resp = sp.tracks(uris)["tracks"]
  return [obj["name"] for obj in resp]

# %%
track_names_new_uris = get_track_names_from_spotify(duplicate_mapping.uri_new)
track_names_existing_uris = get_track_names_from_spotify(duplicate_mapping.uri_existing)

# %%
results = pd.DataFrame({"name_existing": track_names_existing_uris, "name_new": track_names_new_uris})
results
# Out:
#                                         name_existing  \
# 0                                           All Night
# 1                                       Now and Later
# 2                                        Lot to Learn
# 3                                              Issues
# 4                                        Now Or Never
# 5                                         I'm the One
# 6                                 Scared to Be Lonely
# 7                                            Believer
# 8                    Tuesday (feat. Danelle Sandoval)
# 9                                        Now Or Never
# 10                     You Don't Know Me - Radio Edit
# 11             Pretty Girl - Cheat Codes X CADE Remix
# 12                                        Bon Appétit
# 13                                  Sign of the Times
# 14                  Slide (feat. Frank Ocean & Migos)
# 15  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 16                                         Solo Dance
# 17                                            Thunder
# 18                                      Unforgettable
# 19                                            The One
# 20                                         Slow Hands
# 21                                  Whatever It Takes
# 22                                       Passionfruit
# 23                                               DNA.
# 24                      Obsession (feat. Jon Bellion)
#
#                                              name_new
# 0                                           All Night
# 1                                       Now and Later
# 2                                        Lot to Learn
# 3                                              Issues
# 4                                        Now Or Never
# 5   I'm the One (feat. Justin Bieber, Quavo, Chanc...
# 6                                 Scared to Be Lonely
# 7                                            Believer
# 8                                             Tuesday
# 9                                        Now Or Never
# 10                     You Don't Know Me - Radio Edit
# 11             Pretty Girl - Cheat Codes X CADE Remix
# 12                                        Bon appétit
# 13                                  Sign of the Times
# 14                  Slide (feat. Frank Ocean & Migos)
# 15                                      Unforgettable
# 16  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 17                                            Thunder
# 18                                      Unforgettable
# 19  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 20  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 21                                  Whatever It Takes
# 22                                       Passionfruit
# 23  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 24                      Obsession (feat. Jon Bellion)

# %%
duplicate_mapping["name_existing"] = results.name_existing
duplicate_mapping["name_new"] = results.name_new
duplicate_mapping
# Out:
#                                  uri_new  \
# 0   spotify:track:4b4KcovePX8Ke2cLIQTLM0
# 1   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# 2   spotify:track:2HzfRSfCogBSsgW2CckVA2
# 3   spotify:track:6D0b04NJIKfEMg040WioJQ
# 4   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 5   spotify:track:3DXncPQOG4VBw3QHh3S817
# 6   spotify:track:3ebXMykcMXOcLeJ9xZ17XH
# 7   spotify:track:0CcQNd8CINkwQfe1RDtGV6
# 8   spotify:track:7abpmGpF7PGep2rDU68GBR
# 9   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 10  spotify:track:00lNx0OcTJrS3MKHcB80HY
# 11  spotify:track:1NDxZ7cFAo481dtYWdrUnR
# 12  spotify:track:61WbtB6ujkpNAsAf5LjF4b
# 13  spotify:track:5Ohxk2dO5COHF1krpoPigN
# 14  spotify:track:7tr2za8SQg2CI8EDgrdtNl
# 15  spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 16  spotify:track:7nKBxz47S9SD79N086fuhn
# 17  spotify:track:0tKcYR2II1VCQWT79i5NrW
# 18  spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 19  spotify:track:7nKBxz47S9SD79N086fuhn
# 20  spotify:track:7nKBxz47S9SD79N086fuhn
# 21  spotify:track:4IWAyPf1KMq7JCyGeCjTeH
# 22  spotify:track:7hDc8b7IXETo14hHIHdnhd
# 23  spotify:track:7nKBxz47S9SD79N086fuhn
# 24  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
#                             uri_existing  \
# 0   spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 1   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 2   spotify:track:3TRFq09DUgYj1mug6RRqJW
# 3   spotify:track:1sXUWdKx03aP9Gmzft58rt
# 4   spotify:track:0Nhu3zSYbEz32IYiobV75e
# 5   spotify:track:72Q0FQQo32KJloivv5xge2
# 6   spotify:track:0KR2W3St74th8z3LS94Ffh
# 7   spotify:track:6VRghJeP6I0w1KxkdWFfIh
# 8   spotify:track:5c4tB0saSkNHX5CyDosuF7
# 9   spotify:track:1mDGDb2fUmUMdqV3tb8VKQ
# 10  spotify:track:4WrS6vezaPwOafKJmHqMEU
# 11  spotify:track:39IsH7B5byx8NRlEKlZVg9
# 12  spotify:track:14oOKFGuXu8DqvOe1W8vao
# 13  spotify:track:5ELRkzdzz0HvGpMDlfZHkV
# 14  spotify:track:6gpcs5eMhJwax4mIfKDYQk
# 15  spotify:track:7nKBxz47S9SD79N086fuhn
# 16  spotify:track:6HUnnBwYZqcED1eQztxMBN
# 17  spotify:track:56lBX2WHqfGuoeZxZvUnVj
# 18  spotify:track:1F2HXIJrE2Xn81OzT2zZvW
# 19  spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 20  spotify:track:167NczpNbRF7oWakJaY3Hh
# 21  spotify:track:4izg6Hydc6XGErWW6nbdsV
# 22  spotify:track:5mCPDVBb16L4XQwDdbRUpz
# 23  spotify:track:6HZILIRieu8S0iqY8kIKhj
# 24  spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                                         name_existing  \
# 0                                           All Night
# 1                                       Now and Later
# 2                                        Lot to Learn
# 3                                              Issues
# 4                                        Now Or Never
# 5                                         I'm the One
# 6                                 Scared to Be Lonely
# 7                                            Believer
# 8                    Tuesday (feat. Danelle Sandoval)
# 9                                        Now Or Never
# 10                     You Don't Know Me - Radio Edit
# 11             Pretty Girl - Cheat Codes X CADE Remix
# 12                                        Bon Appétit
# 13                                  Sign of the Times
# 14                  Slide (feat. Frank Ocean & Migos)
# 15  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 16                                         Solo Dance
# 17                                            Thunder
# 18                                      Unforgettable
# 19                                            The One
# 20                                         Slow Hands
# 21                                  Whatever It Takes
# 22                                       Passionfruit
# 23                                               DNA.
# 24                      Obsession (feat. Jon Bellion)
#
#                                              name_new
# 0                                           All Night
# 1                                       Now and Later
# 2                                        Lot to Learn
# 3                                              Issues
# 4                                        Now Or Never
# 5   I'm the One (feat. Justin Bieber, Quavo, Chanc...
# 6                                 Scared to Be Lonely
# 7                                            Believer
# 8                                             Tuesday
# 9                                        Now Or Never
# 10                     You Don't Know Me - Radio Edit
# 11             Pretty Girl - Cheat Codes X CADE Remix
# 12                                        Bon appétit
# 13                                  Sign of the Times
# 14                  Slide (feat. Frank Ocean & Migos)
# 15                                      Unforgettable
# 16  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 17                                            Thunder
# 18                                      Unforgettable
# 19  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 20  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 21                                  Whatever It Takes
# 22                                       Passionfruit
# 23  SUBEME LA RADIO (feat. Descemer Bueno & Zion &...
# 24                      Obsession (feat. Jon Bellion)

# %% [markdown]
# We see that rows 15, 16, 19, 20, 21, and 23 are wrong.

# %%
true_dups = (
    duplicate_mapping.drop([15, 16, 19, 20, 23]).reset_index().drop(columns="index")
)
true_dups
# Out:
#                                  uri_new  \
# 0   spotify:track:4b4KcovePX8Ke2cLIQTLM0
# 1   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# 2   spotify:track:2HzfRSfCogBSsgW2CckVA2
# 3   spotify:track:6D0b04NJIKfEMg040WioJQ
# 4   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 5   spotify:track:3DXncPQOG4VBw3QHh3S817
# 6   spotify:track:3ebXMykcMXOcLeJ9xZ17XH
# 7   spotify:track:0CcQNd8CINkwQfe1RDtGV6
# 8   spotify:track:7abpmGpF7PGep2rDU68GBR
# 9   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 10  spotify:track:00lNx0OcTJrS3MKHcB80HY
# 11  spotify:track:1NDxZ7cFAo481dtYWdrUnR
# 12  spotify:track:61WbtB6ujkpNAsAf5LjF4b
# 13  spotify:track:5Ohxk2dO5COHF1krpoPigN
# 14  spotify:track:7tr2za8SQg2CI8EDgrdtNl
# 15  spotify:track:0tKcYR2II1VCQWT79i5NrW
# 16  spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 17  spotify:track:4IWAyPf1KMq7JCyGeCjTeH
# 18  spotify:track:7hDc8b7IXETo14hHIHdnhd
# 19  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
#                             uri_existing  \
# 0   spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 1   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 2   spotify:track:3TRFq09DUgYj1mug6RRqJW
# 3   spotify:track:1sXUWdKx03aP9Gmzft58rt
# 4   spotify:track:0Nhu3zSYbEz32IYiobV75e
# 5   spotify:track:72Q0FQQo32KJloivv5xge2
# 6   spotify:track:0KR2W3St74th8z3LS94Ffh
# 7   spotify:track:6VRghJeP6I0w1KxkdWFfIh
# 8   spotify:track:5c4tB0saSkNHX5CyDosuF7
# 9   spotify:track:1mDGDb2fUmUMdqV3tb8VKQ
# 10  spotify:track:4WrS6vezaPwOafKJmHqMEU
# 11  spotify:track:39IsH7B5byx8NRlEKlZVg9
# 12  spotify:track:14oOKFGuXu8DqvOe1W8vao
# 13  spotify:track:5ELRkzdzz0HvGpMDlfZHkV
# 14  spotify:track:6gpcs5eMhJwax4mIfKDYQk
# 15  spotify:track:56lBX2WHqfGuoeZxZvUnVj
# 16  spotify:track:1F2HXIJrE2Xn81OzT2zZvW
# 17  spotify:track:4izg6Hydc6XGErWW6nbdsV
# 18  spotify:track:5mCPDVBb16L4XQwDdbRUpz
# 19  spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                              name_existing  \
# 0                                All Night
# 1                            Now and Later
# 2                             Lot to Learn
# 3                                   Issues
# 4                             Now Or Never
# 5                              I'm the One
# 6                      Scared to Be Lonely
# 7                                 Believer
# 8         Tuesday (feat. Danelle Sandoval)
# 9                             Now Or Never
# 10          You Don't Know Me - Radio Edit
# 11  Pretty Girl - Cheat Codes X CADE Remix
# 12                             Bon Appétit
# 13                       Sign of the Times
# 14       Slide (feat. Frank Ocean & Migos)
# 15                                 Thunder
# 16                           Unforgettable
# 17                       Whatever It Takes
# 18                            Passionfruit
# 19           Obsession (feat. Jon Bellion)
#
#                                              name_new
# 0                                           All Night
# 1                                       Now and Later
# 2                                        Lot to Learn
# 3                                              Issues
# 4                                        Now Or Never
# 5   I'm the One (feat. Justin Bieber, Quavo, Chanc...
# 6                                 Scared to Be Lonely
# 7                                            Believer
# 8                                             Tuesday
# 9                                        Now Or Never
# 10                     You Don't Know Me - Radio Edit
# 11             Pretty Girl - Cheat Codes X CADE Remix
# 12                                        Bon appétit
# 13                                  Sign of the Times
# 14                  Slide (feat. Frank Ocean & Migos)
# 15                                            Thunder
# 16                                      Unforgettable
# 17                                  Whatever It Takes
# 18                                       Passionfruit
# 19                      Obsession (feat. Jon Bellion)

# %%
def get_row_counts(uris):
  return uris.apply(lambda uri: (combined_data_filtered.uri == uri).sum())

true_dups["uri_new_count"] = get_row_counts(true_dups.uri_new)
true_dups["uri_existing_count"] = get_row_counts(true_dups.uri_existing)

# %%
true_dups
# Out:
#                                  uri_new  \
# 0   spotify:track:4b4KcovePX8Ke2cLIQTLM0
# 1   spotify:track:08WPvDEsHvTFuB9w8tC2OS
# 2   spotify:track:2HzfRSfCogBSsgW2CckVA2
# 3   spotify:track:6D0b04NJIKfEMg040WioJQ
# 4   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 5   spotify:track:3DXncPQOG4VBw3QHh3S817
# 6   spotify:track:3ebXMykcMXOcLeJ9xZ17XH
# 7   spotify:track:0CcQNd8CINkwQfe1RDtGV6
# 8   spotify:track:7abpmGpF7PGep2rDU68GBR
# 9   spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# 10  spotify:track:00lNx0OcTJrS3MKHcB80HY
# 11  spotify:track:1NDxZ7cFAo481dtYWdrUnR
# 12  spotify:track:61WbtB6ujkpNAsAf5LjF4b
# 13  spotify:track:5Ohxk2dO5COHF1krpoPigN
# 14  spotify:track:7tr2za8SQg2CI8EDgrdtNl
# 15  spotify:track:0tKcYR2II1VCQWT79i5NrW
# 16  spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 17  spotify:track:4IWAyPf1KMq7JCyGeCjTeH
# 18  spotify:track:7hDc8b7IXETo14hHIHdnhd
# 19  spotify:track:5pvVAwQbuFoR7LkcicrKnk
#
#                             uri_existing  \
# 0   spotify:track:1yNyoWWWikbLhwIGWjZuDW
# 1   spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# 2   spotify:track:3TRFq09DUgYj1mug6RRqJW
# 3   spotify:track:1sXUWdKx03aP9Gmzft58rt
# 4   spotify:track:0Nhu3zSYbEz32IYiobV75e
# 5   spotify:track:72Q0FQQo32KJloivv5xge2
# 6   spotify:track:0KR2W3St74th8z3LS94Ffh
# 7   spotify:track:6VRghJeP6I0w1KxkdWFfIh
# 8   spotify:track:5c4tB0saSkNHX5CyDosuF7
# 9   spotify:track:1mDGDb2fUmUMdqV3tb8VKQ
# 10  spotify:track:4WrS6vezaPwOafKJmHqMEU
# 11  spotify:track:39IsH7B5byx8NRlEKlZVg9
# 12  spotify:track:14oOKFGuXu8DqvOe1W8vao
# 13  spotify:track:5ELRkzdzz0HvGpMDlfZHkV
# 14  spotify:track:6gpcs5eMhJwax4mIfKDYQk
# 15  spotify:track:56lBX2WHqfGuoeZxZvUnVj
# 16  spotify:track:1F2HXIJrE2Xn81OzT2zZvW
# 17  spotify:track:4izg6Hydc6XGErWW6nbdsV
# 18  spotify:track:5mCPDVBb16L4XQwDdbRUpz
# 19  spotify:track:542Xd5qDeLBvgXZXhfW7LE
#
#                              name_existing  \
# 0                                All Night
# 1                            Now and Later
# 2                             Lot to Learn
# 3                                   Issues
# 4                             Now Or Never
# 5                              I'm the One
# 6                      Scared to Be Lonely
# 7                                 Believer
# 8         Tuesday (feat. Danelle Sandoval)
# 9                             Now Or Never
# 10          You Don't Know Me - Radio Edit
# 11  Pretty Girl - Cheat Codes X CADE Remix
# 12                             Bon Appétit
# 13                       Sign of the Times
# 14       Slide (feat. Frank Ocean & Migos)
# 15                                 Thunder
# 16                           Unforgettable
# 17                       Whatever It Takes
# 18                            Passionfruit
# 19           Obsession (feat. Jon Bellion)
#
#                                              name_new  uri_new_count  \
# 0                                           All Night            131
# 1                                       Now and Later            112
# 2                                        Lot to Learn             41
# 3                                              Issues            549
# 4                                        Now Or Never            789
# 5   I'm the One (feat. Justin Bieber, Quavo, Chanc...           4916
# 6                                 Scared to Be Lonely           5872
# 7                                            Believer           5644
# 8                                             Tuesday           1632
# 9                                        Now Or Never            789
# 10                     You Don't Know Me - Radio Edit           2426
# 11             Pretty Girl - Cheat Codes X CADE Remix           3766
# 12                                        Bon appétit            199
# 13                                  Sign of the Times           2580
# 14                  Slide (feat. Frank Ocean & Migos)           3726
# 15                                            Thunder           7653
# 16                                      Unforgettable           6153
# 17                                  Whatever It Takes            933
# 18                                       Passionfruit           3136
# 19                      Obsession (feat. Jon Bellion)             69
#
#     uri_existing_count
# 0                 2459
# 1                 1199
# 2                  647
# 3                 3889
# 4                  573
# 5                 1453
# 6                  418
# 7                  631
# 8                  338
# 9                  660
# 10                 740
# 11                 647
# 12                 247
# 13                 330
# 14                 868
# 15                 737
# 16                1190
# 17                 118
# 18                  35
# 19                  15

# %%
true_dups.sum()
# Out:
# uri_new               spotify:track:4b4KcovePX8Ke2cLIQTLM0spotify:tr...
# uri_existing          spotify:track:1yNyoWWWikbLhwIGWjZuDWspotify:tr...
# name_existing         All NightNow and LaterLot to LearnIssuesNow Or...
# name_new              All NightNow and LaterLot to LearnIssuesNow Or...
# uri_new_count                                                     51116
# uri_existing_count                                                17194
# dtype: object

# %%
def get_suitable_replacement(dup_row):
  values = [dup_row.uri_new, dup_row.uri_existing]
  if dup_row.uri_new_count > dup_row.uri_existing_count:
    columns = ["replace_with", "uri"]
  else:
    columns = ["uri", "replace_with"]
  return pd.Series(values, index=columns)

# %%
replace_with = true_dups.apply(get_suitable_replacement, axis=1).set_index("uri").replace_with
replace_with
# Out:
# uri
# spotify:track:4b4KcovePX8Ke2cLIQTLM0    spotify:track:1yNyoWWWikbLhwIGWjZuDW
# spotify:track:08WPvDEsHvTFuB9w8tC2OS    spotify:track:43jBqV3j3Xi1g6wO0bhIMd
# spotify:track:2HzfRSfCogBSsgW2CckVA2    spotify:track:3TRFq09DUgYj1mug6RRqJW
# spotify:track:6D0b04NJIKfEMg040WioJQ    spotify:track:1sXUWdKx03aP9Gmzft58rt
# spotify:track:0Nhu3zSYbEz32IYiobV75e    spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# spotify:track:72Q0FQQo32KJloivv5xge2    spotify:track:3DXncPQOG4VBw3QHh3S817
# spotify:track:0KR2W3St74th8z3LS94Ffh    spotify:track:3ebXMykcMXOcLeJ9xZ17XH
# spotify:track:6VRghJeP6I0w1KxkdWFfIh    spotify:track:0CcQNd8CINkwQfe1RDtGV6
# spotify:track:5c4tB0saSkNHX5CyDosuF7    spotify:track:7abpmGpF7PGep2rDU68GBR
# spotify:track:1mDGDb2fUmUMdqV3tb8VKQ    spotify:track:7i2DJ88J7jQ8K7zqFX2fW8
# spotify:track:4WrS6vezaPwOafKJmHqMEU    spotify:track:00lNx0OcTJrS3MKHcB80HY
# spotify:track:39IsH7B5byx8NRlEKlZVg9    spotify:track:1NDxZ7cFAo481dtYWdrUnR
# spotify:track:61WbtB6ujkpNAsAf5LjF4b    spotify:track:14oOKFGuXu8DqvOe1W8vao
# spotify:track:5ELRkzdzz0HvGpMDlfZHkV    spotify:track:5Ohxk2dO5COHF1krpoPigN
# spotify:track:6gpcs5eMhJwax4mIfKDYQk    spotify:track:7tr2za8SQg2CI8EDgrdtNl
# spotify:track:56lBX2WHqfGuoeZxZvUnVj    spotify:track:0tKcYR2II1VCQWT79i5NrW
# spotify:track:1F2HXIJrE2Xn81OzT2zZvW    spotify:track:3B54sVLJ402zGa6Xm4YGNe
# spotify:track:4izg6Hydc6XGErWW6nbdsV    spotify:track:4IWAyPf1KMq7JCyGeCjTeH
# spotify:track:5mCPDVBb16L4XQwDdbRUpz    spotify:track:7hDc8b7IXETo14hHIHdnhd
# spotify:track:542Xd5qDeLBvgXZXhfW7LE    spotify:track:5pvVAwQbuFoR7LkcicrKnk
# Name: replace_with, dtype: object

# %%
data_replaced_duplicates = combined_data_filtered.copy()
data_replaced_duplicates.loc[data_replaced_duplicates.uri.isin(replace_with.index), "uri"]
# Out:
# region     date        rank
# Argentina  2017-05-18  48      spotify:track:72Q0FQQo32KJloivv5xge2
# Australia  2017-01-01  26      spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                        34      spotify:track:08WPvDEsHvTFuB9w8tC2OS
#            2017-01-02  27      spotify:track:4b4KcovePX8Ke2cLIQTLM0
#                        34      spotify:track:08WPvDEsHvTFuB9w8tC2OS
#                                                ...
# Uruguay    2017-05-28  43      spotify:track:72Q0FQQo32KJloivv5xge2
#            2017-05-29  45      spotify:track:72Q0FQQo32KJloivv5xge2
#            2017-06-01  45      spotify:track:72Q0FQQo32KJloivv5xge2
#            2017-06-03  47      spotify:track:72Q0FQQo32KJloivv5xge2
#            2017-06-04  48      spotify:track:72Q0FQQo32KJloivv5xge2
# Name: uri, Length: 9785, dtype: object

# %% [markdown]
# Does that make sense?

# %%
def pick_smaller(row):
  if row.uri_new_count < row.uri_existing_count:
    return row.uri_new_count
  else:
    return row.uri_existing_count

true_dups.apply(pick_smaller, axis=1).sum()
# Out:
# 9785

# %%
len(data_replaced_duplicates)
# Out:
# 4569311

# %% [markdown]
# Yes. So all that work just to fix 9.4k rows of over 4 mio. lool

# %%
def replace_duplicate(uri: str):
  return replace_with[uri]

# %%
data_replaced_duplicates.loc[data_replaced_duplicates.uri.isin(replace_with.index), "uri"].apply(replace_duplicate)
# Out:
# region     date        rank
# Argentina  2017-05-18  48      spotify:track:3DXncPQOG4VBw3QHh3S817
# Australia  2017-01-01  26      spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                        34      spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#            2017-01-02  27      spotify:track:1yNyoWWWikbLhwIGWjZuDW
#                        34      spotify:track:43jBqV3j3Xi1g6wO0bhIMd
#                                                ...
# Uruguay    2017-05-28  43      spotify:track:3DXncPQOG4VBw3QHh3S817
#            2017-05-29  45      spotify:track:3DXncPQOG4VBw3QHh3S817
#            2017-06-01  45      spotify:track:3DXncPQOG4VBw3QHh3S817
#            2017-06-03  47      spotify:track:3DXncPQOG4VBw3QHh3S817
#            2017-06-04  48      spotify:track:3DXncPQOG4VBw3QHh3S817
# Name: uri, Length: 9785, dtype: object

# %%
data_replaced_duplicates.loc[data_replaced_duplicates.uri.isin(replace_with.index), "uri"] = data_replaced_duplicates.loc[data_replaced_duplicates.uri.isin(replace_with.index), "uri"].apply(replace_duplicate)

# %%
data_replaced_duplicates.loc[data_replaced_duplicates.uri.isin(replace_with.index), "uri"]
# Out:
# Series([], Name: uri, dtype: object)

# %% [markdown]
# I guess we achieved what we wanted, nice

# %%
data_replaced_duplicates
# Out:
#                                                          title  \
# region    date       rank
# Argentina 2017-01-01 1                 Chantaje (feat. Maluma)
#                      2             Vente Pa' Ca (feat. Maluma)
#                      3              Reggaetón Lento (Bailemos)
#                      4                                  Safari
#                      5                             Shaky Shaky
# ...                                                        ...
# Uruguay   2021-12-31 46                             Los Tragos
#                      47                                   Sabe
#                      48    Morad: Bzrp Music Sessions, Vol. 47
#                      49                             2:50 Remix
#                      50                                 París
#
#                                                           artist   streams  \
# region    date       rank
# Argentina 2017-01-01 1                                   Shakira  253019.0
#                      2                              Ricky Martin  223988.0
#                      3                                      CNCO  210943.0
#                      4     J Balvin, Pharrell Williams, BIA, Sky  173865.0
#                      5                              Daddy Yankee  153956.0
# ...                                                          ...       ...
# Uruguay   2021-12-31 46                      Reik, Maria Becerra   10707.0
#                      47             Nicki Nicole, Rauw Alejandro   10635.0
#                      48                          Bizarrap, Morad   10491.0
#                      49                          MYA, TINI, Duki   10388.0
#                      50                                 Ingratax   10137.0
#
#                                                             uri    source
# region    date       rank
# Argentina 2017-01-01 1     spotify:track:6mICuAdrwEjh6Y6lroV2Kg  existing
#                      2     spotify:track:7DM4BPaS7uofFul3ywMe46  existing
#                      3     spotify:track:3AEZUABDXNtecAOSC1qTfo  existing
#                      4     spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  existing
#                      5     spotify:track:58IL315gMSTD37DOZPJ2hf  existing
# ...                                                         ...       ...
# Uruguay   2021-12-31 46    spotify:track:7iXJg4IUyrWont5YSQrbKP       new
#                      47    spotify:track:0XYZhJIcwKNjd0tjbSXwaQ       new
#                      48    spotify:track:39yyHtQ4tkjZzd8TfIBKQw       new
#                      49    spotify:track:5eyO0n1HiiSWdGaaSoK731       new
#                      50    spotify:track:4bF2y8rR7GUjrd5LNEvej3       new
#
# [4569311 rows x 5 columns]

# %%
temp = data_replaced_duplicates[["uri", "streams", "source"]]
temp
# Out:
#                                                             uri   streams  \
# region    date       rank
# Argentina 2017-01-01 1     spotify:track:6mICuAdrwEjh6Y6lroV2Kg  253019.0
#                      2     spotify:track:7DM4BPaS7uofFul3ywMe46  223988.0
#                      3     spotify:track:3AEZUABDXNtecAOSC1qTfo  210943.0
#                      4     spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  173865.0
#                      5     spotify:track:58IL315gMSTD37DOZPJ2hf  153956.0
# ...                                                         ...       ...
# Uruguay   2021-12-31 46    spotify:track:7iXJg4IUyrWont5YSQrbKP   10707.0
#                      47    spotify:track:0XYZhJIcwKNjd0tjbSXwaQ   10635.0
#                      48    spotify:track:39yyHtQ4tkjZzd8TfIBKQw   10491.0
#                      49    spotify:track:5eyO0n1HiiSWdGaaSoK731   10388.0
#                      50    spotify:track:4bF2y8rR7GUjrd5LNEvej3   10137.0
#
#                              source
# region    date       rank
# Argentina 2017-01-01 1     existing
#                      2     existing
#                      3     existing
#                      4     existing
#                      5     existing
# ...                             ...
# Uruguay   2021-12-31 46         new
#                      47         new
#                      48         new
#                      49         new
#                      50         new
#
# [4569311 rows x 3 columns]

# %%
track_counts_temp = (
    temp.groupby(["region", "date", "rank"]).count().uri
)
track_counts_temp.loc[track_counts_temp > 1]
# Out:
# region     date        rank
# Argentina  2017-07-20  6       2
#                        8       2
#                        10      2
#                        11      2
#                        17      2
#                               ..
# Uruguay    2021-08-13  25      2
#                        27      2
#                        33      2
#                        35      2
#                        36      2
# Name: uri, Length: 5486, dtype: int64

# %%
remaining_duplicates = track_counts_temp[track_counts_temp > 1].index.unique()

# %%
remaining_duplicates
# Out:
# MultiIndex([('Argentina', '2017-07-20',  6),
#             ('Argentina', '2017-07-20',  8),
#             ('Argentina', '2017-07-20', 10),
#             ('Argentina', '2017-07-20', 11),
#             ('Argentina', '2017-07-20', 17),
#             ('Argentina', '2017-07-20', 21),
#             ('Argentina', '2017-07-20', 22),
#             ('Argentina', '2017-07-20', 23),
#             ('Argentina', '2017-07-20', 24),
#             ('Argentina', '2017-07-20', 27),
#             ...
#             (  'Uruguay', '2021-08-12', 35),
#             (  'Uruguay', '2021-08-12', 39),
#             (  'Uruguay', '2021-08-13',  2),
#             (  'Uruguay', '2021-08-13',  4),
#             (  'Uruguay', '2021-08-13', 16),
#             (  'Uruguay', '2021-08-13', 25),
#             (  'Uruguay', '2021-08-13', 27),
#             (  'Uruguay', '2021-08-13', 33),
#             (  'Uruguay', '2021-08-13', 35),
#             (  'Uruguay', '2021-08-13', 36)],
#            names=['region', 'date', 'rank'], length=5486)

# %%
temp.loc[remaining_duplicates]
# Out:
#                                                             uri   streams  \
# region    date       rank
# Argentina 2017-07-20 6     spotify:track:2cnKEkpVUSV4wnjQiTWfH6  162494.0
#                      6     spotify:track:2cnKEkpVUSV4wnjQiTWfH6  162494.0
#                      8     spotify:track:0Szp49tpFasIjX04Mcsydp  130466.0
#                      8     spotify:track:0Szp49tpFasIjX04Mcsydp  130466.0
#                      10    spotify:track:6m2LNopVJKsvBB9l7Z1rwn  117570.0
# ...                                                         ...       ...
# Uruguay   2021-08-13 33    spotify:track:4M4DTyLupKvbJKlE4I4EYq    9994.0
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2    9251.0
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2    9251.0
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX    9179.0
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX    9179.0
#
#                              source
# region    date       rank
# Argentina 2017-07-20 6     existing
#                      6          new
#                      8     existing
#                      8          new
#                      10    existing
# ...                             ...
# Uruguay   2021-08-13 33         new
#                      35    existing
#                      35         new
#                      36    existing
#                      36         new
#
# [10972 rows x 3 columns]

# %%
len(remaining_duplicates.unique())
# Out:
# 5486

# %%
problematic_charts = remaining_duplicates.droplevel(2).unique()
problematic_charts
# Out:
# MultiIndex([('Argentina', '2017-07-20'),
#             ('Argentina', '2017-07-21'),
#             ('Argentina', '2017-11-09'),
#             ('Argentina', '2017-11-10'),
#             ('Argentina', '2017-11-11'),
#             ('Argentina', '2017-11-12'),
#             ('Argentina', '2017-11-13'),
#             ('Argentina', '2017-11-14'),
#             ('Australia', '2017-07-20'),
#             ('Australia', '2017-07-21'),
#             ...
#             (  'Uruguay', '2017-11-09'),
#             (  'Uruguay', '2017-11-10'),
#             (  'Uruguay', '2017-11-11'),
#             (  'Uruguay', '2017-11-12'),
#             (  'Uruguay', '2017-11-13'),
#             (  'Uruguay', '2017-11-14'),
#             (  'Uruguay', '2021-08-10'),
#             (  'Uruguay', '2021-08-11'),
#             (  'Uruguay', '2021-08-12'),
#             (  'Uruguay', '2021-08-13')],
#            names=['region', 'date'], length=395)

# %%
temp.reset_index().sort_values(by=["region", "date", "rank"]).set_index(["region", "date"]).loc[problematic_charts].source.value_counts()
# Out:
# existing    18582
# new          5486
# Name: source, dtype: int64

# %% [markdown]
# Apparently there was a mismatch between the new data and the existing data we already had in some cases. Let's just remove the new entries and keep the existing ones instead.
#
# I don't know what a smart approach for doing this is, so I just do it in a super complicated way instead lol

# %%
duplicates_fixed = temp.loc[remaining_duplicates].reset_index().set_index("source").drop("new").reset_index().set_index(["region", "date", "rank"])

# %%
final_data = pd.concat([temp.drop(remaining_duplicates), duplicates_fixed]).drop(columns="source")

# %%
len(final_data)
# Out:
# 4563825

# %%
final_track_counts = (
    final_data.groupby(["region", "date", "rank"]).count().uri
)
final_duplicates = final_track_counts.loc[final_track_counts > 1]
final_duplicates
# Out:
# Series([], Name: uri, dtype: int64)

# %%
final_data
# Out:
#                                                             uri   streams
# region    date       rank
# Argentina 2017-01-01 1     spotify:track:6mICuAdrwEjh6Y6lroV2Kg  253019.0
#                      2     spotify:track:7DM4BPaS7uofFul3ywMe46  223988.0
#                      3     spotify:track:3AEZUABDXNtecAOSC1qTfo  210943.0
#                      4     spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  173865.0
#                      5     spotify:track:58IL315gMSTD37DOZPJ2hf  153956.0
# ...                                                         ...       ...
# Uruguay   2021-08-13 25    spotify:track:4aXicRG47bBEcKXlDaSRwW   11431.0
#                      27    spotify:track:43qcs9NpJhDxtG91zxFkj7   10946.0
#                      33    spotify:track:4M4DTyLupKvbJKlE4I4EYq    9994.0
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2    9251.0
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX    9179.0
#
# [4563825 rows x 2 columns]

# %% [markdown]
# ### Check if final data really is "more complete"

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

track_counts_per_region_and_date = final_data.reset_index().groupby(["region", "date"]).uri.count().rename("track_count").reset_index().set_index("date")

track_counts_by_region_pivot = track_counts_per_region_and_date.reset_index().pivot(
    columns=["region"], index="date", values="track_count"
)

plt.figure(figsize=(16, 16))
min_date = mdates.date2num(track_counts_per_region_and_date.index.min())
max_date = mdates.date2num(track_counts_per_region_and_date.index.max())

plt.xticks(ticks=list(range(len(track_counts_by_region_pivot.columns))), labels=track_counts_by_region_pivot.columns, rotation=90)

y_axis = plt.gca().yaxis
y_axis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
y_axis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
y_axis.set_major_locator(mdates.MonthLocator())

plt.imshow(
    track_counts_by_region_pivot,
    aspect="auto",
    extent=[0, 50, max_date, min_date],
    cmap="Greys",
    interpolation="none",
)
plt.show()

# %%
track_counts_per_region_and_date[track_counts_per_region_and_date.track_count < 45]
# Out:
#                  region  track_count
# date
# 2017-12-01      Austria           33
# 2017-12-02      Austria           34
# 2017-12-03      Austria           36
# 2017-12-04      Austria           34
# 2017-12-05      Austria           35
# 2017-12-06      Austria           38
# 2017-12-07      Austria           42
# 2017-12-01      Germany           33
# 2017-12-02      Germany           33
# 2017-12-03      Germany           33
# 2017-12-04      Germany           33
# 2017-12-05      Germany           33
# 2017-12-06      Germany           33
# 2017-12-07      Germany           33
# 2017-12-08      Germany           36
# 2017-12-09      Germany           44
# 2017-12-11      Germany           41
# 2017-12-12      Germany           43
# 2017-12-13      Germany           43
# 2017-01-01       Greece           39
# 2017-01-01      Iceland           37
# 2017-01-01     Slovakia           19
# 2017-01-02     Slovakia           37
# 2017-01-04     Slovakia           43
# 2017-01-05     Slovakia           38
# 2017-01-06     Slovakia           38
# 2017-01-07     Slovakia           40
# 2017-01-08     Slovakia           39
# 2017-01-09     Slovakia           37
# 2017-01-10     Slovakia           39
# 2017-01-11     Slovakia           42
# 2017-01-12     Slovakia           42
# 2017-01-16     Slovakia           43
# 2017-01-17     Slovakia           44
# 2017-01-18     Slovakia           42
# 2017-01-19     Slovakia           39
# 2017-01-20     Slovakia           42
# 2017-01-23     Slovakia           43
# 2017-01-25     Slovakia           44
# 2017-01-26     Slovakia           44
# 2017-01-27     Slovakia           44
# 2017-02-06     Slovakia           42
# 2017-02-10     Slovakia           41
# 2017-02-15     Slovakia           44
# 2017-02-16     Slovakia           43
# 2017-04-17     Slovakia           41
# 2017-12-01  Switzerland           34
# 2017-12-02  Switzerland           39
# 2017-12-03  Switzerland           42
# 2017-12-04  Switzerland           39
# 2017-12-05  Switzerland           42

# %%
len(final_data)
# Out:
# 4563825

# %%
len(existing_data)
# Out:
# 4477832

# %%
len(new_data)
# Out:
# 104575

# %%
len(final_data) - len(existing_data)
# Out:
# 85993

# %%
track_counts_per_region_and_date[track_counts_per_region_and_date.track_count == 0]
# Out:
# Empty DataFrame
# Columns: [region, track_count]
# Index: []

# %%
track_counts_per_region_and_date[track_counts_per_region_and_date.track_count > 50]
# Out:
# Empty DataFrame
# Columns: [region, track_count]
# Index: []

# %%
final_data
# Out:
#                                                             uri   streams
# region    date       rank
# Argentina 2017-01-01 1     spotify:track:6mICuAdrwEjh6Y6lroV2Kg  253019.0
#                      2     spotify:track:7DM4BPaS7uofFul3ywMe46  223988.0
#                      3     spotify:track:3AEZUABDXNtecAOSC1qTfo  210943.0
#                      4     spotify:track:6rQSrBHf7HlZjtcMZ4S4bO  173865.0
#                      5     spotify:track:58IL315gMSTD37DOZPJ2hf  153956.0
# ...                                                         ...       ...
# Uruguay   2021-08-13 25    spotify:track:4aXicRG47bBEcKXlDaSRwW   11431.0
#                      27    spotify:track:43qcs9NpJhDxtG91zxFkj7   10946.0
#                      33    spotify:track:4M4DTyLupKvbJKlE4I4EYq    9994.0
#                      35    spotify:track:5jzEwSyyymBlf1fa1o39T2    9251.0
#                      36    spotify:track:5PjdY0CKGZdEuoNab3yDmX    9179.0
#
# [4563825 rows x 2 columns]

# %% [markdown]
# In total, we gained around 86k new rows with this approach, which is not too bad :) And, most importantly, data is now available across a span of exactly five years! It is not 100% complete, but there's nothing we can do about it, for some days Spotify just hasn't made the chart data avaiable :/

# %% [markdown]
# ## Converting URIs to IDs

# %% [markdown]
# Let's convert URIs to IDs

# %%
final_data["id"] = final_data.uri.str.split("spotify:track:", expand=True).iloc[:,1]
final_data.drop(columns="uri", inplace=True)
final_data
# Out:
#                             streams                      id
# region    date       rank
# Argentina 2017-01-01 1     253019.0  6mICuAdrwEjh6Y6lroV2Kg
#                      2     223988.0  7DM4BPaS7uofFul3ywMe46
#                      3     210943.0  3AEZUABDXNtecAOSC1qTfo
#                      4     173865.0  6rQSrBHf7HlZjtcMZ4S4bO
#                      5     153956.0  58IL315gMSTD37DOZPJ2hf
# ...                             ...                     ...
# Uruguay   2021-08-13 25     11431.0  4aXicRG47bBEcKXlDaSRwW
#                      27     10946.0  43qcs9NpJhDxtG91zxFkj7
#                      33      9994.0  4M4DTyLupKvbJKlE4I4EYq
#                      35      9251.0  5jzEwSyyymBlf1fa1o39T2
#                      36      9179.0  5PjdY0CKGZdEuoNab3yDmX
#
# [4563825 rows x 2 columns]

# %% [markdown]
# ## Checking for new tracks

# %% [markdown]
# Have we received any new tracks through the search for missing tracks?

# %%
tracks = pd.read_csv(get_data_path("tracks.csv"), index_col="id")

# %%
tracks
# Out:
#                                                                     album  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'album_type': 'album', 'artists': [{'external...
# 7DM4BPaS7uofFul3ywMe46  {'album_type': 'single', 'artists': [{'externa...
# 3AEZUABDXNtecAOSC1qTfo  {'album_type': 'album', 'artists': [{'external...
# 6rQSrBHf7HlZjtcMZ4S4bO  {'album_type': 'album', 'artists': [{'external...
# 58IL315gMSTD37DOZPJ2hf  {'album_type': 'single', 'artists': [{'externa...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'album_type': 'album', 'artists': [{'external...
# 7asgcWpGtv92TiMZUYNWVt  {'album_type': 'single', 'artists': [{'externa...
# 1PIiIVeacU0Fj7Rm9lFlsx  {'album_type': 'single', 'artists': [{'externa...
# 6yf3MxEOScNBTYCHOAIiNQ  {'album_type': 'single', 'artists': [{'externa...
# 7KA4W4McWYRpgf0fWsJZWB  {'album_type': 'album', 'artists': [{'external...
#
#                                                                   artists  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  [{'external_urls': {'spotify': 'https://open.s...
# 7DM4BPaS7uofFul3ywMe46  [{'external_urls': {'spotify': 'https://open.s...
# 3AEZUABDXNtecAOSC1qTfo  [{'external_urls': {'spotify': 'https://open.s...
# 6rQSrBHf7HlZjtcMZ4S4bO  [{'external_urls': {'spotify': 'https://open.s...
# 58IL315gMSTD37DOZPJ2hf  [{'external_urls': {'spotify': 'https://open.s...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  [{'external_urls': {'spotify': 'https://open.s...
# 7asgcWpGtv92TiMZUYNWVt  [{'external_urls': {'spotify': 'https://open.s...
# 1PIiIVeacU0Fj7Rm9lFlsx  [{'external_urls': {'spotify': 'https://open.s...
# 6yf3MxEOScNBTYCHOAIiNQ  [{'external_urls': {'spotify': 'https://open.s...
# 7KA4W4McWYRpgf0fWsJZWB  [{'external_urls': {'spotify': 'https://open.s...
#
#                                                         available_markets  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7DM4BPaS7uofFul3ywMe46  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 3AEZUABDXNtecAOSC1qTfo  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 6rQSrBHf7HlZjtcMZ4S4bO                                                 []
# 58IL315gMSTD37DOZPJ2hf                                                 []
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7asgcWpGtv92TiMZUYNWVt  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 1PIiIVeacU0Fj7Rm9lFlsx                                                 []
# 6yf3MxEOScNBTYCHOAIiNQ  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7KA4W4McWYRpgf0fWsJZWB  ['AD', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU...
#
#                         disc_number  duration_ms  explicit  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg            1       195840     False
# 7DM4BPaS7uofFul3ywMe46            1       259195     False
# 3AEZUABDXNtecAOSC1qTfo            1       222560     False
# 6rQSrBHf7HlZjtcMZ4S4bO            1       205600     False
# 58IL315gMSTD37DOZPJ2hf            1       234320     False
# ...                             ...          ...       ...
# 6ClL99PvuCeBLTFTdnR1Hw            1       179120     False
# 7asgcWpGtv92TiMZUYNWVt            1       211896     False
# 1PIiIVeacU0Fj7Rm9lFlsx            1       180240      True
# 6yf3MxEOScNBTYCHOAIiNQ            1       165466      True
# 7KA4W4McWYRpgf0fWsJZWB            1       180386      True
#
#                                     external_ids  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'isrc': 'USSD11600299'}
# 7DM4BPaS7uofFul3ywMe46  {'isrc': 'USSD11600252'}
# 3AEZUABDXNtecAOSC1qTfo  {'isrc': 'USSD11600135'}
# 6rQSrBHf7HlZjtcMZ4S4bO  {'isrc': 'USUM71604778'}
# 58IL315gMSTD37DOZPJ2hf  {'isrc': 'US2BU1600020'}
# ...                                          ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'isrc': 'UYM120700001'}
# 7asgcWpGtv92TiMZUYNWVt  {'isrc': 'UYM122103910'}
# 1PIiIVeacU0Fj7Rm9lFlsx  {'isrc': 'BXIV82097196'}
# 6yf3MxEOScNBTYCHOAIiNQ  {'isrc': 'GBUM71702567'}
# 7KA4W4McWYRpgf0fWsJZWB  {'isrc': 'USQX91701275'}
#
#                                                             external_urls  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'spotify': 'https://open.spotify.com/track/6m...
# 7DM4BPaS7uofFul3ywMe46  {'spotify': 'https://open.spotify.com/track/7D...
# 3AEZUABDXNtecAOSC1qTfo  {'spotify': 'https://open.spotify.com/track/3A...
# 6rQSrBHf7HlZjtcMZ4S4bO  {'spotify': 'https://open.spotify.com/track/6r...
# 58IL315gMSTD37DOZPJ2hf  {'spotify': 'https://open.spotify.com/track/58...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'spotify': 'https://open.spotify.com/track/6C...
# 7asgcWpGtv92TiMZUYNWVt  {'spotify': 'https://open.spotify.com/track/7a...
# 1PIiIVeacU0Fj7Rm9lFlsx  {'spotify': 'https://open.spotify.com/track/1P...
# 6yf3MxEOScNBTYCHOAIiNQ  {'spotify': 'https://open.spotify.com/track/6y...
# 7KA4W4McWYRpgf0fWsJZWB  {'spotify': 'https://open.spotify.com/track/7K...
#
#                                                                      href  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 7DM4BPaS7uofFul3ywMe46  https://api.spotify.com/v1/tracks/7DM4BPaS7uof...
# 3AEZUABDXNtecAOSC1qTfo  https://api.spotify.com/v1/tracks/3AEZUABDXNte...
# 6rQSrBHf7HlZjtcMZ4S4bO  https://api.spotify.com/v1/tracks/6rQSrBHf7HlZ...
# 58IL315gMSTD37DOZPJ2hf  https://api.spotify.com/v1/tracks/58IL315gMSTD...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  https://api.spotify.com/v1/tracks/6ClL99PvuCeB...
# 7asgcWpGtv92TiMZUYNWVt  https://api.spotify.com/v1/tracks/7asgcWpGtv92...
# 1PIiIVeacU0Fj7Rm9lFlsx  https://api.spotify.com/v1/tracks/1PIiIVeacU0F...
# 6yf3MxEOScNBTYCHOAIiNQ  https://api.spotify.com/v1/tracks/6yf3MxEOScNB...
# 7KA4W4McWYRpgf0fWsJZWB  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
#
#                         is_local  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg     False
# 7DM4BPaS7uofFul3ywMe46     False
# 3AEZUABDXNtecAOSC1qTfo     False
# 6rQSrBHf7HlZjtcMZ4S4bO     False
# 58IL315gMSTD37DOZPJ2hf     False
# ...                          ...
# 6ClL99PvuCeBLTFTdnR1Hw     False
# 7asgcWpGtv92TiMZUYNWVt     False
# 1PIiIVeacU0Fj7Rm9lFlsx     False
# 6yf3MxEOScNBTYCHOAIiNQ     False
# 7KA4W4McWYRpgf0fWsJZWB     False
#
#                                                                   name  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg                         Chantaje (feat. Maluma)
# 7DM4BPaS7uofFul3ywMe46                     Vente Pa' Ca (feat. Maluma)
# 3AEZUABDXNtecAOSC1qTfo                      Reggaetón Lento (Bailemos)
# 6rQSrBHf7HlZjtcMZ4S4bO                                          Safari
# 58IL315gMSTD37DOZPJ2hf                                     Shaky Shaky
# ...                                                                ...
# 6ClL99PvuCeBLTFTdnR1Hw                              Que Tiene la Noche
# 7asgcWpGtv92TiMZUYNWVt                                      Me Encanta
# 1PIiIVeacU0Fj7Rm9lFlsx                                          Paypal
# 6yf3MxEOScNBTYCHOAIiNQ  Instruction (feat. Demi Lovato & Stefflon Don)
# 7KA4W4McWYRpgf0fWsJZWB                See You Again (feat. Kali Uchis)
#
#                         popularity  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg          76
# 7DM4BPaS7uofFul3ywMe46          72
# 3AEZUABDXNtecAOSC1qTfo          72
# 6rQSrBHf7HlZjtcMZ4S4bO           0
# 58IL315gMSTD37DOZPJ2hf           0
# ...                            ...
# 6ClL99PvuCeBLTFTdnR1Hw          42
# 7asgcWpGtv92TiMZUYNWVt          58
# 1PIiIVeacU0Fj7Rm9lFlsx           0
# 6yf3MxEOScNBTYCHOAIiNQ          52
# 7KA4W4McWYRpgf0fWsJZWB          84
#
#                                                               preview_url  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  https://p.scdn.co/mp3-preview/b7a66b261ebbe2aa...
# 7DM4BPaS7uofFul3ywMe46  https://p.scdn.co/mp3-preview/21e38a8983daf1c3...
# 3AEZUABDXNtecAOSC1qTfo  https://p.scdn.co/mp3-preview/ced5c17cadb43603...
# 6rQSrBHf7HlZjtcMZ4S4bO                                                NaN
# 58IL315gMSTD37DOZPJ2hf                                                NaN
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  https://p.scdn.co/mp3-preview/93168930edca3314...
# 7asgcWpGtv92TiMZUYNWVt  https://p.scdn.co/mp3-preview/719b6f57859cf341...
# 1PIiIVeacU0Fj7Rm9lFlsx                                                NaN
# 6yf3MxEOScNBTYCHOAIiNQ  https://p.scdn.co/mp3-preview/d528dbeae270d471...
# 7KA4W4McWYRpgf0fWsJZWB  https://p.scdn.co/mp3-preview/e6c4c9656721fe0a...
#
#                         track_number   type  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg             3  track
# 7DM4BPaS7uofFul3ywMe46             1  track
# 3AEZUABDXNtecAOSC1qTfo             3  track
# 6rQSrBHf7HlZjtcMZ4S4bO             3  track
# 58IL315gMSTD37DOZPJ2hf             1  track
# ...                              ...    ...
# 6ClL99PvuCeBLTFTdnR1Hw             1  track
# 7asgcWpGtv92TiMZUYNWVt             1  track
# 1PIiIVeacU0Fj7Rm9lFlsx             1  track
# 6yf3MxEOScNBTYCHOAIiNQ             1  track
# 7KA4W4McWYRpgf0fWsJZWB             4  track
#
#                                                          uri
# id
# 6mICuAdrwEjh6Y6lroV2Kg  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 7DM4BPaS7uofFul3ywMe46  spotify:track:7DM4BPaS7uofFul3ywMe46
# 3AEZUABDXNtecAOSC1qTfo  spotify:track:3AEZUABDXNtecAOSC1qTfo
# 6rQSrBHf7HlZjtcMZ4S4bO  spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 58IL315gMSTD37DOZPJ2hf  spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                                                      ...
# 6ClL99PvuCeBLTFTdnR1Hw  spotify:track:6ClL99PvuCeBLTFTdnR1Hw
# 7asgcWpGtv92TiMZUYNWVt  spotify:track:7asgcWpGtv92TiMZUYNWVt
# 1PIiIVeacU0Fj7Rm9lFlsx  spotify:track:1PIiIVeacU0Fj7Rm9lFlsx
# 6yf3MxEOScNBTYCHOAIiNQ  spotify:track:6yf3MxEOScNBTYCHOAIiNQ
# 7KA4W4McWYRpgf0fWsJZWB  spotify:track:7KA4W4McWYRpgf0fWsJZWB
#
# [33881 rows x 16 columns]

# %%
final_data.id.unique().shape[0] - tracks.shape[0]
# Out:
# 5

# %%
new_track_ids = list(set(final_data.id) - set(tracks.index))
new_track_ids
# Out:
# ['5TS2ugx89E0hls8wtrR8vL',
#  '08QmhAybC6VHeG8gah84qA',
#  '1EeJ9fyxm3HU6SEGmx2rd2',
#  '1j5RqRiLx66wr6GyLRrV7w',
#  '2K2YkSn2utzsRntEClbyB8']

# %% [markdown]
# How many rows of the dataset are affected?

# %%
final_data[final_data.id.isin(new_track_ids)]
# Out:
#                              streams                      id
# region      date       rank
# Denmark     2017-05-30 50    28156.0  1EeJ9fyxm3HU6SEGmx2rd2
# El Salvador 2017-06-02 48     1715.0  2K2YkSn2utzsRntEClbyB8
# Japan       2017-05-30 49     5020.0  1j5RqRiLx66wr6GyLRrV7w
#             2017-05-31 46     5199.0  1j5RqRiLx66wr6GyLRrV7w
# Netherlands 2017-05-30 30    99144.0  5TS2ugx89E0hls8wtrR8vL
#             2017-05-31 35    91255.0  5TS2ugx89E0hls8wtrR8vL
#             2017-06-02 44    83277.0  5TS2ugx89E0hls8wtrR8vL
# Sweden      2017-05-30 49    61446.0  08QmhAybC6VHeG8gah84qA
#             2017-05-31 50    61445.0  08QmhAybC6VHeG8gah84qA

# %% [markdown]
# For convenience, I will just remove those few rows as we would otherwise have to update a whole lot of other related datasets.
#
# Unfortunately, several scripts for creating the other `top50_track_data.csv` file are building on the track IDs of this final dataset and have already run at this point. They are fetching data from the web, which takes quite a lot of time for some scripts. They are also not written in a smart fashion to detected data that was already fetched previously.

# %%
final_data = final_data[~final_data.id.isin(new_track_ids)]
final_data
# Out:
#                             streams                      id
# region    date       rank
# Argentina 2017-01-01 1     253019.0  6mICuAdrwEjh6Y6lroV2Kg
#                      2     223988.0  7DM4BPaS7uofFul3ywMe46
#                      3     210943.0  3AEZUABDXNtecAOSC1qTfo
#                      4     173865.0  6rQSrBHf7HlZjtcMZ4S4bO
#                      5     153956.0  58IL315gMSTD37DOZPJ2hf
# ...                             ...                     ...
# Uruguay   2021-08-13 25     11431.0  4aXicRG47bBEcKXlDaSRwW
#                      27     10946.0  43qcs9NpJhDxtG91zxFkj7
#                      33      9994.0  4M4DTyLupKvbJKlE4I4EYq
#                      35      9251.0  5jzEwSyyymBlf1fa1o39T2
#                      36      9179.0  5PjdY0CKGZdEuoNab3yDmX
#
# [4563816 rows x 2 columns]

# %% [markdown]
# ## Exporting data

# %%
final_data.to_csv(create_data_out_path("top50.csv"))
# Out:
# Data output path: /home/sejmou/Repos/Uni/VisDS/vis-ds/data/top50_complete.csv
