# %% [markdown]
# # Combining chart track data from various sources

# %% [markdown]
# This notebook documents how I combined the additional metadata for the unique songs in my "Spotify daily Top 50 for 50 countries (2017-2021)" dataset `top50.csv` from several sources to obtain a big, cleaned dataset `top50_track_data.csv`

# %%
import pandas as pd
from helpers import get_data_path, create_data_out_path
import json
from ast import literal_eval

# %% [markdown]
# ## Starting point: track metadata fetched from `api.spotify.com/v1/tracks`

# %% [markdown]
# I stored this data in `tracks.csv`. It will serve as the starting point for the final dataset as it contains metadata all the unique tracks.

# %%
tracks = pd.read_csv(
    get_data_path("tracks.csv"),
    index_col="id",  
    converters={"album": literal_eval}, # want to "parse" album objects https://stackoverflow.com/a/67079641
)

tracks
# Out:
#                                                                     album  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'album_type': 'album', 'artists': [{'external...
# 7DM4BPaS7uofFul3ywMe46  {'album_type': 'single', 'artists': [{'externa...
# 3AEZUABDXNtecAOSC1qTfo  {'album_type': 'album', 'artists': [{'external...
# 6rQSrBHf7HlZjtcMZ4S4bO  {'album_type': 'album', 'artists': [{'external...
# 58IL315gMSTD37DOZPJ2hf  {'album_type': 'single', 'artists': [{'externa...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'album_type': 'album', 'artists': [{'external...
# 7asgcWpGtv92TiMZUYNWVt  {'album_type': 'single', 'artists': [{'externa...
# 1PIiIVeacU0Fj7Rm9lFlsx  {'album_type': 'single', 'artists': [{'externa...
# 6yf3MxEOScNBTYCHOAIiNQ  {'album_type': 'single', 'artists': [{'externa...
# 7KA4W4McWYRpgf0fWsJZWB  {'album_type': 'album', 'artists': [{'external...
#
#                                                                   artists  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  [{'external_urls': {'spotify': 'https://open.s...
# 7DM4BPaS7uofFul3ywMe46  [{'external_urls': {'spotify': 'https://open.s...
# 3AEZUABDXNtecAOSC1qTfo  [{'external_urls': {'spotify': 'https://open.s...
# 6rQSrBHf7HlZjtcMZ4S4bO  [{'external_urls': {'spotify': 'https://open.s...
# 58IL315gMSTD37DOZPJ2hf  [{'external_urls': {'spotify': 'https://open.s...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  [{'external_urls': {'spotify': 'https://open.s...
# 7asgcWpGtv92TiMZUYNWVt  [{'external_urls': {'spotify': 'https://open.s...
# 1PIiIVeacU0Fj7Rm9lFlsx  [{'external_urls': {'spotify': 'https://open.s...
# 6yf3MxEOScNBTYCHOAIiNQ  [{'external_urls': {'spotify': 'https://open.s...
# 7KA4W4McWYRpgf0fWsJZWB  [{'external_urls': {'spotify': 'https://open.s...
#
#                                                         available_markets  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7DM4BPaS7uofFul3ywMe46  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 3AEZUABDXNtecAOSC1qTfo  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 6rQSrBHf7HlZjtcMZ4S4bO                                                 []
# 58IL315gMSTD37DOZPJ2hf                                                 []
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7asgcWpGtv92TiMZUYNWVt  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 1PIiIVeacU0Fj7Rm9lFlsx                                                 []
# 6yf3MxEOScNBTYCHOAIiNQ  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 7KA4W4McWYRpgf0fWsJZWB  ['AD', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU...
#
#                         disc_number  duration_ms  explicit  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg            1       195840     False
# 7DM4BPaS7uofFul3ywMe46            1       259195     False
# 3AEZUABDXNtecAOSC1qTfo            1       222560     False
# 6rQSrBHf7HlZjtcMZ4S4bO            1       205600     False
# 58IL315gMSTD37DOZPJ2hf            1       234320     False
# ...                             ...          ...       ...
# 6ClL99PvuCeBLTFTdnR1Hw            1       179120     False
# 7asgcWpGtv92TiMZUYNWVt            1       211896     False
# 1PIiIVeacU0Fj7Rm9lFlsx            1       180240      True
# 6yf3MxEOScNBTYCHOAIiNQ            1       165466      True
# 7KA4W4McWYRpgf0fWsJZWB            1       180386      True
#
#                                     external_ids  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'isrc': 'USSD11600299'}
# 7DM4BPaS7uofFul3ywMe46  {'isrc': 'USSD11600252'}
# 3AEZUABDXNtecAOSC1qTfo  {'isrc': 'USSD11600135'}
# 6rQSrBHf7HlZjtcMZ4S4bO  {'isrc': 'USUM71604778'}
# 58IL315gMSTD37DOZPJ2hf  {'isrc': 'US2BU1600020'}
# ...                                          ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'isrc': 'UYM120700001'}
# 7asgcWpGtv92TiMZUYNWVt  {'isrc': 'UYM122103910'}
# 1PIiIVeacU0Fj7Rm9lFlsx  {'isrc': 'BXIV82097196'}
# 6yf3MxEOScNBTYCHOAIiNQ  {'isrc': 'GBUM71702567'}
# 7KA4W4McWYRpgf0fWsJZWB  {'isrc': 'USQX91701275'}
#
#                                                             external_urls  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  {'spotify': 'https://open.spotify.com/track/6m...
# 7DM4BPaS7uofFul3ywMe46  {'spotify': 'https://open.spotify.com/track/7D...
# 3AEZUABDXNtecAOSC1qTfo  {'spotify': 'https://open.spotify.com/track/3A...
# 6rQSrBHf7HlZjtcMZ4S4bO  {'spotify': 'https://open.spotify.com/track/6r...
# 58IL315gMSTD37DOZPJ2hf  {'spotify': 'https://open.spotify.com/track/58...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  {'spotify': 'https://open.spotify.com/track/6C...
# 7asgcWpGtv92TiMZUYNWVt  {'spotify': 'https://open.spotify.com/track/7a...
# 1PIiIVeacU0Fj7Rm9lFlsx  {'spotify': 'https://open.spotify.com/track/1P...
# 6yf3MxEOScNBTYCHOAIiNQ  {'spotify': 'https://open.spotify.com/track/6y...
# 7KA4W4McWYRpgf0fWsJZWB  {'spotify': 'https://open.spotify.com/track/7K...
#
#                                                                      href  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 7DM4BPaS7uofFul3ywMe46  https://api.spotify.com/v1/tracks/7DM4BPaS7uof...
# 3AEZUABDXNtecAOSC1qTfo  https://api.spotify.com/v1/tracks/3AEZUABDXNte...
# 6rQSrBHf7HlZjtcMZ4S4bO  https://api.spotify.com/v1/tracks/6rQSrBHf7HlZ...
# 58IL315gMSTD37DOZPJ2hf  https://api.spotify.com/v1/tracks/58IL315gMSTD...
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  https://api.spotify.com/v1/tracks/6ClL99PvuCeB...
# 7asgcWpGtv92TiMZUYNWVt  https://api.spotify.com/v1/tracks/7asgcWpGtv92...
# 1PIiIVeacU0Fj7Rm9lFlsx  https://api.spotify.com/v1/tracks/1PIiIVeacU0F...
# 6yf3MxEOScNBTYCHOAIiNQ  https://api.spotify.com/v1/tracks/6yf3MxEOScNB...
# 7KA4W4McWYRpgf0fWsJZWB  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
#
#                         is_local  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg     False
# 7DM4BPaS7uofFul3ywMe46     False
# 3AEZUABDXNtecAOSC1qTfo     False
# 6rQSrBHf7HlZjtcMZ4S4bO     False
# 58IL315gMSTD37DOZPJ2hf     False
# ...                          ...
# 6ClL99PvuCeBLTFTdnR1Hw     False
# 7asgcWpGtv92TiMZUYNWVt     False
# 1PIiIVeacU0Fj7Rm9lFlsx     False
# 6yf3MxEOScNBTYCHOAIiNQ     False
# 7KA4W4McWYRpgf0fWsJZWB     False
#
#                                                                   name  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg                         Chantaje (feat. Maluma)
# 7DM4BPaS7uofFul3ywMe46                     Vente Pa' Ca (feat. Maluma)
# 3AEZUABDXNtecAOSC1qTfo                      Reggaetón Lento (Bailemos)
# 6rQSrBHf7HlZjtcMZ4S4bO                                          Safari
# 58IL315gMSTD37DOZPJ2hf                                     Shaky Shaky
# ...                                                                ...
# 6ClL99PvuCeBLTFTdnR1Hw                              Que Tiene la Noche
# 7asgcWpGtv92TiMZUYNWVt                                      Me Encanta
# 1PIiIVeacU0Fj7Rm9lFlsx                                          Paypal
# 6yf3MxEOScNBTYCHOAIiNQ  Instruction (feat. Demi Lovato & Stefflon Don)
# 7KA4W4McWYRpgf0fWsJZWB                See You Again (feat. Kali Uchis)
#
#                         popularity  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg          76
# 7DM4BPaS7uofFul3ywMe46          72
# 3AEZUABDXNtecAOSC1qTfo          72
# 6rQSrBHf7HlZjtcMZ4S4bO           0
# 58IL315gMSTD37DOZPJ2hf           0
# ...                            ...
# 6ClL99PvuCeBLTFTdnR1Hw          42
# 7asgcWpGtv92TiMZUYNWVt          58
# 1PIiIVeacU0Fj7Rm9lFlsx           0
# 6yf3MxEOScNBTYCHOAIiNQ          52
# 7KA4W4McWYRpgf0fWsJZWB          84
#
#                                                               preview_url  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  https://p.scdn.co/mp3-preview/b7a66b261ebbe2aa...
# 7DM4BPaS7uofFul3ywMe46  https://p.scdn.co/mp3-preview/21e38a8983daf1c3...
# 3AEZUABDXNtecAOSC1qTfo  https://p.scdn.co/mp3-preview/ced5c17cadb43603...
# 6rQSrBHf7HlZjtcMZ4S4bO                                                NaN
# 58IL315gMSTD37DOZPJ2hf                                                NaN
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  https://p.scdn.co/mp3-preview/93168930edca3314...
# 7asgcWpGtv92TiMZUYNWVt  https://p.scdn.co/mp3-preview/719b6f57859cf341...
# 1PIiIVeacU0Fj7Rm9lFlsx                                                NaN
# 6yf3MxEOScNBTYCHOAIiNQ  https://p.scdn.co/mp3-preview/d528dbeae270d471...
# 7KA4W4McWYRpgf0fWsJZWB  https://p.scdn.co/mp3-preview/e6c4c9656721fe0a...
#
#                         track_number   type  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg             3  track
# 7DM4BPaS7uofFul3ywMe46             1  track
# 3AEZUABDXNtecAOSC1qTfo             3  track
# 6rQSrBHf7HlZjtcMZ4S4bO             3  track
# 58IL315gMSTD37DOZPJ2hf             1  track
# ...                              ...    ...
# 6ClL99PvuCeBLTFTdnR1Hw             1  track
# 7asgcWpGtv92TiMZUYNWVt             1  track
# 1PIiIVeacU0Fj7Rm9lFlsx             1  track
# 6yf3MxEOScNBTYCHOAIiNQ             1  track
# 7KA4W4McWYRpgf0fWsJZWB             4  track
#
#                                                          uri
# id
# 6mICuAdrwEjh6Y6lroV2Kg  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 7DM4BPaS7uofFul3ywMe46  spotify:track:7DM4BPaS7uofFul3ywMe46
# 3AEZUABDXNtecAOSC1qTfo  spotify:track:3AEZUABDXNtecAOSC1qTfo
# 6rQSrBHf7HlZjtcMZ4S4bO  spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 58IL315gMSTD37DOZPJ2hf  spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                                                      ...
# 6ClL99PvuCeBLTFTdnR1Hw  spotify:track:6ClL99PvuCeBLTFTdnR1Hw
# 7asgcWpGtv92TiMZUYNWVt  spotify:track:7asgcWpGtv92TiMZUYNWVt
# 1PIiIVeacU0Fj7Rm9lFlsx  spotify:track:1PIiIVeacU0Fj7Rm9lFlsx
# 6yf3MxEOScNBTYCHOAIiNQ  spotify:track:6yf3MxEOScNBTYCHOAIiNQ
# 7KA4W4McWYRpgf0fWsJZWB  spotify:track:7KA4W4McWYRpgf0fWsJZWB
#
# [33881 rows x 16 columns]

# %%
tracks.columns
# Out:
# Index(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'external_ids', 'external_urls', 'href', 'is_local', 'name',
#        'popularity', 'preview_url', 'track_number', 'type', 'uri'],
#       dtype='object')

# %% [markdown]
# ### Remove redundant columns

# %%
tracks.drop(columns=[
  "uri", # can be recreated from track ID
  "type", # same for all tracks ("track")
  "artists",# information will be added later when joining with "track_artists_and_genres.csv"
  "available_markets",
  "disc_number",
  "duration_ms",# contained in "audio_features.csv" too
  "external_urls", # unfortunately only contains Spotify track URLs :/
  "href", # only Spotify API URLs in format https://api.spotify.com/v1/tracks/{track_id}
  "is_local",
  "popularity", # not really meaningful, as it seems to be "current popularity", which is probably lower for older tracks - discussion here: https://community.spotify.com/t5/Content-Questions/Artist-popularity/td-p/4415259
  "track_number",
], inplace=True)

# %% [markdown]
# ### Extract relevant album information

# %%
def extract_relevant_album_data(row):
  album = row.album
  return {
    "album_type": album["album_type"],
    "album_id": album["uri"].split("spotify:album:")[1], # https://stackoverflow.com/a/12572391/13727176
    "album_release_date": album["release_date"],
    "album_release_date_precision": album["release_date_precision"]
  }

album_data = tracks.apply(extract_relevant_album_data, result_type="expand", axis=1)
album_data
# Out:
#                        album_type                album_id album_release_date  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg      album  6bUxh58rYTL67FS8dyTKMN         2017-05-26
# 7DM4BPaS7uofFul3ywMe46     single  1FkaJUwfqLdQdSmRPBlw6l         2016-09-22
# 3AEZUABDXNtecAOSC1qTfo      album  0YLrAWUbY0nyM7PFtqnYld         2016-08-26
# 6rQSrBHf7HlZjtcMZ4S4bO      album  2LYwooMTH1iJeBvWyXXWUf         2016-06-24
# 58IL315gMSTD37DOZPJ2hf     single  2zrLk90b4qjmrxRZKyIY7X         2016-04-08
# ...                           ...                     ...                ...
# 6ClL99PvuCeBLTFTdnR1Hw      album  6zhawgybFcgvkdqpbFjbRK         2007-01-02
# 7asgcWpGtv92TiMZUYNWVt     single  08orK7pUWMWTpdOK1b3AOi         2021-10-01
# 1PIiIVeacU0Fj7Rm9lFlsx     single  0Pcp62cVNnrKo5QXTs26k1         2020-12-08
# 6yf3MxEOScNBTYCHOAIiNQ     single  4qstESQUoK2J7APuxGx0WN         2017-06-16
# 7KA4W4McWYRpgf0fWsJZWB      album  2nkto6YNI4rUYTLqEwWJ3o         2017-07-21
#
#                        album_release_date_precision
# id
# 6mICuAdrwEjh6Y6lroV2Kg                          day
# 7DM4BPaS7uofFul3ywMe46                          day
# 3AEZUABDXNtecAOSC1qTfo                          day
# 6rQSrBHf7HlZjtcMZ4S4bO                          day
# 58IL315gMSTD37DOZPJ2hf                          day
# ...                                             ...
# 6ClL99PvuCeBLTFTdnR1Hw                          day
# 7asgcWpGtv92TiMZUYNWVt                          day
# 1PIiIVeacU0Fj7Rm9lFlsx                          day
# 6yf3MxEOScNBTYCHOAIiNQ                          day
# 7KA4W4McWYRpgf0fWsJZWB                          day
#
# [33881 rows x 4 columns]

# %%
tracks = tracks.join(album_data).drop(columns="album")

# %% [markdown]
# ### Extracting Data related to International Standard Recording Codes (ISRCs)

# %%
(tracks["external_ids"].str.contains("isrc")).sum()
# Out:
# 33857

# %% [markdown]
# Almost all the tracks have an [ISRC](https://en.wikipedia.org/wiki/International_Standard_Recording_Code). This is convenient, as we can extract some information from it!

# %% [markdown]
# According to Wikipedia
# >An ISRC identifies a particular recording, not the work (composition and lyrical content) itself. Therefore, different recordings, edits, and remixes of the same work should each have their own ISRC. Works are identified by ISWC. Recordings remastered or revised in other ways are usually assigned a new ISRC.
#
# Every ISRC is of the form `"CC-XXX-YY-NNNNN"`. `CC` and `YY` are interesting, as they contain the 2-digit ISO country code of the recording and the last two digits of the release year.
#
# However, the Wikipedia article also states
# > High demand for ISRCs within the United States has caused the supply of available registrant codes to become exhausted; after December 6, 2010, new registrants in the US use country code "QM"
#
# Also,
# > "XXX" is a three character alphanumeric registrant code of the ISRC issuer. This number by itself does NOT uniquely identify the ISRC issuer as the same 3-digit registrant code may be used in various countries for different issuers. To uniquely identify an issuer, the country code and registrant code should be used together.
#
# So, the `XXX` component might be interesting as well!

# %% [markdown]
# Let's extract relevant data from the ISRCs:

# %%
def extract_isrc_data(row):
    isrc_obj_str = row.external_ids
    isrc = json.loads(isrc_obj_str.replace("'", '"')).get("isrc")
    if isrc:
        isrc = isrc.replace("-", "")
        isrc = isrc.upper()
        cc = isrc[:2]
        xxx = isrc[2:5]
        yy = isrc[5:7]
        #nn = isrc[7:] not really relevant
        if (yy[0] == "0") or (yy[0] == "1") or (yy[0] == "2"):
            year = "20" + yy
        else:
            year = "19" + yy
        year = int(year)
        out = {"isrc": isrc, "isrc_year": year, "isrc_cc": cc, "isrc_xxx": xxx}
        return out

# %%
isrc_data = tracks.apply(
    extract_isrc_data, result_type="expand", axis=1
).convert_dtypes()
isrc_data
# Out:
#                                 isrc  isrc_year isrc_cc isrc_xxx
# id
# 6mICuAdrwEjh6Y6lroV2Kg  USSD11600299       2016      US      SD1
# 7DM4BPaS7uofFul3ywMe46  USSD11600252       2016      US      SD1
# 3AEZUABDXNtecAOSC1qTfo  USSD11600135       2016      US      SD1
# 6rQSrBHf7HlZjtcMZ4S4bO  USUM71604778       2016      US      UM7
# 58IL315gMSTD37DOZPJ2hf  US2BU1600020       2016      US      2BU
# ...                              ...        ...     ...      ...
# 6ClL99PvuCeBLTFTdnR1Hw  UYM120700001       2007      UY      M12
# 7asgcWpGtv92TiMZUYNWVt  UYM122103910       2021      UY      M12
# 1PIiIVeacU0Fj7Rm9lFlsx  BXIV82097196       2020      BX      IV8
# 6yf3MxEOScNBTYCHOAIiNQ  GBUM71702567       2017      GB      UM7
# 7KA4W4McWYRpgf0fWsJZWB  USQX91701275       2017      US      QX9
#
# [33881 rows x 4 columns]

# %%
isrc_data.count()
# Out:
# isrc         33857
# isrc_year    33857
# isrc_cc      33857
# isrc_xxx     33857
# dtype: int64

# %% [markdown]
# Something is very interesting...

# %%
isrc_data[isrc_data.duplicated()]
# Out:
#                                 isrc  isrc_year isrc_cc isrc_xxx
# id
# 1WniHvhq9zTkny0WvGXX8o  USSD11600299       2016      US      SD1
# 43it4kot08akLzFIEMhXNN  USSD11600112       2016      US      SD1
# 4m5A5meIueOcDBpbqGvkQB  USSD11700088       2017      US      SD1
# 0k23rRi1B8ZHrKtzECGoyk  USUM71604779       2016      US      UM7
# 79Jhw5xn4gGn6PZak275gg  USUM71605331       2016      US      UM7
# ...                              ...        ...     ...      ...
# 7iC56CDz8miPDKaH0OEIqS  USAT22101243       2021      US      AT2
# 71l8BEtJPXXlWbV6hhTHWK  USAT22104222       2021      US      AT2
# 7ACW7VpgoKmfM1sKo15UhX  USRC12101071       2021      US      RC1
# 7M6CFruBrM5x7u0lTMtm6r  ES5701501180       2015      ES      570
# 6yf3MxEOScNBTYCHOAIiNQ  GBUM71702567       2017      GB      UM7
#
# [4287 rows x 4 columns]

# %% [markdown]
# Looks like a lot of duplicates! But don't worry, the reason for this is that the same song recording may appear in different albums/singles. Let's look at an example:

# %%
from helpers import get_spotify_link

example_isrc = isrc_data[isrc_data.duplicated()].iloc[0].isrc
track_ids = isrc_data[isrc_data.isrc == example_isrc].index
display(isrc_data.loc[track_ids])
print("Spotify links:")
for track_id in track_ids:
  print(get_spotify_link(track_id))
# Out:
#                                 isrc  isrc_year isrc_cc isrc_xxx
# id
# 6mICuAdrwEjh6Y6lroV2Kg  USSD11600299       2016      US      SD1
# 1WniHvhq9zTkny0WvGXX8o  USSD11600299       2016      US      SD1
# Spotify links:
# https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg
# https://open.spotify.com/track/1WniHvhq9zTkny0WvGXX8o

# %% [markdown]
# If we open the links, we notice that even the track names and release years differ (one includes the "featuring ..." part while the other doesn't), but still it's actually the same recording! As we will want to merge the track data with the Spotify Charts data, it doesn't make sense to remove duplicates here. By the way, this example also shows that the recording country code does not give us reliable information about the language of the song (in thase case it is Spanish, even though it has been assigned an US country code).

# %% [markdown]
# Those are already interesting insights. But there's more we can do.
#
# I found an [article](https://isrc.ifpi.org/en/isrc-standard/structure) on the official ISRC website. There, a [table](https://isrc.ifpi.org/downloads/Valid_Characters.pdf) with mappings of the `CC` component of ISRC codes to names and territories of ISRC agencies is linked. Unconveniently, it is provided as a PDF.
#
# I used an online tool to convert the PDF table into an Excel spreadsheet, then cleaned the data a bit in Excel, and finally exported a CSV file. It is available in the [Google Drive folder](https://drive.google.com/drive/folders/1bW2Gh3Xrcj6Dnaooe12JyCgYtmLh7Zt5?usp=sharing) of this project as `isrc_cc_agency_and_territory.csv`. Let's load it (I downloaded it to the `data` folder already here):

# %%
agencies_territories = pd.read_csv(get_data_path("isrc_cc_agency_and_territory.csv"), index_col="isrc_cc")
agencies_territories
# Out:
#                                             agency  \
# isrc_cc
# AL       International ISRC Registration Authority
# DZ       International ISRC Registration Authority
# AD       International ISRC Registration Authority
# AO       International ISRC Registration Authority
# AI       International ISRC Registration Authority
# ...                                            ...
# CP       International ISRC Registration Authority
# DG       International ISRC Registration Authority
# ZZ       International ISRC Registration Authority
# CS       International ISRC Registration Authority
# YU       International ISRC Registration Authority
#
#                               territory
# isrc_cc
# AL                              Albania
# DZ                              Algeria
# AD                              Andorra
# AO                               Angola
# AI                             Anguilla
# ...                                 ...
# CP                            Worldwide
# DG                            Worldwide
# ZZ                            Worldwide
# CS       (former) Serbia and Montenegro
# YU                  (former) Yugoslavia
#
# [179 rows x 2 columns]

# %%
agencies_territories.agency.value_counts()
# Out:
# International ISRC Registration Authority    108
# Pro-música Brazil                              5
# Recorded Music NZ                              3
# RIAA                                           3
# PPL UK                                         3
# RISA                                           2
# IFPI Switzerland                               2
# SCPP                                           2
# KMCA                                           2
# SIMIM                                          2
# Connect                                        2
# RIT                                            1
# SLOVGRAM                                       1
# PRODUCE                                        1
# SGP                                            1
# UNIMPRO                                        1
# PARI                                           1
# ZPAV                                           1
# AFP                                            1
# UPFR                                           1
# Recording Industry Association Singapore       1
# COSCAP                                         1
# SENA                                           1
# AGEDI                                          1
# IFPI Sweden                                    1
# TECA                                           1
# COTT                                           1
# MU-YAP                                         1
# Ukrainian Music Alliance                       1
# LSG                                            1
# ARIA                                           1
# Camara Uruguaya Del Disco                      1
# Gramo                                          1
# RIM                                            1
# AMPROFON                                       1
# INTERGRAM                                      1
# GRAMEK DK                                      1
# SODINPRO                                       1
# EFU                                            1
# IFPI Chile                                     1
# IFPI Finland                                   1
# BVMI                                           1
# IFPI Greece                                    1
# IFPI Hong Kong                                 1
# SFH                                            1
# IMI                                            1
# ASIRI                                          1
# PPI                                            1
# IFPI Israel                                    1
# FIMI                                           1
# JAMMS                                          1
# RIAJ                                           1
# CAPIF                                          1
# LaIPA                                          1
# AGATA                                          1
# TuneCore                                       1
# Name: agency, dtype: int64

# %%
agencies_territories.territory.value_counts()
# Out:
# Brazil                 5
# Worldwide              4
# United Kingdom         3
# United States          3
# Canada                 2
#                       ..
# Grenada                1
# Guatemala              1
# Guernsey               1
# Guyana                 1
# (former) Yugoslavia    1
# Name: territory, Length: 164, dtype: int64

# %% [markdown]
# So, we can "enrich" the `isrc_data` a bit now:

# %%
track_agencies_territories = agencies_territories[agencies_territories.index.isin(isrc_data.isrc_cc.unique())]
track_agencies_territories
# Out:
#                                             agency      territory
# isrc_cc
# AL       International ISRC Registration Authority        Albania
# AR                                           CAPIF      Argentina
# AM       International ISRC Registration Authority        Armenia
# AU                                            ARIA      Australia
# AT                                             LSG        Austria
# ...                                            ...            ...
# QZ                                            RIAA  United States
# UY                       Camara Uruguaya Del Disco        Uruguay
# TC                                        TuneCore      Worldwide
# DG       International ISRC Registration Authority      Worldwide
# ZZ       International ISRC Registration Authority      Worldwide
#
# [74 rows x 2 columns]

# %% [markdown]
# Do we have any cases where the mapping of `isrc_cc` to territory is not clear?

# %%
track_agencies_territories[track_agencies_territories.index.duplicated(False)] # show all occurences of rows with duplicated index
# Out:
#                                             agency                 territory
# isrc_cc
# DG       International ISRC Registration Authority  Turks and Caicos Islands
# DG       International ISRC Registration Authority                 Worldwide

# %% [markdown]
# Unfortunately yes. The Turks and Caicos Islands are pretty small, and `DG` is also not an official ISO 2-digit country code. So, maybe some agency moved to those islands for tax reasons? Anyway, remove that row!

# %%
track_agencies_territories = track_agencies_territories[
    ~track_agencies_territories.index.duplicated(keep="last")
]  # removes DG with Turks and Caicos Islands (as it first duplicate)
track_agencies_territories.shape
# Out:
# (73, 2)

# %% [markdown]
# Let's quickly check whether the "official list of agencies/territories" for the `CC` component of ISRC codes also covers all the unique values for `isrc_cc` in our track dataset:

# %%
set(isrc_data.isrc_cc) - set(track_agencies_territories.index)
# Out:
# {<NA>}

# %% [markdown]
# Looks good, as we do have some tracks without ISRC codes.

# %%
enriched_isrc_data = pd.merge(isrc_data, track_agencies_territories, left_on="isrc_cc", right_index=True, how="left")
enriched_isrc_data.columns
# Out:
# Index(['isrc', 'isrc_year', 'isrc_cc', 'isrc_xxx', 'agency', 'territory'], dtype='object')

# %%
enriched_isrc_data.count()
# Out:
# isrc         33857
# isrc_year    33857
# isrc_cc      33857
# isrc_xxx     33857
# agency       33857
# territory    33857
# dtype: int64

# %%
enriched_isrc_data
# Out:
#                                 isrc  isrc_year isrc_cc isrc_xxx  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  USSD11600299       2016      US      SD1
# 7DM4BPaS7uofFul3ywMe46  USSD11600252       2016      US      SD1
# 3AEZUABDXNtecAOSC1qTfo  USSD11600135       2016      US      SD1
# 6rQSrBHf7HlZjtcMZ4S4bO  USUM71604778       2016      US      UM7
# 58IL315gMSTD37DOZPJ2hf  US2BU1600020       2016      US      2BU
# ...                              ...        ...     ...      ...
# 6ClL99PvuCeBLTFTdnR1Hw  UYM120700001       2007      UY      M12
# 7asgcWpGtv92TiMZUYNWVt  UYM122103910       2021      UY      M12
# 1PIiIVeacU0Fj7Rm9lFlsx  BXIV82097196       2020      BX      IV8
# 6yf3MxEOScNBTYCHOAIiNQ  GBUM71702567       2017      GB      UM7
# 7KA4W4McWYRpgf0fWsJZWB  USQX91701275       2017      US      QX9
#
#                                            agency       territory
# id
# 6mICuAdrwEjh6Y6lroV2Kg                       RIAA   United States
# 7DM4BPaS7uofFul3ywMe46                       RIAA   United States
# 3AEZUABDXNtecAOSC1qTfo                       RIAA   United States
# 6rQSrBHf7HlZjtcMZ4S4bO                       RIAA   United States
# 58IL315gMSTD37DOZPJ2hf                       RIAA   United States
# ...                                           ...             ...
# 6ClL99PvuCeBLTFTdnR1Hw  Camara Uruguaya Del Disco         Uruguay
# 7asgcWpGtv92TiMZUYNWVt  Camara Uruguaya Del Disco         Uruguay
# 1PIiIVeacU0Fj7Rm9lFlsx          Pro-música Brazil          Brazil
# 6yf3MxEOScNBTYCHOAIiNQ                     PPL UK  United Kingdom
# 7KA4W4McWYRpgf0fWsJZWB                       RIAA   United States
#
# [33881 rows x 6 columns]

# %% [markdown]
# Rename columns and drop the `CC` and `XXX` parts (could extract exact issuers from that, however I could not find a list of all issuers - apart from that this data is pretty useless)

# %%
enriched_isrc_data = enriched_isrc_data.rename(
    columns={"agency": "isrc_agency", "territory": "isrc_territory"}
).drop(columns=["isrc_cc", "isrc_xxx"])
enriched_isrc_data.columns
# Out:
# Index(['isrc', 'isrc_year', 'isrc_agency', 'isrc_territory'], dtype='object')

# %% [markdown]
# Let's add that data to the existing DataFrame. We can remove the `external_urls` column as it doesn't contain any additional info for most of the rows.

# %%
tracks = tracks.join(enriched_isrc_data).drop(columns=["external_ids"])

# %% [markdown]
# ## Add audio features fetched from `api.spotify.com/v1/audio-features`

# %%
track_features = pd.read_csv(get_data_path("audio_features.csv"), index_col="id").drop(
    columns=["uri", "type", "track_href", "analysis_url"] # all those columns are redundant
)
track_features
# Out:
#                         danceability  energy   key  loudness  mode  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8.0    -2.921   0.0
# 7DM4BPaS7uofFul3ywMe46         0.663   0.920  11.0    -4.070   0.0
# 3AEZUABDXNtecAOSC1qTfo         0.761   0.838   4.0    -3.073   0.0
# 6rQSrBHf7HlZjtcMZ4S4bO         0.508   0.687   0.0    -4.361   1.0
# 58IL315gMSTD37DOZPJ2hf         0.899   0.626   6.0    -4.228   0.0
# ...                              ...     ...   ...       ...   ...
# 6ClL99PvuCeBLTFTdnR1Hw         0.766   0.795   9.0    -5.530   0.0
# 7asgcWpGtv92TiMZUYNWVt         0.672   0.708   7.0    -5.454   1.0
# 1PIiIVeacU0Fj7Rm9lFlsx         0.902   0.560   4.0    -4.471   0.0
# 6yf3MxEOScNBTYCHOAIiNQ         0.767   0.929   9.0    -3.080   0.0
# 7KA4W4McWYRpgf0fWsJZWB         0.558   0.559   6.0    -9.222   1.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg       0.0776       0.18700          0.000030    0.1590
# 7DM4BPaS7uofFul3ywMe46       0.2260       0.00431          0.000017    0.1010
# 3AEZUABDXNtecAOSC1qTfo       0.0502       0.40000          0.000000    0.1760
# 6rQSrBHf7HlZjtcMZ4S4bO       0.3260       0.55100          0.000003    0.1260
# 58IL315gMSTD37DOZPJ2hf       0.2920       0.07600          0.000000    0.0631
# ...                             ...           ...               ...       ...
# 6ClL99PvuCeBLTFTdnR1Hw       0.0644       0.26600          0.000000    0.3500
# 7asgcWpGtv92TiMZUYNWVt       0.0364       0.55100          0.000000    0.1280
# 1PIiIVeacU0Fj7Rm9lFlsx       0.3220       0.30200          0.000000    0.2890
# 6yf3MxEOScNBTYCHOAIiNQ       0.1850       0.10200          0.000000    0.0921
# 7KA4W4McWYRpgf0fWsJZWB       0.0959       0.37100          0.000007    0.1090
#
#                         valence    tempo  duration_ms  time_signature
# id
# 6mICuAdrwEjh6Y6lroV2Kg    0.907  102.034     195840.0             4.0
# 7DM4BPaS7uofFul3ywMe46    0.533   99.935     259196.0             4.0
# 3AEZUABDXNtecAOSC1qTfo    0.710   93.974     222560.0             4.0
# 6rQSrBHf7HlZjtcMZ4S4bO    0.555  180.044     205600.0             4.0
# 58IL315gMSTD37DOZPJ2hf    0.873   88.007     234320.0             4.0
# ...                         ...      ...          ...             ...
# 6ClL99PvuCeBLTFTdnR1Hw    0.789   85.055     179120.0             4.0
# 7asgcWpGtv92TiMZUYNWVt    0.939   79.991     211897.0             4.0
# 1PIiIVeacU0Fj7Rm9lFlsx    0.913  130.047     180241.0             4.0
# 6yf3MxEOScNBTYCHOAIiNQ    0.923  121.087     165467.0             4.0
# 7KA4W4McWYRpgf0fWsJZWB    0.620   78.558     180387.0             4.0
#
# [33881 rows x 13 columns]

# %%
tracks = tracks.join(track_features)

# %%
tracks
# Out:
#                         explicit                                  name  \
# id
# 000RW47rhEkSqjgTrZx7YX     False                      Lance Individual
# 000xQL6tZNLJzIrtIgxqSl     False  Still Got Time (feat. PARTYNEXTDOOR)
# 000xYdQfIZ4pDmBGzQalKU     False                 Eu, Você, O Mar e Ela
# 001b8t3bYPfnabpjpfG1Y4      True                             Geen Stof
# 003VDDA7J3Xb2ZFlNx7nIZ      True                               YELL OH
# ...                          ...                                   ...
# 7zxphfIdUMOfZOAVpKFlld      True           Trapper Of The Year (Intro)
# 7zyYmIdjqqiX6kLryb7QBx     False                                以後別做朋友
# 7zyZ9yPXIQebb79PrMghpV     False                               Zap Zum
# 7zyofXGhXgaqT8fhvLufdf     False                  Kuka Antais Pukille?
# 7zzhknA0A39TH81meuX7WA      True                     C'est pas des LOL
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000xQL6tZNLJzIrtIgxqSl  https://p.scdn.co/mp3-preview/83fad967740b8a85...
# 000xYdQfIZ4pDmBGzQalKU  https://p.scdn.co/mp3-preview/ae0e943883e06623...
# 001b8t3bYPfnabpjpfG1Y4  https://p.scdn.co/mp3-preview/535320aa4cbc5811...
# 003VDDA7J3Xb2ZFlNx7nIZ  https://p.scdn.co/mp3-preview/14e659590d1a70cf...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  https://p.scdn.co/mp3-preview/b48d68019fc66831...
# 7zyYmIdjqqiX6kLryb7QBx  https://p.scdn.co/mp3-preview/4d243321f0ec66ba...
# 7zyZ9yPXIQebb79PrMghpV  https://p.scdn.co/mp3-preview/2f82c76f077fb377...
# 7zyofXGhXgaqT8fhvLufdf  https://p.scdn.co/mp3-preview/236ec096925cdb1f...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                        album_type                album_id album_release_date  \
# id
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000xQL6tZNLJzIrtIgxqSl     single  2kGUeTGnkLOYlinKRJe47G         2017-03-23
# 000xYdQfIZ4pDmBGzQalKU      album  4QianJs5Ls4mxwcT7gDBww         2016-11-04
# 001b8t3bYPfnabpjpfG1Y4      album  06v2EPzWTwcP0egTJVrPdU         2021-01-21
# 003VDDA7J3Xb2ZFlNx7nIZ     single  2orYogfKeURqyS1hRP1vZ4         2020-02-07
# ...                           ...                     ...                ...
# 7zxphfIdUMOfZOAVpKFlld     single  65DP4VYecvLUlUVfCsXPLF         2021-11-19
# 7zyYmIdjqqiX6kLryb7QBx      album  1JEzXcEYuEFKKmo4mfMgC7         2014-12-19
# 7zyZ9yPXIQebb79PrMghpV      album  194szTkDIGJsa9iZJNStwN         2021-06-24
# 7zyofXGhXgaqT8fhvLufdf     single  2QIHDFGxEjYdVg8Y1QYBRv         2018-11-21
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
#
#                        album_release_date_precision          isrc  isrc_year  \
# id
# 000RW47rhEkSqjgTrZx7YX                          day  BRRGE2010642       2020
# 000xQL6tZNLJzIrtIgxqSl                          day  USRC11700675       2017
# 000xYdQfIZ4pDmBGzQalKU                          day  BRRGE1603547       2016
# 001b8t3bYPfnabpjpfG1Y4                          day  NLG662000948       2020
# 003VDDA7J3Xb2ZFlNx7nIZ                          day  QZJ842000061       2020
# ...                                             ...           ...        ...
# 7zxphfIdUMOfZOAVpKFlld                          day  SE6XY2184006       2021
# 7zyYmIdjqqiX6kLryb7QBx                          day  TWA471410001       2014
# 7zyZ9yPXIQebb79PrMghpV                          day  BCM112100037       2021
# 7zyofXGhXgaqT8fhvLufdf                          day  FIUM71800543       2018
# 7zzhknA0A39TH81meuX7WA                          day  FR96X1941264       2019
#
#                               isrc_agency  ... loudness  mode  speechiness  \
# id                                         ...
# 000RW47rhEkSqjgTrZx7YX  Pro-música Brazil  ...   -5.536   1.0       0.0509
# 000xQL6tZNLJzIrtIgxqSl               RIAA  ...   -6.029   1.0       0.0639
# 000xYdQfIZ4pDmBGzQalKU  Pro-música Brazil  ...   -6.743   1.0       0.0400
# 001b8t3bYPfnabpjpfG1Y4               SENA  ...   -4.846   1.0       0.3720
# 003VDDA7J3Xb2ZFlNx7nIZ               RIAA  ...   -6.050   0.0       0.1380
# ...                                   ...  ...      ...   ...          ...
# 7zxphfIdUMOfZOAVpKFlld        IFPI Sweden  ...  -11.291   0.0       0.3160
# 7zyYmIdjqqiX6kLryb7QBx                RIT  ...   -9.458   1.0       0.0372
# 7zyZ9yPXIQebb79PrMghpV  Pro-música Brazil  ...   -3.850   1.0       0.0400
# 7zyofXGhXgaqT8fhvLufdf       IFPI Finland  ...   -4.364   1.0       0.0300
# 7zzhknA0A39TH81meuX7WA               SCPP  ...   -6.526   0.0       0.0519
#
#                         acousticness  instrumentalness  liveness  valence  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.30900          0.000000    0.0750    0.962
# 000xQL6tZNLJzIrtIgxqSl       0.13100          0.000000    0.0852    0.524
# 000xYdQfIZ4pDmBGzQalKU       0.68400          0.000539    0.4630    0.651
# 001b8t3bYPfnabpjpfG1Y4       0.10500          0.000000    0.1170    0.541
# 003VDDA7J3Xb2ZFlNx7nIZ       0.00419          0.000000    0.2280    0.190
# ...                              ...               ...       ...      ...
# 7zxphfIdUMOfZOAVpKFlld       0.00582          0.013500    0.0827    0.461
# 7zyYmIdjqqiX6kLryb7QBx       0.72800          0.000000    0.1050    0.291
# 7zyZ9yPXIQebb79PrMghpV       0.08580          0.000000    0.1580    0.833
# 7zyofXGhXgaqT8fhvLufdf       0.20000          0.000000    0.1850    0.419
# 7zzhknA0A39TH81meuX7WA       0.18700          0.000000    0.0940    0.886
#
#                           tempo  duration_ms  time_signature
# id
# 000RW47rhEkSqjgTrZx7YX  117.399     164459.0             4.0
# 000xQL6tZNLJzIrtIgxqSl  120.963     188491.0             4.0
# 000xYdQfIZ4pDmBGzQalKU  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ   74.496     236779.0             4.0
# ...                         ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA  132.004     279467.0             4.0
#
# [33881 rows x 24 columns]

# %% [markdown]
# ## Add First 3 Featuring Artists and Extracted Genre List

# %% [markdown]
# Next, we add the top 3 artists and all their associated genres as our best guess for the track's genres. Using artist genre tags was the only feasible approach for getting the genres of a track, as Spotify doesn't provide song-level genre annotations - see `extract_track_artists_and_genres.py` for more information on how the data was created.

# %%
track_artists_and_genres = (
    pd.read_csv(get_data_path("track_artists_and_genres.csv"))
    .rename(
        columns={
            "track_id": "id",
        }
    )
    .set_index("id")
)
track_artists_and_genres
# Out:
#                                    artist_id_1             artist_id_2  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg  0EmeFodog0BfCgMzAIvKQp  1r4hJ1h58CWwUQe3MxPuau
# 7DM4BPaS7uofFul3ywMe46  7slfeZO9LsJbWgpkIoXBUJ  1r4hJ1h58CWwUQe3MxPuau
# 3AEZUABDXNtecAOSC1qTfo  0eecdvMrqBftK0M1VKhaF4                     NaN
# 6rQSrBHf7HlZjtcMZ4S4bO  1vyhD5VmyZ7KMfW5gqLgo5  2RdwBSPQiwcmiDo9kixcl8
# 58IL315gMSTD37DOZPJ2hf  4VMYDCV2IEDYJArk749S6m                     NaN
# ...                                        ...                     ...
# 6ClL99PvuCeBLTFTdnR1Hw  2QoRWNLJ6A9M8f9F0ovGcM  7Bl9s8h4F1jcX1aJYHBpfm
# 7asgcWpGtv92TiMZUYNWVt  6SGCqG5HEr5gFZR9ct8wID  0WnP62TjkFfRrt52yE8zcX
# 1PIiIVeacU0Fj7Rm9lFlsx  7A7wnJp6eGBNV5Foax2kYg  6OviQMT0o5K1fzKYvUNbRS
# 6yf3MxEOScNBTYCHOAIiNQ  4Q6nIcaBED8qUel8bBx6Cr  6S2OmqARrzebs0tKUEyXyp
# 7KA4W4McWYRpgf0fWsJZWB  4V8LLVI7PbaPR0K2TGSxFF  1U1el3k54VvEUzo3ybLPlM
#
#                                    artist_id_3       artist_name_1  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg                     NaN             Shakira
# 7DM4BPaS7uofFul3ywMe46                     NaN        Ricky Martin
# 3AEZUABDXNtecAOSC1qTfo                     NaN                CNCO
# 6rQSrBHf7HlZjtcMZ4S4bO  6veh5zbFpm31XsPdjBgPER            J Balvin
# 58IL315gMSTD37DOZPJ2hf                     NaN        Daddy Yankee
# ...                                        ...                 ...
# 6ClL99PvuCeBLTFTdnR1Hw                     NaN      Sonido Caracol
# 7asgcWpGtv92TiMZUYNWVt                     NaN       Matías Valdez
# 1PIiIVeacU0Fj7Rm9lFlsx                     NaN             Teto Mc
# 6yf3MxEOScNBTYCHOAIiNQ  2ExGrw6XpbtUAJHTLtUXUD           Jax Jones
# 7KA4W4McWYRpgf0fWsJZWB                     NaN  Tyler, The Creator
#
#                             artist_name_2 artist_name_3  \
# id
# 6mICuAdrwEjh6Y6lroV2Kg             Maluma           NaN
# 7DM4BPaS7uofFul3ywMe46             Maluma           NaN
# 3AEZUABDXNtecAOSC1qTfo                NaN           NaN
# 6rQSrBHf7HlZjtcMZ4S4bO  Pharrell Williams           BIA
# 58IL315gMSTD37DOZPJ2hf                NaN           NaN
# ...                                   ...           ...
# 6ClL99PvuCeBLTFTdnR1Hw       Chacho Ramos           NaN
# 7asgcWpGtv92TiMZUYNWVt         Lucas Sugo           NaN
# 1PIiIVeacU0Fj7Rm9lFlsx     Lucas Corleone           NaN
# 6yf3MxEOScNBTYCHOAIiNQ        Demi Lovato  Stefflon Don
# 7KA4W4McWYRpgf0fWsJZWB         Kali Uchis           NaN
#
#                                                                    genres
# id
# 6mICuAdrwEjh6Y6lroV2Kg  ['colombian pop', 'dance pop', 'latin pop', 'r...
# 7DM4BPaS7uofFul3ywMe46  ['dance pop', 'latin pop', 'mexican pop', 'pue...
# 3AEZUABDXNtecAOSC1qTfo             ['boy band', 'latin pop', 'reggaeton']
# 6rQSrBHf7HlZjtcMZ4S4bO  ['reggaeton', 'reggaeton colombiano', 'trap la...
# 58IL315gMSTD37DOZPJ2hf      ['latin hip hop', 'reggaeton', 'trap latino']
# ...                                                                   ...
# 6ClL99PvuCeBLTFTdnR1Hw  ['cumbia pop', 'cumbia uruguaya', 'plena urugu...
# 7asgcWpGtv92TiMZUYNWVt  ['cumbia pop', 'canto popular uruguayo', 'cumb...
# 1PIiIVeacU0Fj7Rm9lFlsx                                   ['rap paraense']
# 6yf3MxEOScNBTYCHOAIiNQ  ['dance pop', 'edm', 'electro house', 'house',...
# 7KA4W4McWYRpgf0fWsJZWB         ['hip hop', 'rap', 'colombian pop', 'pop']
#
# [33881 rows x 7 columns]

# %%
tracks = tracks.join(track_artists_and_genres)

# %% [markdown]
# ## Brief analysis of final dataset

# %%
tracks
# Out:
#                         explicit                                  name  \
# id
# 000RW47rhEkSqjgTrZx7YX     False                      Lance Individual
# 000xQL6tZNLJzIrtIgxqSl     False  Still Got Time (feat. PARTYNEXTDOOR)
# 000xYdQfIZ4pDmBGzQalKU     False                 Eu, Você, O Mar e Ela
# 001b8t3bYPfnabpjpfG1Y4      True                             Geen Stof
# 003VDDA7J3Xb2ZFlNx7nIZ      True                               YELL OH
# ...                          ...                                   ...
# 7zxphfIdUMOfZOAVpKFlld      True           Trapper Of The Year (Intro)
# 7zyYmIdjqqiX6kLryb7QBx     False                                以後別做朋友
# 7zyZ9yPXIQebb79PrMghpV     False                               Zap Zum
# 7zyofXGhXgaqT8fhvLufdf     False                  Kuka Antais Pukille?
# 7zzhknA0A39TH81meuX7WA      True                     C'est pas des LOL
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000xQL6tZNLJzIrtIgxqSl  https://p.scdn.co/mp3-preview/83fad967740b8a85...
# 000xYdQfIZ4pDmBGzQalKU  https://p.scdn.co/mp3-preview/ae0e943883e06623...
# 001b8t3bYPfnabpjpfG1Y4  https://p.scdn.co/mp3-preview/535320aa4cbc5811...
# 003VDDA7J3Xb2ZFlNx7nIZ  https://p.scdn.co/mp3-preview/14e659590d1a70cf...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  https://p.scdn.co/mp3-preview/b48d68019fc66831...
# 7zyYmIdjqqiX6kLryb7QBx  https://p.scdn.co/mp3-preview/4d243321f0ec66ba...
# 7zyZ9yPXIQebb79PrMghpV  https://p.scdn.co/mp3-preview/2f82c76f077fb377...
# 7zyofXGhXgaqT8fhvLufdf  https://p.scdn.co/mp3-preview/236ec096925cdb1f...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                        album_type                album_id album_release_date  \
# id
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000xQL6tZNLJzIrtIgxqSl     single  2kGUeTGnkLOYlinKRJe47G         2017-03-23
# 000xYdQfIZ4pDmBGzQalKU      album  4QianJs5Ls4mxwcT7gDBww         2016-11-04
# 001b8t3bYPfnabpjpfG1Y4      album  06v2EPzWTwcP0egTJVrPdU         2021-01-21
# 003VDDA7J3Xb2ZFlNx7nIZ     single  2orYogfKeURqyS1hRP1vZ4         2020-02-07
# ...                           ...                     ...                ...
# 7zxphfIdUMOfZOAVpKFlld     single  65DP4VYecvLUlUVfCsXPLF         2021-11-19
# 7zyYmIdjqqiX6kLryb7QBx      album  1JEzXcEYuEFKKmo4mfMgC7         2014-12-19
# 7zyZ9yPXIQebb79PrMghpV      album  194szTkDIGJsa9iZJNStwN         2021-06-24
# 7zyofXGhXgaqT8fhvLufdf     single  2QIHDFGxEjYdVg8Y1QYBRv         2018-11-21
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
#
#                        album_release_date_precision          isrc  isrc_year  \
# id
# 000RW47rhEkSqjgTrZx7YX                          day  BRRGE2010642       2020
# 000xQL6tZNLJzIrtIgxqSl                          day  USRC11700675       2017
# 000xYdQfIZ4pDmBGzQalKU                          day  BRRGE1603547       2016
# 001b8t3bYPfnabpjpfG1Y4                          day  NLG662000948       2020
# 003VDDA7J3Xb2ZFlNx7nIZ                          day  QZJ842000061       2020
# ...                                             ...           ...        ...
# 7zxphfIdUMOfZOAVpKFlld                          day  SE6XY2184006       2021
# 7zyYmIdjqqiX6kLryb7QBx                          day  TWA471410001       2014
# 7zyZ9yPXIQebb79PrMghpV                          day  BCM112100037       2021
# 7zyofXGhXgaqT8fhvLufdf                          day  FIUM71800543       2018
# 7zzhknA0A39TH81meuX7WA                          day  FR96X1941264       2019
#
#                               isrc_agency  ...    tempo  duration_ms  \
# id                                         ...
# 000RW47rhEkSqjgTrZx7YX  Pro-música Brazil  ...  117.399     164459.0
# 000xQL6tZNLJzIrtIgxqSl               RIAA  ...  120.963     188491.0
# 000xYdQfIZ4pDmBGzQalKU  Pro-música Brazil  ...  166.018     187119.0
# 001b8t3bYPfnabpjpfG1Y4               SENA  ...   95.951     167866.0
# 003VDDA7J3Xb2ZFlNx7nIZ               RIAA  ...   74.496     236779.0
# ...                                   ...  ...      ...          ...
# 7zxphfIdUMOfZOAVpKFlld        IFPI Sweden  ...  121.913     110164.0
# 7zyYmIdjqqiX6kLryb7QBx                RIT  ...  130.576     260573.0
# 7zyZ9yPXIQebb79PrMghpV  Pro-música Brazil  ...  169.123     167503.0
# 7zyofXGhXgaqT8fhvLufdf       IFPI Finland  ...   89.982     241564.0
# 7zzhknA0A39TH81meuX7WA               SCPP  ...  132.004     279467.0
#
#                         time_signature             artist_id_1  \
# id
# 000RW47rhEkSqjgTrZx7YX             4.0  1elUiq4X7pxej6FRlrEzjM
# 000xQL6tZNLJzIrtIgxqSl             4.0  5ZsFI1h6hIdQRw2ti0hz81
# 000xYdQfIZ4pDmBGzQalKU             4.0  3qvcCP2J0fWi0m0uQDUf6r
# 001b8t3bYPfnabpjpfG1Y4             4.0  1wFoE1RwBMWoWkXcFrCgsx
# 003VDDA7J3Xb2ZFlNx7nIZ             4.0  6Xgp2XMz1fhVYe7i6yNAax
# ...                                ...                     ...
# 7zxphfIdUMOfZOAVpKFlld             4.0  2Dor6diK1zw9BEluKBOdoA
# 7zyYmIdjqqiX6kLryb7QBx             4.0  5fEQLwq1BWWQNR8GzhOIvi
# 7zyZ9yPXIQebb79PrMghpV             4.0  6tzRZ39aZlNqlUzQlkuhDV
# 7zyofXGhXgaqT8fhvLufdf             4.0  3zh3U2eQ64EhBFbJuxgf1M
# 7zzhknA0A39TH81meuX7WA             4.0  3IW7ScrzXmPvZhB27hmfgy
#
#                                    artist_id_2             artist_id_3  \
# id
# 000RW47rhEkSqjgTrZx7YX                     NaN                     NaN
# 000xQL6tZNLJzIrtIgxqSl  2HPaUgqeutzr3jx5a9WyDV                     NaN
# 000xYdQfIZ4pDmBGzQalKU                     NaN                     NaN
# 001b8t3bYPfnabpjpfG1Y4                     NaN                     NaN
# 003VDDA7J3Xb2ZFlNx7nIZ  50co4Is1HCEo8bhOyUWKpn                     NaN
# ...                                        ...                     ...
# 7zxphfIdUMOfZOAVpKFlld                     NaN                     NaN
# 7zyYmIdjqqiX6kLryb7QBx                     NaN                     NaN
# 7zyZ9yPXIQebb79PrMghpV                     NaN                     NaN
# 7zyofXGhXgaqT8fhvLufdf  05qPtpcSltJZLI9sj0qm3B  4l0zTor5S32Yly4uw96Bto
# 7zzhknA0A39TH81meuX7WA                     NaN                     NaN
#
#                           artist_name_1  artist_name_2  artist_name_3  \
# id
# 000RW47rhEkSqjgTrZx7YX   Jorge & Mateus            NaN            NaN
# 000xQL6tZNLJzIrtIgxqSl             ZAYN  PARTYNEXTDOOR            NaN
# 000xYdQfIZ4pDmBGzQalKU     Luan Santana            NaN            NaN
# 001b8t3bYPfnabpjpfG1Y4         Josylvio            NaN            NaN
# 003VDDA7J3Xb2ZFlNx7nIZ     Trippie Redd     Young Thug            NaN
# ...                                 ...            ...            ...
# 7zxphfIdUMOfZOAVpKFlld               23            NaN            NaN
# 7zyYmIdjqqiX6kLryb7QBx        Eric Chou            NaN            NaN
# 7zyZ9yPXIQebb79PrMghpV    Pabllo Vittar            NaN            NaN
# 7zyofXGhXgaqT8fhvLufdf  Teflon Brothers         Spekti   Petri Nygård
# 7zzhknA0A39TH81meuX7WA              Jul            NaN            NaN
#
#                                                                    genres
# id
# 000RW47rhEkSqjgTrZx7YX  ['arrocha', 'sertanejo', 'sertanejo universita...
# 000xQL6tZNLJzIrtIgxqSl  ['dance pop', 'pop', 'post-teen pop', 'uk pop'...
# 000xYdQfIZ4pDmBGzQalKU  ['arrocha', 'sertanejo', 'sertanejo pop', 'ser...
# 001b8t3bYPfnabpjpfG1Y4                                  ['dutch hip hop']
# 003VDDA7J3Xb2ZFlNx7nIZ  ['melodic rap', 'rap', 'trap', 'atl hip hop', ...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  ['swedish drill', 'swedish hip hop', 'swedish ...
# 7zyYmIdjqqiX6kLryb7QBx                                       ['mandopop']
# 7zyZ9yPXIQebb79PrMghpV  ['dance pop', 'funk carioca', 'funk pop', 'pop...
# 7zyofXGhXgaqT8fhvLufdf  ['eurovision', 'finnish dance pop', 'finnish h...
# 7zzhknA0A39TH81meuX7WA                     ['francoton', 'rap marseille']
#
# [33881 rows x 31 columns]

# %%
tracks.shape
# Out:
# (33881, 31)

# %%
tracks.columns
# Out:
# Index(['explicit', 'name', 'preview_url', 'album_type', 'album_id',
#        'album_release_date', 'album_release_date_precision', 'isrc',
#        'isrc_year', 'isrc_agency', 'isrc_territory', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'artist_id_1', 'artist_id_2', 'artist_id_3',
#        'artist_name_1', 'artist_name_2', 'artist_name_3', 'genres'],
#       dtype='object')

# %%
type_counts = tracks.dtypes.value_counts()
type_counts
# Out:
# object     15
# float64    13
# bool        1
# string      1
# Int64       1
# dtype: int64

# %%
for dtype in type_counts.index:
  print(dtype, tracks.dtypes.index[tracks.dtypes == dtype].tolist())
  print()
# Out:
# object ['name', 'preview_url', 'album_type', 'album_id', 'album_release_date', 'album_release_date_precision', 'isrc_agency', 'isrc_territory', 'artist_id_1', 'artist_id_2', 'artist_id_3', 'artist_name_1', 'artist_name_2', 'artist_name_3', 'genres']
#
# float64 ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
#
# bool ['explicit']
#
# string ['isrc']
#
# Int64 ['isrc_year']

# %%
tracks.count().sort_values()
# Out:
# artist_id_3                      3828
# artist_name_3                    3828
# artist_name_2                   13515
# artist_id_2                     13515
# preview_url                     25713
# artist_name_1                   33856
# isrc_year                       33857
# isrc                            33857
# isrc_agency                     33857
# isrc_territory                  33857
# name                            33858
# instrumentalness                33876
# liveness                        33876
# mode                            33876
# tempo                           33876
# valence                         33876
# acousticness                    33876
# danceability                    33876
# loudness                        33876
# key                             33876
# energy                          33876
# duration_ms                     33876
# speechiness                     33876
# time_signature                  33876
# explicit                        33881
# album_release_date_precision    33881
# album_release_date              33881
# album_id                        33881
# album_type                      33881
# artist_id_1                     33881
# genres                          33881
# dtype: int64

# %% [markdown]
# Interesting, there are some songs without a name (luckily only around 20). Also, for 5 songs no audio features seem to be available. Overall, the completeness of the track metadata is pretty satifsying :)

# %% [markdown]
# ## Export data

# %%
tracks.to_csv(create_data_out_path("top50_track_data.csv"))
# Out:
# Data output path: /home/sejmou/Repos/Uni/VisDS/vis-ds/data/top50_track_data.csv
