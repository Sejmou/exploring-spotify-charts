# %% [markdown]
# # Obtaining a dataset for region classification of Spotify Chart tracks

# %% [markdown]
# In this notebook, I create a dataset that could be used for training and evaluating a classifier that identifies what features are typical for a track charting in a particular region. The endresult is a dataframe with equal numbers of examples for Europe, Asia, Northern America and Latin America. Note that every track in this dataset only charted in a single region, so this is **not** a multi-label classification task.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from helpers import get_countries_charts
from helpers.model import get_basic_track_features

# %%
countries_charts = get_countries_charts()
countries_charts
# Out:
#            country       date  rank   streams                      id  \
# 0        Argentina 2017-01-01     1  253019.0  6mICuAdrwEjh6Y6lroV2Kg
# 1        Argentina 2017-01-01     2  223988.0  7DM4BPaS7uofFul3ywMe46
# 2        Argentina 2017-01-01     3  210943.0  3AEZUABDXNtecAOSC1qTfo
# 3        Argentina 2017-01-01     4  173865.0  6rQSrBHf7HlZjtcMZ4S4bO
# 4        Argentina 2017-01-01     5  153956.0  58IL315gMSTD37DOZPJ2hf
# ...            ...        ...   ...       ...                     ...
# 4472525    Uruguay 2021-08-13    25   11431.0  4aXicRG47bBEcKXlDaSRwW
# 4472526    Uruguay 2021-08-13    27   10946.0  43qcs9NpJhDxtG91zxFkj7
# 4472527    Uruguay 2021-08-13    33    9994.0  4M4DTyLupKvbJKlE4I4EYq
# 4472528    Uruguay 2021-08-13    35    9251.0  5jzEwSyyymBlf1fa1o39T2
# 4472529    Uruguay 2021-08-13    36    9179.0  5PjdY0CKGZdEuoNab3yDmX
#
#         iso_alpha3 iso_alpha2 geo_region                    geo_subregion
# 0              ARG         AR   Americas  Latin America and the Caribbean
# 1              ARG         AR   Americas  Latin America and the Caribbean
# 2              ARG         AR   Americas  Latin America and the Caribbean
# 3              ARG         AR   Americas  Latin America and the Caribbean
# 4              ARG         AR   Americas  Latin America and the Caribbean
# ...            ...        ...        ...                              ...
# 4472525        URY         UY   Americas  Latin America and the Caribbean
# 4472526        URY         UY   Americas  Latin America and the Caribbean
# 4472527        URY         UY   Americas  Latin America and the Caribbean
# 4472528        URY         UY   Americas  Latin America and the Caribbean
# 4472529        URY         UY   Americas  Latin America and the Caribbean
#
# [4472530 rows x 9 columns]

# %%
charting_tracks_by_region = (
    countries_charts.drop_duplicates(subset=["id", "geo_region"])[
        ["id", "geo_region"]
    ]
    .rename(columns={"geo_region": "region"})
)
charting_tracks_by_region
# Out:
#                              id    region
# 0        6mICuAdrwEjh6Y6lroV2Kg  Americas
# 1        7DM4BPaS7uofFul3ywMe46  Americas
# 2        3AEZUABDXNtecAOSC1qTfo  Americas
# 3        6rQSrBHf7HlZjtcMZ4S4bO  Americas
# 4        58IL315gMSTD37DOZPJ2hf  Americas
# ...                         ...       ...
# 4470104  4yMWMZEesltigOANqYkaWo  Americas
# 4470307  7exaYYNN99DHkbZuHOZWO3  Americas
# 4471250  39yyHtQ4tkjZzd8TfIBKQw  Americas
# 4472041  6ClL99PvuCeBLTFTdnR1Hw  Americas
# 4472042  7asgcWpGtv92TiMZUYNWVt  Americas
#
# [40589 rows x 2 columns]

# %%
def plot_overlap_with_other_regions(tracks_by_region):
    df = tracks_by_region.copy()
    df["is_charting"] = True
    df = df.pivot(
        index="id", columns="region", values="is_charting"
    )
    df = df.fillna(False)

    fig, axs = plt.subplots(1, len(tracks_by_region.region.unique()), figsize=(12, 3), sharey=True)
    axs = axs.ravel()

    for i, region in enumerate(df.columns):
        ax = axs[i]
        ax.set_title(region)
        tracks_charting_in_region = df.loc[df[region] == True]
        no_tracks_charting_in_other_regions_too = tracks_charting_in_region.loc[:, df.columns != region].sum()
        perc_tracks_charting_in_other_regions = no_tracks_charting_in_other_regions_too / tracks_charting_in_region.shape[0]
        #perc_tracks_charting_in_other_regions.index = perc_tracks_charting_in_other_regions.index.remove_unused_categories()
        perc_tracks_charting_in_other_regions.plot.bar(ax=ax)


plot_overlap_with_other_regions(charting_tracks_by_region)

# %%
tracks_charting_only_in_one_region = charting_tracks_by_region[~charting_tracks_by_region.duplicated(keep=False, subset=["id"])].reset_index(drop=True)
tracks_charting_only_in_one_region
# Out:
#                            id    region
# 0      1MpKZi1zTXpERKwxmOu1PH  Americas
# 1      1pWYnQIlqxTh5bxuPmTG4E  Americas
# 2      7IRuf7FrdQvOGs0g9mSNGr  Americas
# 3      3gEebOzxHpEwElicl1XBy0  Americas
# 4      0tGAPnTFwRJA6FZgYZ0BAe  Americas
# ...                       ...       ...
# 30099  4PDoCa5P0QK7KFhTsEKJB8  Americas
# 30100  4yMWMZEesltigOANqYkaWo  Americas
# 30101  7exaYYNN99DHkbZuHOZWO3  Americas
# 30102  6ClL99PvuCeBLTFTdnR1Hw  Americas
# 30103  7asgcWpGtv92TiMZUYNWVt  Americas
#
# [30104 rows x 2 columns]

# %% [markdown]
# ## Combining track IDs per (sub-)region with features

# %%
track_feats = get_basic_track_features()
track_feats
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xQL6tZNLJzIrtIgxqSl       0.0639       0.13100          0.000000    0.0852
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release
# id
# 000RW47rhEkSqjgTrZx7YX           False
# 000xQL6tZNLJzIrtIgxqSl            True
# 000xYdQfIZ4pDmBGzQalKU           False
# 001b8t3bYPfnabpjpfG1Y4           False
# 003VDDA7J3Xb2ZFlNx7nIZ            True
# ...                                ...
# 7zxphfIdUMOfZOAVpKFlld            True
# 7zyYmIdjqqiX6kLryb7QBx           False
# 7zyZ9yPXIQebb79PrMghpV           False
# 7zyofXGhXgaqT8fhvLufdf            True
# 7zzhknA0A39TH81meuX7WA           False
#
# [33876 rows x 15 columns]

# %% [markdown]
# ### Regions

# %%
region_tracks_features = pd.merge(track_feats, tracks_charting_only_in_one_region, on="id").set_index("id")
region_tracks_features
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyYmIdjqqiX6kLryb7QBx           False      Asia
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
# [30099 rows x 16 columns]

# %%
sns.countplot(data=region_tracks_features, x="region")
# Out:
# <AxesSubplot: xlabel='region', ylabel='count'>

# %% [markdown]
# #### Removing region with too little training examples

# %% [markdown]
# We have too little examples from Oceania to train a classifier in a meaningful way. So, better remove that category entirely.

# %%
region_tracks_features
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyYmIdjqqiX6kLryb7QBx           False      Asia
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
# [30099 rows x 16 columns]

# %%
region_track_feats_dataset = region_tracks_features.copy().loc[region_tracks_features.region != "Oceania"]
region_track_feats_dataset.region = region_track_feats_dataset.region.cat.remove_unused_categories()
region_track_feats_dataset
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyYmIdjqqiX6kLryb7QBx           False      Asia
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
# [29794 rows x 16 columns]

# %%
sns.countplot(data=region_track_feats_dataset, x="region")
# Out:
# <AxesSubplot: xlabel='region', ylabel='count'>

# %%
charting_tracks_by_region.groupby('id').size().value_counts()
# Out:
# 1    30104
# 2     1947
# 4     1104
# 3      725
# dtype: int64

# %%
region_track_feats_dataset.groupby(["id"]).size().value_counts()
# Out:
# 1    29794
# dtype: int64

# %%
region_track_feats_dataset
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyYmIdjqqiX6kLryb7QBx           False      Asia
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
# [29794 rows x 16 columns]

# %%
from helpers.model import get_track_feature_region_dataset

all(region_track_feats_dataset == get_track_feature_region_dataset())
# Out:
# True

# %%
region_track_feats_dataset
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyYmIdjqqiX6kLryb7QBx           False      Asia
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
# [29794 rows x 16 columns]

# %% [markdown]
# #### Looking for differences in feature distribution by region

# %%
from sklearn.preprocessing import MinMaxScaler

track_feat_cols = track_feats.columns
def min_max_scale_track_features(track_feature_dataset):
    df = track_feature_dataset.copy()
    scaler = MinMaxScaler()
    df[track_feat_cols] = scaler.fit_transform(df[track_feat_cols])
    return df

# %%
region_track_feats_minmax_scaled = min_max_scale_track_features(region_track_feats_dataset)

# %%
data = pd.melt(region_track_feats_minmax_scaled,
                   id_vars="region",
                   var_name="features",
                   value_name='value')

plt.figure(figsize=(16, 4))
sns.violinplot(x="features", y="value", data=data,
                   hue="region",# compare distributions of values for feature by class (different colors for each of the two classes)
                   #split=True,# split violins (left half distribution of false class, right shows distribution of true)
                   inner="quartile"# show quartiles as lines instead of putting boxplot inside
                   )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Analyzing data by subregion

# %%
charting_tracks_by_subregion = (
    countries_charts.drop_duplicates(subset=["id", "geo_subregion"])[
        ["id", "geo_region", "geo_subregion"]
    ]
    .rename(columns={"geo_region": "region", "geo_subregion": "subregion"})
)
charting_tracks_by_subregion
# Out:
#                              id    region                        subregion
# 0        6mICuAdrwEjh6Y6lroV2Kg  Americas  Latin America and the Caribbean
# 1        7DM4BPaS7uofFul3ywMe46  Americas  Latin America and the Caribbean
# 2        3AEZUABDXNtecAOSC1qTfo  Americas  Latin America and the Caribbean
# 3        6rQSrBHf7HlZjtcMZ4S4bO  Americas  Latin America and the Caribbean
# 4        58IL315gMSTD37DOZPJ2hf  Americas  Latin America and the Caribbean
# ...                         ...       ...                              ...
# 4470104  4yMWMZEesltigOANqYkaWo  Americas  Latin America and the Caribbean
# 4470307  7exaYYNN99DHkbZuHOZWO3  Americas  Latin America and the Caribbean
# 4471250  39yyHtQ4tkjZzd8TfIBKQw  Americas  Latin America and the Caribbean
# 4472041  6ClL99PvuCeBLTFTdnR1Hw  Americas  Latin America and the Caribbean
# 4472042  7asgcWpGtv92TiMZUYNWVt  Americas  Latin America and the Caribbean
#
# [48575 rows x 3 columns]

# %%
def plot_overlap_with_other_subregions(tracks_by_subregion):
    df = tracks_by_subregion.copy()
    df["is_charting"] = True
    df = df.pivot(index="id", columns="subregion", values="is_charting")
    df = df.fillna(False)
    display(df)

    subregion_count = len(tracks_by_subregion.subregion.unique())
    fig, axs = plt.subplots(
        subregion_count, 1, figsize=(20, subregion_count * 6), sharey=True
    )
    axs = axs.ravel()
    subregion_to_region = tracks_by_subregion.set_index("subregion")["region"].to_dict()
    color_palette = sns.color_palette("colorblind")
    region_to_color = {
        region: color
        for region, color in zip(subregion_to_region.values(), color_palette)
    }

    def get_color_for_subregion(subregion):
        region = subregion_to_region[subregion]
        return region_to_color[region]

    for i, subregion in enumerate(df.columns):
        ax = axs[i]
        ax.set_title(subregion)
        tracks_charting_in_subregion = df.loc[df[subregion] == True]
        no_tracks_charting_in_other_subregions_too = (
            tracks_charting_in_subregion.loc[:, df.columns != subregion]
            .sum()
            .sort_values(ascending=False)
        )
        perc_tracks_charting_in_other_subregions = (
            no_tracks_charting_in_other_subregions_too
            / tracks_charting_in_subregion.shape[0]
        )
        perc_tracks_charting_in_other_subregions.plot.bar(
            ax=ax,
            color=[
                get_color_for_subregion(subregion)
                for subregion in perc_tracks_charting_in_other_subregions.index
            ],
        )
        number_of_other_charting_countries_per_track = tracks_charting_in_subregion.loc[
            :, df.columns != subregion
        ].sum(axis=1)
        perc_tracks_charting_only_in_subregion = (
            number_of_other_charting_countries_per_track.loc[
                number_of_other_charting_countries_per_track == 0
            ].shape[0]
            / tracks_charting_in_subregion.shape[0]
        )
        ax.axhline(
            perc_tracks_charting_only_in_subregion,
            color=get_color_for_subregion(subregion),
            linestyle="--",
        )
        ax.tick_params(axis="x", rotation=10)

    plt.tight_layout()


plot_overlap_with_other_subregions(charting_tracks_by_subregion)
# Out:
# subregion               Australia and New Zealand  Eastern Asia  \
# id
# 000RW47rhEkSqjgTrZx7YX                      False         False
# 000xQL6tZNLJzIrtIgxqSl                       True          True
# 000xYdQfIZ4pDmBGzQalKU                      False         False
# 001b8t3bYPfnabpjpfG1Y4                      False         False
# 003VDDA7J3Xb2ZFlNx7nIZ                      False         False
# ...                                           ...           ...
# 7zxphfIdUMOfZOAVpKFlld                      False         False
# 7zyYmIdjqqiX6kLryb7QBx                      False          True
# 7zyZ9yPXIQebb79PrMghpV                      False         False
# 7zyofXGhXgaqT8fhvLufdf                      False         False
# 7zzhknA0A39TH81meuX7WA                      False         False
#
# subregion               Eastern Europe  Latin America and the Caribbean  \
# id
# 000RW47rhEkSqjgTrZx7YX           False                             True
# 000xQL6tZNLJzIrtIgxqSl            True                            False
# 000xYdQfIZ4pDmBGzQalKU           False                             True
# 001b8t3bYPfnabpjpfG1Y4           False                            False
# 003VDDA7J3Xb2ZFlNx7nIZ           False                            False
# ...                                ...                              ...
# 7zxphfIdUMOfZOAVpKFlld           False                            False
# 7zyYmIdjqqiX6kLryb7QBx           False                            False
# 7zyZ9yPXIQebb79PrMghpV           False                             True
# 7zyofXGhXgaqT8fhvLufdf           False                            False
# 7zzhknA0A39TH81meuX7WA           False                            False
#
# subregion               Northern America  Northern Europe  South-eastern Asia  \
# id
# 000RW47rhEkSqjgTrZx7YX             False            False               False
# 000xQL6tZNLJzIrtIgxqSl              True             True                True
# 000xYdQfIZ4pDmBGzQalKU             False            False               False
# 001b8t3bYPfnabpjpfG1Y4             False            False               False
# 003VDDA7J3Xb2ZFlNx7nIZ              True            False               False
# ...                                  ...              ...                 ...
# 7zxphfIdUMOfZOAVpKFlld             False             True               False
# 7zyYmIdjqqiX6kLryb7QBx             False            False                True
# 7zyZ9yPXIQebb79PrMghpV             False            False               False
# 7zyofXGhXgaqT8fhvLufdf             False             True               False
# 7zzhknA0A39TH81meuX7WA             False            False               False
#
# subregion               Southern Europe  Western Asia  Western Europe
# id
# 000RW47rhEkSqjgTrZx7YX            False         False           False
# 000xQL6tZNLJzIrtIgxqSl             True         False            True
# 000xYdQfIZ4pDmBGzQalKU            False         False           False
# 001b8t3bYPfnabpjpfG1Y4            False         False            True
# 003VDDA7J3Xb2ZFlNx7nIZ            False         False           False
# ...                                 ...           ...             ...
# 7zxphfIdUMOfZOAVpKFlld            False         False           False
# 7zyYmIdjqqiX6kLryb7QBx            False         False           False
# 7zyZ9yPXIQebb79PrMghpV            False         False           False
# 7zyofXGhXgaqT8fhvLufdf            False         False           False
# 7zzhknA0A39TH81meuX7WA            False         False            True
#
# [33880 rows x 10 columns]

# %%
charting_tracks_by_subregion.groupby('id').size().value_counts()
# Out:
# 1     29389
# 2      1792
# 3       625
# 4       450
# 8       345
# 5       327
# 6       287
# 10      241
# 9       216
# 7       208
# dtype: int64

# %%
tracks_charting_only_in_one_subregion = charting_tracks_by_subregion[~charting_tracks_by_subregion.duplicated(keep=False, subset="id")].reset_index(drop=True)
tracks_charting_only_in_one_subregion
# Out:
#                            id    region                        subregion
# 0      1MpKZi1zTXpERKwxmOu1PH  Americas  Latin America and the Caribbean
# 1      1pWYnQIlqxTh5bxuPmTG4E  Americas  Latin America and the Caribbean
# 2      7IRuf7FrdQvOGs0g9mSNGr  Americas  Latin America and the Caribbean
# 3      3gEebOzxHpEwElicl1XBy0  Americas  Latin America and the Caribbean
# 4      0tGAPnTFwRJA6FZgYZ0BAe  Americas  Latin America and the Caribbean
# ...                       ...       ...                              ...
# 29384  4PDoCa5P0QK7KFhTsEKJB8  Americas  Latin America and the Caribbean
# 29385  4yMWMZEesltigOANqYkaWo  Americas  Latin America and the Caribbean
# 29386  7exaYYNN99DHkbZuHOZWO3  Americas  Latin America and the Caribbean
# 29387  6ClL99PvuCeBLTFTdnR1Hw  Americas  Latin America and the Caribbean
# 29388  7asgcWpGtv92TiMZUYNWVt  Americas  Latin America and the Caribbean
#
# [29389 rows x 3 columns]

# %%
# verify that we calculated makes sense
tracks_charting_only_in_one_subregion.groupby("id").subregion.count().value_counts()
# Out:
# 1    29389
# Name: subregion, dtype: int64

# %%
subregion_tracks_features = pd.merge(
        track_feats, tracks_charting_only_in_one_subregion, on="id"
    ).set_index("id")

# %%
subregion_tracks_features
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 004zGvrc84enQHFitC6auy      True         0.730   0.696  2.0    -7.173   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxRMhXxJMQCeDDg0rKAVo      True         0.744   0.715  0.0    -6.103   1.0
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 004zGvrc84enQHFitC6auy       0.3550       0.17500          0.000020    0.3210
# ...                             ...           ...               ...       ...
# 7zxRMhXxJMQCeDDg0rKAVo       0.3510       0.10100          0.000000    0.0919
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 004zGvrc84enQHFitC6auy    0.584  172.040     184186.0             4.0
# ...                         ...      ...          ...             ...
# 7zxRMhXxJMQCeDDg0rKAVo    0.340  154.962     179773.0             4.0
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region  \
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 004zGvrc84enQHFitC6auy           False    Europe
# ...                                ...       ...
# 7zxRMhXxJMQCeDDg0rKAVo           False  Americas
# 7zxphfIdUMOfZOAVpKFlld            True    Europe
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zyofXGhXgaqT8fhvLufdf            True    Europe
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
#                                               subregion
# id
# 000RW47rhEkSqjgTrZx7YX  Latin America and the Caribbean
# 000xYdQfIZ4pDmBGzQalKU  Latin America and the Caribbean
# 001b8t3bYPfnabpjpfG1Y4                   Western Europe
# 003VDDA7J3Xb2ZFlNx7nIZ                 Northern America
# 004zGvrc84enQHFitC6auy                  Southern Europe
# ...                                                 ...
# 7zxRMhXxJMQCeDDg0rKAVo                 Northern America
# 7zxphfIdUMOfZOAVpKFlld                  Northern Europe
# 7zyZ9yPXIQebb79PrMghpV  Latin America and the Caribbean
# 7zyofXGhXgaqT8fhvLufdf                  Northern Europe
# 7zzhknA0A39TH81meuX7WA                   Western Europe
#
# [29385 rows x 17 columns]

# %%
sns.countplot(subregion_tracks_features, x="subregion")
plt.xticks(rotation=90)
plt.show()

# %%
subregion_track_feats_minmax_scaled = min_max_scale_track_features(subregion_tracks_features)

# %%
def plot_subregion_data(
    subregion_data, features_per_figure=4, features=track_feat_cols, subregions=None, title=None
):
    subregion_data = subregion_data.copy()
    if subregions is not None:
        subregion_data = subregion_data.loc[subregion_data.subregion.isin(subregions)]
        subregion_data.subregion = (
            subregion_data.subregion.cat.remove_unused_categories()
        )
        subregion_data.region = (
            subregion_data.region.cat.remove_unused_categories()
        )
    
    min_max_scaled = min_max_scale_track_features(subregion_data)
    data = pd.melt(
        min_max_scaled.drop(columns="region"),
        id_vars="subregion",
        var_name="features",
        value_name="value",
    )
    i = 0
    while i < len(features):
        plt.figure(figsize=(16, 4))
        sns.violinplot(
            x="features",
            y="value",
            data=data.loc[
                data.features.isin(features[i : i + features_per_figure])
            ],
            hue="subregion",  # compare distributions of values for feature by class (different colors for each of the two classes)
            # split=True,# split violins (left half distribution of false class, right shows distribution of true)
        )
        plt.xticks(rotation=90)
        i += features_per_figure
    if title is not None:
        plt.title(title)
    plt.show()

# %%
plot_subregion_data(subregion_tracks_features)

# %%
plot_subregion_data(
    subregion_tracks_features,
    subregions=[
        "Northern America",
        "Latin America and the Caribbean",
        "Western Europe",
        "Eastern Asia",
    ],
)

# %%
plot_subregion_data(
    subregion_tracks_features,
    subregions=[
        "Northern America",
        "Latin America and the Caribbean",
        "Western Europe",
        "Eastern Asia",
    ],
    features=["valence", "tempo", "danceability", "energy"],
    title="Distribution of features of tracks charting only in one subregion"
)

# %%
subregion_selection = subregion_tracks_features.copy().loc[
    subregion_tracks_features.subregion.isin(
        [
            "Northern America",
            "Latin America and the Caribbean",
            "Western Europe",
            "Eastern Asia",
        ]
    )
]
subregion_selection.subregion = subregion_selection.subregion.cat.remove_unused_categories()
subregion_selection.region = subregion_selection.region.cat.remove_unused_categories()

# %%
subregion_selection
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# 006Q8ORZ9zPjf3IiO5evwX      True         0.820   0.518  9.0   -10.497   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7ztdl6cnbJgHRdMkKldkts     False         0.641   0.618  0.0    -4.269   1.0
# 7zvGNZu33bC4jZEkXHdDZ6     False         0.661   0.834  8.0    -4.426   1.0
# 7zxRMhXxJMQCeDDg0rKAVo      True         0.744   0.715  0.0    -6.103   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# 006Q8ORZ9zPjf3IiO5evwX       0.3380       0.32100          0.000000    0.0891
# ...                             ...           ...               ...       ...
# 7ztdl6cnbJgHRdMkKldkts       0.0259       0.09320          0.000000    0.1550
# 7zvGNZu33bC4jZEkXHdDZ6       0.0772       0.11800          0.000000    0.2730
# 7zxRMhXxJMQCeDDg0rKAVo       0.3510       0.10100          0.000000    0.0919
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# 006Q8ORZ9zPjf3IiO5evwX    0.746   75.987     146842.0             4.0
# ...                         ...      ...          ...             ...
# 7ztdl6cnbJgHRdMkKldkts    0.338   90.032     271160.0             4.0
# 7zvGNZu33bC4jZEkXHdDZ6    0.652  169.952     153423.0             4.0
# 7zxRMhXxJMQCeDDg0rKAVo    0.340  154.962     179773.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release    region  \
# id
# 000RW47rhEkSqjgTrZx7YX           False  Americas
# 000xYdQfIZ4pDmBGzQalKU           False  Americas
# 001b8t3bYPfnabpjpfG1Y4           False    Europe
# 003VDDA7J3Xb2ZFlNx7nIZ            True  Americas
# 006Q8ORZ9zPjf3IiO5evwX           False    Europe
# ...                                ...       ...
# 7ztdl6cnbJgHRdMkKldkts           False      Asia
# 7zvGNZu33bC4jZEkXHdDZ6           False  Americas
# 7zxRMhXxJMQCeDDg0rKAVo           False  Americas
# 7zyZ9yPXIQebb79PrMghpV           False  Americas
# 7zzhknA0A39TH81meuX7WA           False    Europe
#
#                                               subregion
# id
# 000RW47rhEkSqjgTrZx7YX  Latin America and the Caribbean
# 000xYdQfIZ4pDmBGzQalKU  Latin America and the Caribbean
# 001b8t3bYPfnabpjpfG1Y4                   Western Europe
# 003VDDA7J3Xb2ZFlNx7nIZ                 Northern America
# 006Q8ORZ9zPjf3IiO5evwX                   Western Europe
# ...                                                 ...
# 7ztdl6cnbJgHRdMkKldkts                     Eastern Asia
# 7zvGNZu33bC4jZEkXHdDZ6  Latin America and the Caribbean
# 7zxRMhXxJMQCeDDg0rKAVo                 Northern America
# 7zyZ9yPXIQebb79PrMghpV  Latin America and the Caribbean
# 7zzhknA0A39TH81meuX7WA                   Western Europe
#
# [13022 rows x 17 columns]

# %%
from helpers.model import get_track_feature_subregion_dataset

all(subregion_selection == get_track_feature_subregion_dataset())
# Out:
# True

# %%
sns.scatterplot(data=subregion_selection, x="danceability", y="energy", hue="subregion", alpha=0.1)
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='energy'>

# %%
sns.scatterplot(data=subregion_selection, x="danceability", y="valence", hue="subregion", alpha=0.1)
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='valence'>

# %%
subregion_selection.subregion.value_counts()
# Out:
# Western Europe                     6663
# Latin America and the Caribbean    3207
# Eastern Asia                       1947
# Northern America                   1205
# Name: subregion, dtype: int64

# %% [markdown]
# ## Data by country

# %%
charting_tracks_by_country = (
    countries_charts.drop_duplicates(subset=["id", "country"])[
        ["id", "country", "geo_region", "geo_subregion"]
    ]
    .rename(columns={"geo_region": "region", "geo_subregion": "subregion"})
)
charting_tracks_by_country
# Out:
#                              id    country    region  \
# 0        6mICuAdrwEjh6Y6lroV2Kg  Argentina  Americas
# 1        7DM4BPaS7uofFul3ywMe46  Argentina  Americas
# 2        3AEZUABDXNtecAOSC1qTfo  Argentina  Americas
# 3        6rQSrBHf7HlZjtcMZ4S4bO  Argentina  Americas
# 4        58IL315gMSTD37DOZPJ2hf  Argentina  Americas
# ...                         ...        ...       ...
# 4472058  1sZ39ZxvFo8FyMz4s7iVlf    Uruguay  Americas
# 4472108  7hiAGGyiLaLBTVroaE08hx    Uruguay  Americas
# 4472157  5W1qmxHrMlQGGAiFA3ZQqP    Uruguay  Americas
# 4472208  7rglLriMNBPAyuJOMGwi39    Uruguay  Americas
# 4472259  2Gq636OOGgxCTqEuzCZhsa    Uruguay  Americas
#
#                                subregion
# 0        Latin America and the Caribbean
# 1        Latin America and the Caribbean
# 2        Latin America and the Caribbean
# 3        Latin America and the Caribbean
# 4        Latin America and the Caribbean
# ...                                  ...
# 4472058  Latin America and the Caribbean
# 4472108  Latin America and the Caribbean
# 4472157  Latin America and the Caribbean
# 4472208  Latin America and the Caribbean
# 4472259  Latin America and the Caribbean
#
# [93004 rows x 4 columns]

# %%
charting_tracks_by_country.groupby('country').size().sort_values(ascending = False)
# Out:
# country
# Switzerland           3414
# United States         3394
# France                3391
# Germany               3181
# Finland               2968
# Austria               2823
# Slovakia              2820
# Canada                2805
# Italy                 2781
# Sweden                2718
# Iceland               2669
# Netherlands           2549
# Greece                2493
# Denmark               2475
# United Kingdom        2460
# Poland                2404
# Czech Republic        2377
# Belgium               2187
# Norway                2121
# Taiwan                2098
# Hong Kong             2093
# Ireland               2068
# Hungary               1920
# Australia             1791
# New Zealand           1742
# Malaysia              1722
# Singapore             1688
# Portugal              1646
# Turkey                1537
# Dominican Republic    1432
# Spain                 1361
# Brazil                1341
# Panama                1305
# Philippines           1292
# Indonesia             1193
# Mexico                1170
# Costa Rica            1153
# El Salvador           1111
# Chile                 1102
# Colombia              1091
# Argentina             1076
# Honduras              1076
# Uruguay               1075
# Guatemala             1068
# Bolivia               1019
# Japan                 1005
# Ecuador               1004
# Peru                   927
# Paraguay               868
# dtype: int64

# %%
countries_charts.groupby("geo_region").streams.sum().sort_values(ascending = False)
# Out:
# geo_region
# Americas    1.641368e+11
# Europe      1.256232e+11
# Asia        3.667009e+10
# Oceania     1.227340e+10
# Name: streams, dtype: float64

# %%
streams_per_country = countries_charts.groupby("country").streams.sum().sort_values(ascending = False)
streams_per_country
# Out:
# country
# United States         6.664872e+10
# Brazil                2.776871e+10
# Mexico                2.287400e+10
# Germany               2.077738e+10
# United Kingdom        1.897820e+10
# Spain                 1.547413e+10
# Italy                 1.358924e+10
# France                1.168422e+10
# Argentina             1.104077e+10
# Australia             1.019892e+10
# Netherlands           1.018208e+10
# Philippines           1.010755e+10
# Chile                 9.869191e+09
# Canada                9.327649e+09
# Indonesia             8.255808e+09
# Sweden                8.015910e+09
# Turkey                6.406908e+09
# Japan                 5.507563e+09
# Norway                4.880355e+09
# Peru                  4.527544e+09
# Poland                4.300430e+09
# Denmark               3.565919e+09
# Colombia              3.407812e+09
# Finland               2.654623e+09
# Ireland               2.209751e+09
# New Zealand           2.074481e+09
# Malaysia              2.043456e+09
# Belgium               2.013845e+09
# Singapore             1.965480e+09
# Switzerland           1.660520e+09
# Taiwan                1.598159e+09
# Ecuador               1.461315e+09
# Portugal              1.454081e+09
# Paraguay              1.344949e+09
# Austria               1.326314e+09
# Costa Rica            1.130278e+09
# Guatemala             1.066732e+09
# Czech Republic        8.462289e+08
# Hong Kong             7.851639e+08
# Uruguay               7.603492e+08
# Greece                6.983228e+08
# Hungary               6.709781e+08
# Bolivia               6.513140e+08
# Dominican Republic    6.509236e+08
# Panama                6.319854e+08
# El Salvador           5.268831e+08
# Honduras              4.477088e+08
# Slovakia              3.489526e+08
# Iceland               2.916828e+08
# Name: streams, dtype: float64

# %%
from helpers import get_country_data
country_data = get_country_data().rename(columns={"geo_subregion": "subregion", "geo_region": "region"})
country_data.index.name = "country"

# %%
countries_with_subregion_and_streams = country_data[["subregion"]].join(streams_per_country)
countries_with_subregion_and_streams
# Out:
#                                           subregion       streams
# country
# Argentina           Latin America and the Caribbean  1.104077e+10
# Australia                 Australia and New Zealand  1.019892e+10
# Austria                              Western Europe  1.326314e+09
# Belgium                              Western Europe  2.013845e+09
# Brazil              Latin America and the Caribbean  2.776871e+10
# Canada                             Northern America  9.327649e+09
# Chile               Latin America and the Caribbean  9.869191e+09
# Colombia            Latin America and the Caribbean  3.407812e+09
# Costa Rica          Latin America and the Caribbean  1.130278e+09
# Denmark                             Northern Europe  3.565919e+09
# Dominican Republic  Latin America and the Caribbean  6.509236e+08
# Ecuador             Latin America and the Caribbean  1.461315e+09
# El Salvador         Latin America and the Caribbean  5.268831e+08
# Finland                             Northern Europe  2.654623e+09
# France                               Western Europe  1.168422e+10
# Germany                              Western Europe  2.077738e+10
# Greece                              Southern Europe  6.983228e+08
# Guatemala           Latin America and the Caribbean  1.066732e+09
# Honduras            Latin America and the Caribbean  4.477088e+08
# Hong Kong                              Eastern Asia  7.851639e+08
# Hungary                              Eastern Europe  6.709781e+08
# Iceland                             Northern Europe  2.916828e+08
# Indonesia                        South-eastern Asia  8.255808e+09
# Ireland                             Northern Europe  2.209751e+09
# Italy                               Southern Europe  1.358924e+10
# Japan                                  Eastern Asia  5.507563e+09
# Malaysia                         South-eastern Asia  2.043456e+09
# Mexico              Latin America and the Caribbean  2.287400e+10
# Netherlands                          Western Europe  1.018208e+10
# New Zealand               Australia and New Zealand  2.074481e+09
# Norway                              Northern Europe  4.880355e+09
# Panama              Latin America and the Caribbean  6.319854e+08
# Paraguay            Latin America and the Caribbean  1.344949e+09
# Peru                Latin America and the Caribbean  4.527544e+09
# Philippines                      South-eastern Asia  1.010755e+10
# Poland                               Eastern Europe  4.300430e+09
# Portugal                            Southern Europe  1.454081e+09
# Singapore                        South-eastern Asia  1.965480e+09
# Slovakia                             Eastern Europe  3.489526e+08
# Spain                               Southern Europe  1.547413e+10
# Sweden                              Northern Europe  8.015910e+09
# Switzerland                          Western Europe  1.660520e+09
# Turkey                                 Western Asia  6.406908e+09
# Uruguay             Latin America and the Caribbean  7.603492e+08
# Bolivia             Latin America and the Caribbean  6.513140e+08
# Czech Republic                       Eastern Europe  8.462289e+08
# Taiwan                                 Eastern Asia  1.598159e+09
# United Kingdom                      Northern Europe  1.897820e+10
# United States                      Northern America  6.664872e+10

# %%
country_idx_biggest_market_per_subregion = countries_with_subregion_and_streams.groupby(['subregion']).streams.transform(max) == countries_with_subregion_and_streams.streams

# %%
countries_with_most_streams_by_subregion = countries_with_subregion_and_streams[country_idx_biggest_market_per_subregion].reset_index()
countries_with_most_streams_by_subregion
# Out:
#           country                        subregion       streams
# 0       Australia        Australia and New Zealand  1.019892e+10
# 1          Brazil  Latin America and the Caribbean  2.776871e+10
# 2         Germany                   Western Europe  2.077738e+10
# 3           Japan                     Eastern Asia  5.507563e+09
# 4     Philippines               South-eastern Asia  1.010755e+10
# 5          Poland                   Eastern Europe  4.300430e+09
# 6           Spain                  Southern Europe  1.547413e+10
# 7          Turkey                     Western Asia  6.406908e+09
# 8  United Kingdom                  Northern Europe  1.897820e+10
# 9   United States                 Northern America  6.664872e+10

# %%
sns.barplot(countries_with_most_streams_by_subregion, x="country", y="streams")
plt.xticks(rotation=90)
plt.show()

# %%
chart_tracks_largest_country_market_by_subregion = charting_tracks_by_country.set_index("country").loc[country_idx_biggest_market_per_subregion]
chart_tracks_largest_country_market_by_subregion
# Out:
#                                    id    region                  subregion
# country
# Australia      5aAx2yezTd8zXrkmtKl66Z   Oceania  Australia and New Zealand
# Australia      5knuzwU65gJK7IF5yJsuaW   Oceania  Australia and New Zealand
# Australia      7BKLCZ1jbUBVqRi2FVlTVw   Oceania  Australia and New Zealand
# Australia      3NdDpSvN911VPGivFlV5d0   Oceania  Australia and New Zealand
# Australia      78rIJddV4X0HkNAInEcYde   Oceania  Australia and New Zealand
# ...                               ...       ...                        ...
# United States  7ACW7VpgoKmfM1sKo15UhX  Americas           Northern America
# United States  2AaJeBEq3WLcfFW1y8svDf  Americas           Northern America
# United States  20on25jryn53hWghthWWW3  Americas           Northern America
# United States  2ccuOtUjIyx3tPcsnpeBzJ  Americas           Northern America
# United States  7KA4W4McWYRpgf0fWsJZWB  Americas           Northern America
#
# [19766 rows x 3 columns]

# %%
country_tracks_dataset = chart_tracks_largest_country_market_by_subregion.reset_index()

# %%
tracks_charting_only_in_one_country = country_tracks_dataset[
    country_tracks_dataset.duplicated(keep=False, subset="id")
]

# %%
tracks_charting_only_in_one_country.groupby("country").size().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot: xlabel='country'>

# %%
country_track_features = pd.merge(
        track_feats, tracks_charting_only_in_one_country, on="id"
    ).set_index("id")

# %%
country_track_features
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779  2.0    -6.454   1.0
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779  2.0    -6.454   1.0
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779  2.0    -6.454   1.0
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779  2.0    -6.454   1.0
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779  2.0    -6.454   1.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000xQL6tZNLJzIrtIgxqSl       0.0639        0.1310               0.0    0.0852
# 000xQL6tZNLJzIrtIgxqSl       0.0639        0.1310               0.0    0.0852
# 000xQL6tZNLJzIrtIgxqSl       0.0639        0.1310               0.0    0.0852
# 000xQL6tZNLJzIrtIgxqSl       0.0639        0.1310               0.0    0.0852
# 000xQL6tZNLJzIrtIgxqSl       0.0639        0.1310               0.0    0.0852
# ...                             ...           ...               ...       ...
# 7zgqtptZvhf8GEmdsM2vp2       0.1350        0.0665               0.0    0.1550
# 7zgqtptZvhf8GEmdsM2vp2       0.1350        0.0665               0.0    0.1550
# 7zgqtptZvhf8GEmdsM2vp2       0.1350        0.0665               0.0    0.1550
# 7zgqtptZvhf8GEmdsM2vp2       0.1350        0.0665               0.0    0.1550
# 7zgqtptZvhf8GEmdsM2vp2       0.1350        0.0665               0.0    0.1550
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# ...                         ...      ...          ...             ...
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
#
#                         single_release         country    region  \
# id
# 000xQL6tZNLJzIrtIgxqSl            True       Australia   Oceania
# 000xQL6tZNLJzIrtIgxqSl            True           Japan      Asia
# 000xQL6tZNLJzIrtIgxqSl            True     Philippines      Asia
# 000xQL6tZNLJzIrtIgxqSl            True          Poland    Europe
# 000xQL6tZNLJzIrtIgxqSl            True  United Kingdom    Europe
# ...                                ...             ...       ...
# 7zgqtptZvhf8GEmdsM2vp2            True     Philippines      Asia
# 7zgqtptZvhf8GEmdsM2vp2            True          Poland    Europe
# 7zgqtptZvhf8GEmdsM2vp2            True          Turkey      Asia
# 7zgqtptZvhf8GEmdsM2vp2            True  United Kingdom    Europe
# 7zgqtptZvhf8GEmdsM2vp2            True   United States  Americas
#
#                                         subregion
# id
# 000xQL6tZNLJzIrtIgxqSl  Australia and New Zealand
# 000xQL6tZNLJzIrtIgxqSl               Eastern Asia
# 000xQL6tZNLJzIrtIgxqSl         South-eastern Asia
# 000xQL6tZNLJzIrtIgxqSl             Eastern Europe
# 000xQL6tZNLJzIrtIgxqSl            Northern Europe
# ...                                           ...
# 7zgqtptZvhf8GEmdsM2vp2         South-eastern Asia
# 7zgqtptZvhf8GEmdsM2vp2             Eastern Europe
# 7zgqtptZvhf8GEmdsM2vp2               Western Asia
# 7zgqtptZvhf8GEmdsM2vp2            Northern Europe
# 7zgqtptZvhf8GEmdsM2vp2           Northern America
#
# [9568 rows x 18 columns]

# %%
country_track_feats_minmax_scaled = min_max_scale_track_features(country_track_features)

# %%
country_track_feats_minmax_scaled.columns
# Out:
# Index(['explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'single_release',
#        'country', 'region', 'subregion'],
#       dtype='object')

# %%
data = pd.melt(country_track_feats_minmax_scaled.drop(columns=["region", "subregion"]),
                   id_vars="country",
                   var_name="features",
                   value_name='value')

display(data)
print(data.dtypes)

features_per_figure = 4
i = 0
while i < len(track_feat_cols):
    plt.figure(figsize=(16, 4))
    sns.violinplot(x="features", y="value", data=data.loc[data.features.isin(track_feat_cols[i:i+features_per_figure])],
                   hue="country",# compare distributions of values for feature by class (different colors for each of the two classes)
                   #split=True,# split violins (left half distribution of false class, right shows distribution of true)
                   inner="quartile"# show quartiles as lines instead of putting boxplot inside
                   )
    plt.xticks(rotation=90)
    i += features_per_figure

plt.show()
# Out:
#                country        features  value
# 0            Australia        explicit    0.0
# 1                Japan        explicit    0.0
# 2          Philippines        explicit    0.0
# 3               Poland        explicit    0.0
# 4       United Kingdom        explicit    0.0
# ...                ...             ...    ...
# 143515     Philippines  single_release    1.0
# 143516          Poland  single_release    1.0
# 143517          Turkey  single_release    1.0
# 143518  United Kingdom  single_release    1.0
# 143519   United States  single_release    1.0
#
# [143520 rows x 3 columns]
# country      object
# features     object
# value       float64
# dtype: object
