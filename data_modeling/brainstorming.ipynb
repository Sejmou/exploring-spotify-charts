# %% [markdown]
# # Brainstorming

# %% [markdown]
# This notebook documents my attempts to make sense of the data and extract data we could use for a modeling task (regression, classification, clustering etc.) and training some models.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from helpers import get_countries_charts, get_global_charts, get_track_data

# %%
global_charts = get_global_charts()
global_charts
# Out:
#             date  rank    streams                      id
# 0     2017-01-01     1  3135625.0  5aAx2yezTd8zXrkmtKl66Z
# 1     2017-01-01     2  3015525.0  7BKLCZ1jbUBVqRi2FVlTVw
# 2     2017-01-01     3  2545384.0  4pdPtRcBmOSQDlJ3Fk945m
# 3     2017-01-01     4  2356604.0  5knuzwU65gJK7IF5yJsuaW
# 4     2017-01-01     5  2259887.0  1xznGGDReH1oQq0xzbwXa3
# ...          ...   ...        ...                     ...
# 91281 2017-11-14    32  1514407.0  7fwXWKdDNI5IutOMc5OKYw
# 91282 2017-11-14    43  1319431.0  7sO5G9EABYOXQKNPNiE9NR
# 91283 2017-11-14    44  1313844.0  70lnL3QaSOIIyMa2X9aVRL
# 91284 2017-11-14    47  1311951.0  7nZmah2llfvLDiUjm0kiyz
# 91285 2017-11-14    48  1286028.0  7iDa6hUg2VgEL1o1HjmfBn
#
# [91286 rows x 4 columns]

# %%
countries_charts = get_countries_charts()
countries_charts
# Out:
#            country       date  rank   streams                      id  \
# 0        Argentina 2017-01-01     1  253019.0  6mICuAdrwEjh6Y6lroV2Kg
# 1        Argentina 2017-01-01     2  223988.0  7DM4BPaS7uofFul3ywMe46
# 2        Argentina 2017-01-01     3  210943.0  3AEZUABDXNtecAOSC1qTfo
# 3        Argentina 2017-01-01     4  173865.0  6rQSrBHf7HlZjtcMZ4S4bO
# 4        Argentina 2017-01-01     5  153956.0  58IL315gMSTD37DOZPJ2hf
# ...            ...        ...   ...       ...                     ...
# 4472525    Uruguay 2021-08-13    25   11431.0  4aXicRG47bBEcKXlDaSRwW
# 4472526    Uruguay 2021-08-13    27   10946.0  43qcs9NpJhDxtG91zxFkj7
# 4472527    Uruguay 2021-08-13    33    9994.0  4M4DTyLupKvbJKlE4I4EYq
# 4472528    Uruguay 2021-08-13    35    9251.0  5jzEwSyyymBlf1fa1o39T2
# 4472529    Uruguay 2021-08-13    36    9179.0  5PjdY0CKGZdEuoNab3yDmX
#
#         iso_alpha3 iso_alpha2 geo_region                    geo_subregion
# 0              ARG         AR   Americas  Latin America and the Caribbean
# 1              ARG         AR   Americas  Latin America and the Caribbean
# 2              ARG         AR   Americas  Latin America and the Caribbean
# 3              ARG         AR   Americas  Latin America and the Caribbean
# 4              ARG         AR   Americas  Latin America and the Caribbean
# ...            ...        ...        ...                              ...
# 4472525        URY         UY   Americas  Latin America and the Caribbean
# 4472526        URY         UY   Americas  Latin America and the Caribbean
# 4472527        URY         UY   Americas  Latin America and the Caribbean
# 4472528        URY         UY   Americas  Latin America and the Caribbean
# 4472529        URY         UY   Americas  Latin America and the Caribbean
#
# [4472530 rows x 9 columns]

# %%
tracks = get_track_data()
tracks
# Out:
#                         explicit                                  name  \
# id
# 000RW47rhEkSqjgTrZx7YX     False                      Lance Individual
# 000xQL6tZNLJzIrtIgxqSl     False  Still Got Time (feat. PARTYNEXTDOOR)
# 000xYdQfIZ4pDmBGzQalKU     False                 Eu, Você, O Mar e Ela
# 001b8t3bYPfnabpjpfG1Y4      True                             Geen Stof
# 003VDDA7J3Xb2ZFlNx7nIZ      True                               YELL OH
# ...                          ...                                   ...
# 7zxphfIdUMOfZOAVpKFlld      True           Trapper Of The Year (Intro)
# 7zyYmIdjqqiX6kLryb7QBx     False                                以後別做朋友
# 7zyZ9yPXIQebb79PrMghpV     False                               Zap Zum
# 7zyofXGhXgaqT8fhvLufdf     False                  Kuka Antais Pukille?
# 7zzhknA0A39TH81meuX7WA      True                     C'est pas des LOL
#
#                                                               preview_url  \
# id
# 000RW47rhEkSqjgTrZx7YX  https://p.scdn.co/mp3-preview/c64292f4c53560bc...
# 000xQL6tZNLJzIrtIgxqSl  https://p.scdn.co/mp3-preview/83fad967740b8a85...
# 000xYdQfIZ4pDmBGzQalKU  https://p.scdn.co/mp3-preview/ae0e943883e06623...
# 001b8t3bYPfnabpjpfG1Y4  https://p.scdn.co/mp3-preview/535320aa4cbc5811...
# 003VDDA7J3Xb2ZFlNx7nIZ  https://p.scdn.co/mp3-preview/14e659590d1a70cf...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  https://p.scdn.co/mp3-preview/b48d68019fc66831...
# 7zyYmIdjqqiX6kLryb7QBx  https://p.scdn.co/mp3-preview/4d243321f0ec66ba...
# 7zyZ9yPXIQebb79PrMghpV  https://p.scdn.co/mp3-preview/2f82c76f077fb377...
# 7zyofXGhXgaqT8fhvLufdf  https://p.scdn.co/mp3-preview/236ec096925cdb1f...
# 7zzhknA0A39TH81meuX7WA  https://p.scdn.co/mp3-preview/5724fd69cc6a400c...
#
#                        album_type                album_id album_release_date  \
# id
# 000RW47rhEkSqjgTrZx7YX      album  57h6WHDjwNGIs5NMeKYEoL         2021-04-22
# 000xQL6tZNLJzIrtIgxqSl     single  2kGUeTGnkLOYlinKRJe47G         2017-03-23
# 000xYdQfIZ4pDmBGzQalKU      album  4QianJs5Ls4mxwcT7gDBww         2016-11-04
# 001b8t3bYPfnabpjpfG1Y4      album  06v2EPzWTwcP0egTJVrPdU         2021-01-21
# 003VDDA7J3Xb2ZFlNx7nIZ     single  2orYogfKeURqyS1hRP1vZ4         2020-02-07
# ...                           ...                     ...                ...
# 7zxphfIdUMOfZOAVpKFlld     single  65DP4VYecvLUlUVfCsXPLF         2021-11-19
# 7zyYmIdjqqiX6kLryb7QBx      album  1JEzXcEYuEFKKmo4mfMgC7         2014-12-19
# 7zyZ9yPXIQebb79PrMghpV      album  194szTkDIGJsa9iZJNStwN         2021-06-24
# 7zyofXGhXgaqT8fhvLufdf     single  2QIHDFGxEjYdVg8Y1QYBRv         2018-11-21
# 7zzhknA0A39TH81meuX7WA      album  3Jtj1RlmKnRvBkp3YJWHXO         2019-10-04
#
#                        album_release_date_precision          isrc  isrc_year  \
# id
# 000RW47rhEkSqjgTrZx7YX                          day  BRRGE2010642     2020.0
# 000xQL6tZNLJzIrtIgxqSl                          day  USRC11700675     2017.0
# 000xYdQfIZ4pDmBGzQalKU                          day  BRRGE1603547     2016.0
# 001b8t3bYPfnabpjpfG1Y4                          day  NLG662000948     2020.0
# 003VDDA7J3Xb2ZFlNx7nIZ                          day  QZJ842000061     2020.0
# ...                                             ...           ...        ...
# 7zxphfIdUMOfZOAVpKFlld                          day  SE6XY2184006     2021.0
# 7zyYmIdjqqiX6kLryb7QBx                          day  TWA471410001     2014.0
# 7zyZ9yPXIQebb79PrMghpV                          day  BCM112100037     2021.0
# 7zyofXGhXgaqT8fhvLufdf                          day  FIUM71800543     2018.0
# 7zzhknA0A39TH81meuX7WA                          day  FR96X1941264     2019.0
#
#                               isrc_agency  ...    tempo  duration_ms  \
# id                                         ...
# 000RW47rhEkSqjgTrZx7YX  Pro-música Brazil  ...  117.399     164459.0
# 000xQL6tZNLJzIrtIgxqSl               RIAA  ...  120.963     188491.0
# 000xYdQfIZ4pDmBGzQalKU  Pro-música Brazil  ...  166.018     187119.0
# 001b8t3bYPfnabpjpfG1Y4               SENA  ...   95.951     167866.0
# 003VDDA7J3Xb2ZFlNx7nIZ               RIAA  ...   74.496     236779.0
# ...                                   ...  ...      ...          ...
# 7zxphfIdUMOfZOAVpKFlld        IFPI Sweden  ...  121.913     110164.0
# 7zyYmIdjqqiX6kLryb7QBx                RIT  ...  130.576     260573.0
# 7zyZ9yPXIQebb79PrMghpV  Pro-música Brazil  ...  169.123     167503.0
# 7zyofXGhXgaqT8fhvLufdf       IFPI Finland  ...   89.982     241564.0
# 7zzhknA0A39TH81meuX7WA               SCPP  ...  132.004     279467.0
#
#                         time_signature             artist_id_1  \
# id
# 000RW47rhEkSqjgTrZx7YX             4.0  1elUiq4X7pxej6FRlrEzjM
# 000xQL6tZNLJzIrtIgxqSl             4.0  5ZsFI1h6hIdQRw2ti0hz81
# 000xYdQfIZ4pDmBGzQalKU             4.0  3qvcCP2J0fWi0m0uQDUf6r
# 001b8t3bYPfnabpjpfG1Y4             4.0  1wFoE1RwBMWoWkXcFrCgsx
# 003VDDA7J3Xb2ZFlNx7nIZ             4.0  6Xgp2XMz1fhVYe7i6yNAax
# ...                                ...                     ...
# 7zxphfIdUMOfZOAVpKFlld             4.0  2Dor6diK1zw9BEluKBOdoA
# 7zyYmIdjqqiX6kLryb7QBx             4.0  5fEQLwq1BWWQNR8GzhOIvi
# 7zyZ9yPXIQebb79PrMghpV             4.0  6tzRZ39aZlNqlUzQlkuhDV
# 7zyofXGhXgaqT8fhvLufdf             4.0  3zh3U2eQ64EhBFbJuxgf1M
# 7zzhknA0A39TH81meuX7WA             4.0  3IW7ScrzXmPvZhB27hmfgy
#
#                                    artist_id_2             artist_id_3  \
# id
# 000RW47rhEkSqjgTrZx7YX                     NaN                     NaN
# 000xQL6tZNLJzIrtIgxqSl  2HPaUgqeutzr3jx5a9WyDV                     NaN
# 000xYdQfIZ4pDmBGzQalKU                     NaN                     NaN
# 001b8t3bYPfnabpjpfG1Y4                     NaN                     NaN
# 003VDDA7J3Xb2ZFlNx7nIZ  50co4Is1HCEo8bhOyUWKpn                     NaN
# ...                                        ...                     ...
# 7zxphfIdUMOfZOAVpKFlld                     NaN                     NaN
# 7zyYmIdjqqiX6kLryb7QBx                     NaN                     NaN
# 7zyZ9yPXIQebb79PrMghpV                     NaN                     NaN
# 7zyofXGhXgaqT8fhvLufdf  05qPtpcSltJZLI9sj0qm3B  4l0zTor5S32Yly4uw96Bto
# 7zzhknA0A39TH81meuX7WA                     NaN                     NaN
#
#                           artist_name_1  artist_name_2  artist_name_3  \
# id
# 000RW47rhEkSqjgTrZx7YX   Jorge & Mateus            NaN            NaN
# 000xQL6tZNLJzIrtIgxqSl             ZAYN  PARTYNEXTDOOR            NaN
# 000xYdQfIZ4pDmBGzQalKU     Luan Santana            NaN            NaN
# 001b8t3bYPfnabpjpfG1Y4         Josylvio            NaN            NaN
# 003VDDA7J3Xb2ZFlNx7nIZ     Trippie Redd     Young Thug            NaN
# ...                                 ...            ...            ...
# 7zxphfIdUMOfZOAVpKFlld               23            NaN            NaN
# 7zyYmIdjqqiX6kLryb7QBx        Eric Chou            NaN            NaN
# 7zyZ9yPXIQebb79PrMghpV    Pabllo Vittar            NaN            NaN
# 7zyofXGhXgaqT8fhvLufdf  Teflon Brothers         Spekti   Petri Nygård
# 7zzhknA0A39TH81meuX7WA              Jul            NaN            NaN
#
#                                                                    genres
# id
# 000RW47rhEkSqjgTrZx7YX      [arrocha, sertanejo, sertanejo universitario]
# 000xQL6tZNLJzIrtIgxqSl  [dance pop, pop, post-teen pop, uk pop, r&b, r...
# 000xYdQfIZ4pDmBGzQalKU  [arrocha, sertanejo, sertanejo pop, sertanejo ...
# 001b8t3bYPfnabpjpfG1Y4                                    [dutch hip hop]
# 003VDDA7J3Xb2ZFlNx7nIZ  [melodic rap, rap, trap, atl hip hop, atl trap...
# ...                                                                   ...
# 7zxphfIdUMOfZOAVpKFlld  [swedish drill, swedish hip hop, swedish trap ...
# 7zyYmIdjqqiX6kLryb7QBx                                         [mandopop]
# 7zyZ9yPXIQebb79PrMghpV  [dance pop, funk carioca, funk pop, pop, pop l...
# 7zyofXGhXgaqT8fhvLufdf  [eurovision, finnish dance pop, finnish hip ho...
# 7zzhknA0A39TH81meuX7WA                         [francoton, rap marseille]
#
# [33881 rows x 31 columns]

# %% [markdown]
# ## Extracting track features

# %% [markdown]
# We pick some track features that are easily extractable.

# %%
isrc_cols = tracks.columns[tracks.columns.str.contains("isrc")].tolist()
album_cols = tracks.columns[tracks.columns.str.contains("album")].tolist()
artist_cols = tracks.columns[tracks.columns.str.contains("artist")].tolist()
other_irrelevant_cols = ["name", "preview_url", "genres"]
irrelevant_cols = isrc_cols + album_cols + artist_cols + other_irrelevant_cols


track_feats = tracks.drop(columns=irrelevant_cols)
track_feats["single_release"] = tracks.album_type == "single"
track_feats
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xQL6tZNLJzIrtIgxqSl       0.0639       0.13100          0.000000    0.0852
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release
# id
# 000RW47rhEkSqjgTrZx7YX           False
# 000xQL6tZNLJzIrtIgxqSl            True
# 000xYdQfIZ4pDmBGzQalKU           False
# 001b8t3bYPfnabpjpfG1Y4           False
# 003VDDA7J3Xb2ZFlNx7nIZ            True
# ...                                ...
# 7zxphfIdUMOfZOAVpKFlld            True
# 7zyYmIdjqqiX6kLryb7QBx           False
# 7zyZ9yPXIQebb79PrMghpV           False
# 7zyofXGhXgaqT8fhvLufdf            True
# 7zzhknA0A39TH81meuX7WA           False
#
# [33881 rows x 15 columns]

# %%
track_feats.isna().sum()
# Out:
# explicit            0
# danceability        5
# energy              5
# key                 5
# loudness            5
# mode                5
# speechiness         5
# acousticness        5
# instrumentalness    5
# liveness            5
# valence             5
# tempo               5
# duration_ms         5
# time_signature      5
# single_release      0
# dtype: int64

# %% [markdown]
# Let's just drop the examples where data is missing

# %%
track_feats = track_feats.dropna()
track_feats
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xQL6tZNLJzIrtIgxqSl       0.0639       0.13100          0.000000    0.0852
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release
# id
# 000RW47rhEkSqjgTrZx7YX           False
# 000xQL6tZNLJzIrtIgxqSl            True
# 000xYdQfIZ4pDmBGzQalKU           False
# 001b8t3bYPfnabpjpfG1Y4           False
# 003VDDA7J3Xb2ZFlNx7nIZ            True
# ...                                ...
# 7zxphfIdUMOfZOAVpKFlld            True
# 7zyYmIdjqqiX6kLryb7QBx           False
# 7zyZ9yPXIQebb79PrMghpV           False
# 7zyofXGhXgaqT8fhvLufdf            True
# 7zzhknA0A39TH81meuX7WA           False
#
# [33876 rows x 15 columns]

# %% [markdown]
# We notice that we only lost 5 tracks.

# %% [markdown]
# Note: this functionality has been extracted into a function for my `helpers` package:

# %%
from helpers.model import get_basic_track_features
track_feats_from_helper = get_basic_track_features()
track_feats_from_helper
# Out:
#                         explicit  danceability  energy  key  loudness  mode  \
# id
# 000RW47rhEkSqjgTrZx7YX     False         0.752   0.620  5.0    -5.536   1.0
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627  7.0    -6.029   1.0
# 000xYdQfIZ4pDmBGzQalKU     False         0.509   0.803  0.0    -6.743   1.0
# 001b8t3bYPfnabpjpfG1Y4      True         0.772   0.635  9.0    -4.846   1.0
# 003VDDA7J3Xb2ZFlNx7nIZ      True         0.842   0.578  6.0    -6.050   0.0
# ...                          ...           ...     ...  ...       ...   ...
# 7zxphfIdUMOfZOAVpKFlld      True         0.725   0.453  6.0   -11.291   0.0
# 7zyYmIdjqqiX6kLryb7QBx     False         0.423   0.360  3.0    -9.458   1.0
# 7zyZ9yPXIQebb79PrMghpV     False         0.596   0.864  8.0    -3.850   1.0
# 7zyofXGhXgaqT8fhvLufdf     False         0.637   0.741  9.0    -4.364   1.0
# 7zzhknA0A39TH81meuX7WA      True         0.939   0.700  9.0    -6.526   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000RW47rhEkSqjgTrZx7YX       0.0509       0.30900          0.000000    0.0750
# 000xQL6tZNLJzIrtIgxqSl       0.0639       0.13100          0.000000    0.0852
# 000xYdQfIZ4pDmBGzQalKU       0.0400       0.68400          0.000539    0.4630
# 001b8t3bYPfnabpjpfG1Y4       0.3720       0.10500          0.000000    0.1170
# 003VDDA7J3Xb2ZFlNx7nIZ       0.1380       0.00419          0.000000    0.2280
# ...                             ...           ...               ...       ...
# 7zxphfIdUMOfZOAVpKFlld       0.3160       0.00582          0.013500    0.0827
# 7zyYmIdjqqiX6kLryb7QBx       0.0372       0.72800          0.000000    0.1050
# 7zyZ9yPXIQebb79PrMghpV       0.0400       0.08580          0.000000    0.1580
# 7zyofXGhXgaqT8fhvLufdf       0.0300       0.20000          0.000000    0.1850
# 7zzhknA0A39TH81meuX7WA       0.0519       0.18700          0.000000    0.0940
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000RW47rhEkSqjgTrZx7YX    0.962  117.399     164459.0             4.0
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 000xYdQfIZ4pDmBGzQalKU    0.651  166.018     187119.0             4.0
# 001b8t3bYPfnabpjpfG1Y4    0.541   95.951     167866.0             4.0
# 003VDDA7J3Xb2ZFlNx7nIZ    0.190   74.496     236779.0             4.0
# ...                         ...      ...          ...             ...
# 7zxphfIdUMOfZOAVpKFlld    0.461  121.913     110164.0             4.0
# 7zyYmIdjqqiX6kLryb7QBx    0.291  130.576     260573.0             4.0
# 7zyZ9yPXIQebb79PrMghpV    0.833  169.123     167503.0             4.0
# 7zyofXGhXgaqT8fhvLufdf    0.419   89.982     241564.0             4.0
# 7zzhknA0A39TH81meuX7WA    0.886  132.004     279467.0             4.0
#
#                         single_release
# id
# 000RW47rhEkSqjgTrZx7YX           False
# 000xQL6tZNLJzIrtIgxqSl            True
# 000xYdQfIZ4pDmBGzQalKU           False
# 001b8t3bYPfnabpjpfG1Y4           False
# 003VDDA7J3Xb2ZFlNx7nIZ            True
# ...                                ...
# 7zxphfIdUMOfZOAVpKFlld            True
# 7zyYmIdjqqiX6kLryb7QBx           False
# 7zyZ9yPXIQebb79PrMghpV           False
# 7zyofXGhXgaqT8fhvLufdf            True
# 7zzhknA0A39TH81meuX7WA           False
#
# [33876 rows x 15 columns]

# %%
track_feats.isna().sum()
# Out:
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# single_release      0
# dtype: int64

# %%
track_feats_from_helper.isna().sum()
# Out:
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# single_release      0
# dtype: int64

# %%
(track_feats != track_feats_from_helper).sum()
# Out:
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# single_release      0
# dtype: int64

# %%
binary_and_cat_feats = ["explicit", "key", "mode", "time_signature", "single_release"]

# %%
interval_feats = [
    feat
    for feat in track_feats.columns.tolist()
    if feat not in binary_and_cat_feats
]

# %%
len(interval_feats)
# Out:
# 10

# %%
len(binary_and_cat_feats)
# Out:
# 5

# %% [markdown]
# ### Feature value distributions across tracks in dataset

# %%
def plot_boxplots(df, features, figsize=(18, 5)):
    fig, axs = plt.subplots(2, 5, figsize=(18, 5))
    axs = axs.ravel()

    for i, feature in enumerate(features):
        df.boxplot([feature], ax=axs[i])

    plt.show()


plot_boxplots(track_feats, interval_feats)

# %%
def violinplots_for_features(df, features, figsize=(18, 8)):
    fig, axs = plt.subplots(2, 5, figsize=figsize)
    axs = axs.ravel()

    for i, feature in enumerate(features):
        sns.violinplot(x=feature, data=df, ax=axs[i])

    plt.show()

violinplots_for_features(track_feats, interval_feats)

# %%
def countplots_for_categorical_features(track_features):
    fig, axs = plt.subplots(3, 2, figsize=(16, 14))
    axs = axs.ravel()
    for i, column in enumerate(track_features.drop(columns=interval_feats)):
        sns.countplot(data=track_features, x=column, ax=axs[i])
    
    plt.show()

countplots_for_categorical_features(track_feats)

# %%
global_chart_track_features = track_feats[track_feats.index.isin(global_charts["id"])]
global_chart_track_features
# Out:
#                         explicit  danceability  energy   key  loudness  mode  \
# id
# 000xQL6tZNLJzIrtIgxqSl     False         0.748   0.627   7.0    -6.029   1.0
# 00Blm7zeNqgYLPtW6zg8cj      True         0.687   0.781   1.0    -4.806   1.0
# 00ko9WaS4jOX1kEk3gvHjf      True         0.899   0.509   9.0    -8.040   1.0
# 00lNx0OcTJrS3MKHcB80HY      True         0.876   0.669  11.0    -6.054   0.0
# 017PF4Q3l4DBUiWoXk4OWT     False         0.730   0.729   4.0    -3.434   0.0
# ...                          ...           ...     ...   ...       ...   ...
# 7yyRTcZmCiyzzJlNzGC9Ol      True         0.886   0.525   8.0    -7.390   1.0
# 7z4xW9WY86uH3gd1V9pfCM      True         0.827   0.571  11.0    -7.949   1.0
# 7zLGHiDWd9T1Rxw4PQCb13      True         0.577   0.593   9.0    -4.816   0.0
# 7zQirOExB0VR8yWUOqYeio      True         0.923   0.533  11.0    -6.016   0.0
# 7zgqtptZvhf8GEmdsM2vp2     False         0.615   0.779   2.0    -6.454   1.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 000xQL6tZNLJzIrtIgxqSl       0.0639       0.13100          0.000000    0.0852
# 00Blm7zeNqgYLPtW6zg8cj       0.0530       0.03610          0.000000    0.0755
# 00ko9WaS4jOX1kEk3gvHjf       0.3870       0.00157          0.000000    0.0573
# 00lNx0OcTJrS3MKHcB80HY       0.1380       0.16300          0.000000    0.1850
# 017PF4Q3l4DBUiWoXk4OWT       0.0884       0.16700          0.000001    0.3490
# ...                             ...           ...               ...       ...
# 7yyRTcZmCiyzzJlNzGC9Ol       0.1310       0.23600          0.000000    0.0570
# 7z4xW9WY86uH3gd1V9pfCM       0.3660       0.01950          0.000000    0.1660
# 7zLGHiDWd9T1Rxw4PQCb13       0.1370       0.80000          0.000000    0.6230
# 7zQirOExB0VR8yWUOqYeio       0.2620       0.05040          0.000000    0.1020
# 7zgqtptZvhf8GEmdsM2vp2       0.1350       0.06650          0.000000    0.1550
#
#                         valence    tempo  duration_ms  time_signature  \
# id
# 000xQL6tZNLJzIrtIgxqSl    0.524  120.963     188491.0             4.0
# 00Blm7zeNqgYLPtW6zg8cj    0.688   97.014     193507.0             4.0
# 00ko9WaS4jOX1kEk3gvHjf    0.599  150.001     225924.0             4.0
# 00lNx0OcTJrS3MKHcB80HY    0.682  124.007     213947.0             4.0
# 017PF4Q3l4DBUiWoXk4OWT    0.467  113.011     221820.0             4.0
# ...                         ...      ...          ...             ...
# 7yyRTcZmCiyzzJlNzGC9Ol    0.708  145.990     225205.0             4.0
# 7z4xW9WY86uH3gd1V9pfCM    0.620  142.034     146419.0             4.0
# 7zLGHiDWd9T1Rxw4PQCb13    0.575  120.611     303781.0             5.0
# 7zQirOExB0VR8yWUOqYeio    0.587  133.991     145075.0             4.0
# 7zgqtptZvhf8GEmdsM2vp2    0.453  160.000     208198.0             4.0
#
#                         single_release
# id
# 000xQL6tZNLJzIrtIgxqSl            True
# 00Blm7zeNqgYLPtW6zg8cj            True
# 00ko9WaS4jOX1kEk3gvHjf           False
# 00lNx0OcTJrS3MKHcB80HY            True
# 017PF4Q3l4DBUiWoXk4OWT           False
# ...                                ...
# 7yyRTcZmCiyzzJlNzGC9Ol           False
# 7z4xW9WY86uH3gd1V9pfCM           False
# 7zLGHiDWd9T1Rxw4PQCb13            True
# 7zQirOExB0VR8yWUOqYeio           False
# 7zgqtptZvhf8GEmdsM2vp2            True
#
# [2361 rows x 15 columns]

# %%
plot_boxplots(global_chart_track_features, interval_feats)

# %%
violinplots_for_features(global_chart_track_features, interval_feats)

# %%
countplots_for_categorical_features(global_chart_track_features)

# %% [markdown]
# ## Track genres

# %%
import numpy as np

# %%
np.array(tracks.genres.values)
# Out:
# array([list(['arrocha', 'sertanejo', 'sertanejo universitario']),
#        list(['dance pop', 'pop', 'post-teen pop', 'uk pop', 'r&b', 'rap', 'toronto rap', 'trap', 'urban contemporary']),
#        list(['arrocha', 'sertanejo', 'sertanejo pop', 'sertanejo universitario']),
#        ...,
#        list(['dance pop', 'funk carioca', 'funk pop', 'pop', 'pop lgbtq+ brasileira', 'pop nacional']),
#        list(['eurovision', 'finnish dance pop', 'finnish hip hop', 'finnish pop']),
#        list(['francoton', 'rap marseille'])], dtype=object)

# %%
all_genres = pd.Series(np.concatenate(tracks.genres.values))
all_genres
# Out:
# 0                         arrocha
# 1                       sertanejo
# 2         sertanejo universitario
# 3                       dance pop
# 4                             pop
#                    ...
# 108546          finnish dance pop
# 108547            finnish hip hop
# 108548                finnish pop
# 108549                  francoton
# 108550              rap marseille
# Length: 108551, dtype: object

# %%
all_genres.str.isupper().sum()
# Out:
# 0

# %% [markdown]
# ### Exploring single words (unigrams) in genre names

# %%
genre_unigrams = all_genres.str.split("\s", expand=True).stack()
unigram_counts = genre_unigrams.value_counts()
unigram_counts
# Out:
# pop       32731
# hip       22739
# hop       22639
# rap       13525
# trap       9457
#           ...
# jewish        1
# malian        1
# cuban         1
# violin        1
# early         1
# Length: 1120, dtype: int64

# %%
unigram_counts.describe()
# Out:
# count     1120.000000
# mean       204.122321
# std       1504.791381
# min          1.000000
# 25%          2.000000
# 50%          8.000000
# 75%         41.000000
# max      32731.000000
# dtype: float64

# %%
len(unigram_counts)
# Out:
# 1120

# %%
unigram_counts.sum()
# Out:
# 228617

# %%
unigram_counts[:50].sum()
# Out:
# 181181

# %%
unigram_counts[:50]
# Out:
# pop            32731
# hip            22739
# hop            22639
# rap            13525
# trap            9457
# dance           4937
# finnish         4292
# swedish         4228
# german          3961
# italian         3603
# dutch           3008
# rock            2937
# reggaeton       2807
# polish          2514
# french          2469
# house           2318
# danish          2154
# indie           2147
# urbaine         2145
# latino          1949
# turkish         1940
# drill           1938
# icelandic       1895
# latin           1860
# uk              1857
# greek           1615
# czsk            1606
# francais        1451
# czech           1362
# edm             1312
# r&b             1169
# francoton       1158
# tropical        1147
# funk            1027
# norwegian       1000
# canadian         954
# melodic          938
# classic          928
# sertanejo        925
# alternative      893
# italiana         846
# mandopop         817
# k-pop            805
# conscient        788
# taiwan           785
# post-teen        772
# atl              765
# electropop       737
# slovak           680
# electro          651
# dtype: int64

# %% [markdown]
# ### Identifying common patterns

# %%
all_genres.str.contains(" ").sum()
# Out:
# 87056

# %%
all_genres.str.contains("pop").sum()
# Out:
# 37163

# %%
all_genres.str.contains("rock").sum()
# Out:
# 3128

# %%
all_genres.str.contains("hip hop").sum()
# Out:
# 22634

# %% [markdown]
# ### Genre diversity

# %%
unique_genres = all_genres.drop_duplicates().reset_index(drop=True)

# %%
unique_genres
# Out:
# 0                       arrocha
# 1                     sertanejo
# 2       sertanejo universitario
# 3                     dance pop
# 4                           pop
#                  ...
# 1788     early modern classical
# 1789          swedish classical
# 1790                 afro house
# 1791                future bass
# 1792         puerto rican indie
# Length: 1793, dtype: object

# %%
unique_genres[unique_genres.str.contains("pop")]
# Out:
# 3                 dance pop
# 4                       pop
# 5             post-teen pop
# 6                    uk pop
# 12            sertanejo pop
#                ...
# 1764         melanesian pop
# 1765                png pop
# 1766    solomon islands pop
# 1772         lithuanian pop
# 1777              chill pop
# Length: 286, dtype: object

# %%
unique_genres[unique_genres.str.contains("hip hop")]
# Out:
# 13           dutch hip hop
# 15             atl hip hop
# 18                 hip hop
# 20        southern hip hop
# 28         italian hip hop
#                ...
# 1613       cypriot hip hop
# 1643    sacramento hip hop
# 1707       lapland hip hop
# 1736     nashville hip hop
# 1737        hip hop cubano
# Length: 120, dtype: object

# %%
unique_genres[unique_genres.str.contains("rock")]
# Out:
# 24         alternative rock
# 25               dance rock
# 27                     rock
# 131              album rock
# 132            classic rock
#                ...
# 1745    garage rock revival
# 1752                 k-rock
# 1759              idol rock
# 1773        lithuanian rock
# 1784            boston rock
# Length: 134, dtype: object

# %%
unique_genres[unique_genres.str.contains("dance")]
# Out:
# 3                     dance pop
# 25                   dance rock
# 38            finnish dance pop
# 49                    pop dance
# 125                    uk dance
# 148               russian dance
# 246             bubblegum dance
# 247                   eurodance
# 276              afro dancehall
# 388                uk dancehall
# 471                   dancehall
# 499                 italo dance
# 539                german dance
# 630           swedish dancehall
# 666               belgian dance
# 714          japanese dance pop
# 751             dancehall queen
# 810           alternative dance
# 811            australian dance
# 857              dancefloor dnb
# 961           swedish eurodance
# 1066         jamaican dancehall
# 1302    south african pop dance
# 1402       old school dancehall
# 1565               zimdancehall
# 1660         magyar retro dance
# 1729        dancehall guyanaise
# dtype: object

# %%
unique_genres[unique_genres.str.contains("edm")]
# Out:
# 48                 edm
# 149        russian edm
# 309            pop edm
# 322          dutch edm
# 407      brazilian edm
# 515     lithuanian edm
# 634        turkish edm
# 667        belgian edm
# 776         gaming edm
# 820      hungarian edm
# 1135       finnish edm
# 1154      deep pop edm
# 1335        indian edm
# dtype: object

# %%
unique_genres[unique_genres.str.contains("reggaeton")]
# Out:
# 46                 reggaeton
# 67      reggaeton colombiano
# 68            reggaeton flow
# 360            pop reggaeton
# 596        reggaeton chileno
# 1153      reggaeton mexicano
# dtype: object

# %%
unique_genres[unique_genres.str.contains("rap")]
# Out:
# 8                             rap
# 9                     toronto rap
# 10                           trap
# 14                    melodic rap
# 16                       atl trap
#                   ...
# 1696    hungarian underground rap
# 1740              german jazz rap
# 1763                   smutny rap
# 1774            turkce trap metal
# 1778                aesthetic rap
# Length: 195, dtype: object

# %%
unique_genres[unique_genres.str.contains("trap")]
# Out:
# 10                     trap
# 16                 atl trap
# 47              trap latino
# 66         swedish trap pop
# 77              slovak trap
# 81              polish trap
# 104            swedish trap
# 108           trap italiana
# 111              vapor trap
# 143        turkish trap pop
# 165              pinoy trap
# 170             german trap
# 173              greek trap
# 186          trap antillais
# 188            detroit trap
# 229            trap boricua
# 261            turkish trap
# 283          trap argentino
# 291             trap triste
# 328         trap dominicano
# 357         australian trap
# 358         trap venezolano
# 393           trap mexicano
# 413     trap metal italiana
# 428              trap queen
# 435             trap baiano
# 438         trap brasileiro
# 470               dark trap
# 475            finnish trap
# 479             magyar trap
# 555           canadian trap
# 584               trap funk
# 597            trap chileno
# 644               trap tuga
# 660               trap soul
# 703         electronic trap
# 731             trap catala
# 735            trap carioca
# 736             trap pesado
# 754          norwegian trap
# 854                 traprun
# 864               bass trap
# 903              swiss trap
# 1069        trap colombiano
# 1130             trap maroc
# 1170             dutch trap
# 1204      emo trap italiana
# 1284               traphall
# 1400           russian trap
# 1603              arab trap
# 1633             viral trap
# 1644        west coast trap
# 1667           trap peruano
# 1682            balkan trap
# 1774      turkce trap metal
# dtype: object

# %%
unique_genres[unique_genres.str.contains("trap")].shape[0]
# Out:
# 55
